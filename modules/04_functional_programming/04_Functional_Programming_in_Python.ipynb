# %% [markdown]
# # Functional Programming in Python
#
# Functional programming is a programming paradigm that focuses on using functions to perform computation and avoiding changing state and mutable data. It is a declarative programming style, where the programmer specifies what the program should do, instead of how it should do it. This leads to more concise, easy to understand, and predictable code.
#
# In Python, functional programming can be achieved through the use of higher-order functions such as map, filter, and reduce. These functions can be used to perform operations on lists or other iterable objects in a functional manner. Another way to implement functional programming in Python is through the use of lambda functions. These are small anonymous functions that can be defined inline and passed as arguments to other functions, similar to closures or function pointers in other languages. They are useful for defining simple, one-time-use functions that would be impractical to define using the def keyword.
#
# As is generally the case with Python, it can be used to write functional code, but there is no way to enforce the standard. Other languages, like Haskell, were designed to be functional programming languages and have the tenants of functional programming built in.
#
#
# Core tenants:
# * You always work with immutable data structures. One of the benefits of this is that it enables you to more easily parallelize code because your data structures are locked, so you don't have to worry about simultaneous reads from different threads
# * Decrease errors because you do not have to retype field names
#
# Pros:
# * Runs faster
# * Can decrease bugs
#
# Cons:
# * Steep learning curve
# * Verbosity: functional programming can lead to more verbose code, as functions are often used in place of simpler constructs like loops and conditional statements.
# * Harder to debug: since functional programming emphasizes immutability and the avoidance of side-effects, it can be harder to debug issues that arise in functional code.
#
#
# ## Contents
#
# * [Immutable Data Structures](#immutable_data_structures)
# * [Functional Primatives](#Functional-Primatives)
# * [filter()](#filter())
# * [map()](#map())
# * [reduce()](#reduce())
# * [Parallel Processing with Functional Programming](#Parallel-Processing-with-Functional-Programming)
# * [Multiprocessing](#Multiprocessing)
# * [Concurrent.futures](#concurrent.futures)
# * [Multiprocessing vs Concurrent.Futures and the GIL](#Multiprocessing-vs-Concurrent.Futures-and-the-GIL)
# * [The End of the GIL?](#The-End-of-the-GIL?)
# * [Resources](#Resources)

# %% [markdown]
# Data cleaning I did on underlying [datasource](https://www.kaggle.com/datasets/matheusdalbuquerque/philosophers-dataset?resource=download) saved for reference

# %%
import pandas as pd
import ast
import re

df = pd.read_csv("Philosophers-dataset.csv")

new_df = df[["Born", "Birth place", "Died", "Subjects Of Study", "Philosophers"]]
new_df = new_df.dropna()
new_df = new_df[new_df["Born"].str.contains("BCE") == False] # Don't want to deal with BCE dates; sorry Socrates


def get_country(places):
    if not places:
        return None
    else:
        return places[-1]
    
new_df["Birth Country"] = new_df['Birth place'].apply(lambda x: ast.literal_eval(x)).apply(get_country)
# This is ugly, but I got a bit lazy; will endeavor to beautify later
new_df["Born"] = new_df["Born"].apply(lambda x: x.split(", ")[-1]).apply(lambda x: x.split(". ")[-1]).apply(lambda x: x.split(" ")[-1]).apply(lambda x: x.replace("?", "")).apply(lambda x: int(x))
new_df["Died"] = new_df["Died"].apply(lambda x: x.split(", ")[-1]).apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x)).apply(lambda x: x.split(". ")[-1]).apply(lambda x: x.split(" ")[-1] if x.split(" ")[-1] != "" else x.split(" ")[0]).apply(lambda x: x.replace(")", "")).apply(lambda x: x.replace("?", "")).apply(lambda x: int(x))
del new_df["Birth place"]
new_df.columns = ["_".join(i.lower().split(" ")) for i in new_df.columns]
new_df = new_df.dropna()
new_df = new_df.rename(columns={"philosophers": "name"})

# We'll need this for the reduce section later 
all_subjects = list(set([a for b in new_df["subjects_of_study"].apply(lambda x: x.split(", ")).tolist() for a in b]))
all_countries = list(set([x for x in new_df["birth_country"].tolist()]))

new_df
# Out:
#      born  died                                  subjects_of_study  \
# 1    1856  1922                               Agriculture, Zionism
# 3    1907  1972                    Judaism, Philosophy Of Religion
# 18   1316  1390                                            Gravity
# 23   1463  1512                                  William Of Ockham
# 26   1714  1762  Aesthetics, Gottfried Wilhelm Leibniz, Feeling...
# ..    ...   ...                                                ...
# 655  1020  1077                                            Ren, Qi
# 656  1017  1073                        Confucianism, Dark Learning
# 657  1130  1200                                             Qi, Li
# 661   878   950             Political Philosophy, Greek Philosophy
# 662  1058  1111                              Islam, Sufism, Sharif
#
#                               name birth_country
# 1               Aaron David Gordon       Ukraine
# 3           Abraham Joshua Heschel        Poland
# 18                Albert of Saxony       Germany
# 23            Alessandro Achillini         Italy
# 26   Alexander Gottlieb Baumgarten       Germany
# ..                             ...           ...
# 655                      Zhang Zai         China
# 656                     Zhou Dunyi         China
# 657                         Zhu Xi         China
# 661                      al-Farabi     Turkistan
# 662                     al-Ghazali          Iran
#
# [282 rows x 5 columns]

# %% [markdown]
# <a id='immutable_data_structures'></a>
# ## Immutable Data Structures

# %%
# Namedtuples
import collections
from pprint import pprint


Philosopher = collections.namedtuple("Philosopher", [
    "born",
    "died",
    "subjects_of_study",
    "name",
    "birth_country"
])


# This could also been defined:
# Philosophers = collections.namedtuple("Philosopher", [
#     *new_df.columns
# ])
# 
# This is in fact the preferred way to define it to ensure you are not getting the order wrong in the step below

# %%
# mixed mutable and immutable types

philosophers = [Philosopher(*row) for row in new_df.itertuples(index=False, name=None)]
philosophers
# Out:
# [Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine'),
#  Philosopher(born=1907, died=1972, subjects_of_study='Judaism, Philosophy Of Religion', name='Abraham Joshua Heschel', birth_country='Poland'),
#  Philosopher(born=1316, died=1390, subjects_of_study='Gravity', name='Albert of Saxony', birth_country='Germany'),
#  Philosopher(born=1463, died=1512, subjects_of_study='William Of Ockham', name='Alessandro Achillini', birth_country='Italy'),
#  Philosopher(born=1714, died=1762, subjects_of_study='Aesthetics, Gottfried Wilhelm Leibniz, Feeling, Christian, Baron Von Wolff', name='Alexander Gottlieb Baumgarten', birth_country='Germany'),
#  Philosopher(born=1853, died=1920, subjects_of_study='Objectivism, Intentionality', name='Alexius Meinong', birth_country='Ukraine'),
#  Philosopher(born=1857, died=1940, subjects_of_study='Philosophy Of Religion, Modernism', name='Alfred Firmin Loisy', birth_country='France'),
#  Philosopher(born=1879, died=1950, subjects_of_study='Semantics, General Semantics', name='Alfred Korzybski', birth_country='Poland'),
#  Philosopher(born=1861, died=1947, subjects_of_study='Education, Mathematics, Philosophy Of Science, Formal Logic, Materialism', name='Alfred North Whitehead', birth_country='England'),
#  Philosopher(born=1930, died=1992, subjects_of_study='Higher Education', name='Allan Bloom', birth_country='Indiana'),
#  Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy'),
#  Philosopher(born=1843, died=1904, subjects_of_study='Socialism, Historical Materialism', name='Antonio Labriola', birth_country='Kingdom of the Two Sicilies'),
#  Philosopher(born=1797, died=1855, subjects_of_study='Philosophy Of Religion', name='Antonio Rosmini-Serbati', birth_country='Italy'),
#  Philosopher(born=1923, died=2010, subjects_of_study='Atheism, Philosophy Of Religion, Theology', name='Antony Flew', birth_country='England'),
#  Philosopher(born=1878, died=1959, subjects_of_study='Phenomenon', name='Armando Carlini', birth_country='Italy'),
#  Philosopher(born=1873, died=1962, subjects_of_study='Great Chain Of Being', name='Arthur O. Lovejoy', birth_country='Germany'),
#  Philosopher(born=1788, died=1860, subjects_of_study='Philosophy Of Art, Panpsychism', name='Arthur Schopenhauer', birth_country='Poland'),
#  Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England'),
#  Philosopher(born=80, died=150, subjects_of_study='Mahayana', name='Ashvaghosha', birth_country='India'),
#  Philosopher(born=1798, died=1857, subjects_of_study='Sociology, Social Evolution', name='Auguste Comte', birth_country='France'),
#  Philosopher(born=1126, died=1198, subjects_of_study='Islam, Platonism, Aristotelianism, Greek Philosophy', name='Averroes', birth_country='Spain'),
#  Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan'),
#  Philosopher(born=1528, died=1580, subjects_of_study='Casuistry, Probabilism', name='Bartolome de Medina', birth_country='Spain'),
#  Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy'),
#  Philosopher(born=1632, died=1677, subjects_of_study='Pantheism, Mind-Body Dualism', name='Benedict de Spinoza', birth_country='Netherlands'),
#  Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'),
#  Philosopher(born=1670, died=1733, subjects_of_study='Virtue', name='Bernard de Mandeville', birth_country='Netherlands'),
#  Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales'),
#  Philosopher(born=1403, died=1472, subjects_of_study='Greek Literature, Platonism', name='Bessarion', birth_country='Turkey'),
#  Philosopher(born=570, died=651, subjects_of_study='Philosophy Of Language, Shabdadvaita', name='Bhartrihari', birth_country='India'),
#  Philosopher(born=1623, died=1662, subjects_of_study='Probability, Conic Section, Pascal’S Triangle, Cycloid, Pascal’S Principle', name='Blaise Pascal', birth_country='France'),
#  Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland'),
#  Philosopher(born=1905, died=1997, subjects_of_study='Philosophy Of Science, Scientific Theory, Covering-Law Model', name='Carl Gustav Hempel', birth_country='Germany'),
#  Philosopher(born=1839, died=1914, subjects_of_study='Category, Induction, Abduction', name='Charles Sanders Peirce', birth_country='Massachusetts'),
#  Philosopher(born=1032, died=1085, subjects_of_study='Li, Neo-Confucianism', name='Cheng Hao', birth_country='China'),
#  Philosopher(born=1033, died=1107, subjects_of_study='Li, Neo-Confucianism, Lixue', name='Cheng Yi', birth_country='China'),
#  Philosopher(born=1715, died=1771, subjects_of_study='Education', name='Claude-Adrien Helvetius', birth_country='France'),
#  Philosopher(born=1808, died=1874, subjects_of_study='Rationalism, Religion, Dialectic', name='David Friedrich Strauss', birth_country='Germany'),
#  Philosopher(born=1705, died=1757, subjects_of_study='Associationism', name='David Hartley', birth_country='England'),
#  Philosopher(born=1711, died=1776, subjects_of_study='England, Miracle, Idea, Neutral Monism, Causation', name='David Hume', birth_country='Scotland'),
#  Philosopher(born=1877, died=1971, subjects_of_study='Aristotelianism', name='David Ross', birth_country='Scotland'),
#  Philosopher(born=1713, died=1784, subjects_of_study='Dramatic Literature', name='Denis Diderot', birth_country='France'),
#  Philosopher(born=1942, died=2017, subjects_of_study='Personal Identity, Triple Theory', name='Derek Parfit', birth_country='China'),
#  Philosopher(born=1891, died=1942, subjects_of_study='Phenomenology, Thomism', name='Edith Stein', birth_country='Poland'),
#  Philosopher(born=1859, died=1938, subjects_of_study='Consciousness, Eidetic Reduction, Phenomenological Reduction', name='Edmund Husserl', birth_country='Czechoslovakia'),
#  Philosopher(born=1842, died=1906, subjects_of_study='Rationalism, Irrationalism, Unconscious', name='Eduard von Hartmann', birth_country='Germany'),
#  Philosopher(born=1835, died=1908, subjects_of_study='Immanuel Kant, Theology', name='Edward Caird', birth_country='Scotland'),
#  Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland'),
#  Philosopher(born=1906, died=1995, subjects_of_study='Judaism', name='Emmanuel Levinas', birth_country='Lithuania'),
#  Philosopher(born=1883, died=1949, subjects_of_study='Faith', name='Erich Frank', birth_country='Czech Republic'),
#  Philosopher(born=1900, died=1980, subjects_of_study='Self-Image', name='Erich Fromm', birth_country='Germany'),
#  Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia'),
#  Philosopher(born=1823, died=1892, subjects_of_study='Judaism, Jesus, Rationalism, Religion, Early Church', name='Ernest Renan', birth_country='France'),
#  Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria'),
#  Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany'),
#  Philosopher(born=1887, died=1961, subjects_of_study='Quantum, Schrödinger Equation', name='Erwin Schrodinger', birth_country='Austria'),
#  Philosopher(born=1715, died=1780, subjects_of_study='John Locke, Sensation', name='Etienne Bonnot de Condillac', birth_country='France'),
#  Philosopher(born=1884, died=1978, subjects_of_study='Middle Ages', name='Etienne Gilson', birth_country='France'),
#  Philosopher(born=1792, died=1860, subjects_of_study='Christianity, Hegelianism', name='Ferdinand Christian Baur', birth_country='Germany'),
#  Philosopher(born=1694, died=1746, subjects_of_study='Moral Sense', name='Francis Hutcheson', birth_country='Ireland'),
#  Philosopher(born=1548, died=1617, subjects_of_study='Church And State, Theocracy', name='Francisco Suarez', birth_country='Spain'),
#  Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands'),
#  Philosopher(born=1838, died=1917, subjects_of_study='Intentionality, Intentionalism', name='Franz Brentano', birth_country='Germany'),
#  Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'),
#  Philosopher(born=1866, died=1957, subjects_of_study='Theism, Argument From Design', name='Frederick Robert Tennant', birth_country='England'),
#  Philosopher(born=1844, died=1900, subjects_of_study='Philosophy Of Art', name='Friedrich Nietzsche', birth_country='Germany'),
#  Philosopher(born=1768, died=1834, subjects_of_study='Protestantism', name='Friedrich Schleiermacher', birth_country='Poland'),
#  Philosopher(born=1807, died=1887, subjects_of_study='Literature, Realism', name='Friedrich Theodor von Vischer', birth_country='Germany'),
#  Philosopher(born=1775, died=1854, subjects_of_study='Ego, Consciousness, Free Will, Absolute', name='Friedrich Wilhelm Joseph von Schelling', birth_country='Germany'),
#  Philosopher(born=1849, died=1923, subjects_of_study='Language, Epistemology', name='Fritz Mauthner', birth_country='Bohemia'),
#  Philosopher(born=1866, died=1942, subjects_of_study='Buddhism, Indian Philosophy, Logic', name='Fyodor Ippolitovich Shcherbatskoy', birth_country='Poland'),
#  Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer'),
#  Philosopher(born=1862, died=1906, subjects_of_study='Theism', name='Gaston Frommel', birth_country='Switzerland'),
#  Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'),
#  Philosopher(born=1405, died=1473, subjects_of_study='Aristotelianism, Neoplatonism', name='Gennadios II Scholarios', birth_country='Turkey'),
#  Philosopher(born=1693, died=1750, subjects_of_study='Gottfried Wilhelm Leibniz, Christian, Baron Von Wolff, Possibility, Monad', name='Georg Bernhard Bilfinger', birth_country='Germany'),
#  Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark'),
#  Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany'),
#  Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'),
#  Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland'),
#  Philosopher(born=1355, died=1452, subjects_of_study='Aristotelianism, Neoplatonism', name='George Gemistus Plethon', birth_country='Turkey'),
#  Philosopher(born=1918, died=1988, subjects_of_study='Canada, Nationalism', name='George Grant', birth_country='Canada'),
#  Philosopher(born=1817, died=1878, subjects_of_study='Science', name='George Henry Lewes', birth_country='England'),
#  Philosopher(born=1863, died=1931, subjects_of_study='Language, Social Interaction', name='George Herbert Mead', birth_country='Massachusetts'),
#  Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain'),
#  Philosopher(born=1842, died=1921, subjects_of_study='Biological Psychology, Functionalism, Experimental Psychology', name='George Trumbull Ladd', birth_country='Ohio'),
#  Philosopher(born=1861, died=1909, subjects_of_study='Theological Liberalism, Modernism', name='George Tyrrell', birth_country='Ireland'),
#  Philosopher(born=1620, died=1684, subjects_of_study='Animal Magnetism, Matter', name='Geraud de Cordemoy', birth_country='France'),
#  Philosopher(born=1668, died=1744, subjects_of_study='Philosophical Anthropology, Providence, Social Evolution', name='Giambattista Vico', birth_country='Italy'),
#  Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy'),
#  Philosopher(born=1925, died=1995, subjects_of_study='Metaphysics', name='Gilles Deleuze', birth_country='France'),
#  Philosopher(born=1646, died=1716, subjects_of_study='Problem Of Evil, Personalism, Differentiation, Best Of All Possible Worlds, Integration', name='Gottfried Wilhelm Leibniz', birth_country='Germany'),
#  Philosopher(born=1729, died=1781, subjects_of_study='Dramatic Literature', name='Gotthold Ephraim Lessing', birth_country='Germany'),
#  Philosopher(born=1848, died=1925, subjects_of_study='Variable, Quantifier', name='Gottlob Frege', birth_country='Germany'),
#  Philosopher(born=1300, died=1358, subjects_of_study='Grace', name='Gregory of Rimini', birth_country='Italy'),
#  Philosopher(born=1613, died=1682, subjects_of_study='Confucianism', name='Gu Yanwu', birth_country='China'),
#  Philosopher(born=1801, died=1887, subjects_of_study='Perception, Sensation, Weber’S Law', name='Gustav Theodor Fechner', birth_country='Germany'),
#  Philosopher(born=1798, died=1878, subjects_of_study='Ḥikmah', name='Hajji Hadi Sabzevari', birth_country='Iran'),
#  Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany'),
#  Philosopher(born=1891, died=1953, subjects_of_study='Probability Theory, Induction', name='Hans Reichenbach', birth_country='Germany'),
#  Philosopher(born=1900, died=2002, subjects_of_study='Hermeneutics', name='Hans-Georg Gadamer', birth_country='Germany'),
#  Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland'),
#  Philosopher(born=1877, died=1950, subjects_of_study='Christianity', name='Hatano Seiichi', birth_country='Japan'),
#  Philosopher(born=1583, died=1657, subjects_of_study='Shintō, Zhu Xi, Neo-Confucianism', name='Hayashi Razan', birth_country='Japan'),
#  Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China'),
#  Philosopher(born=1088, died=1172, subjects_of_study='Jainism', name='Hemachandra', birth_country='India'),
#  Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France'),
#  Philosopher(born=1863, died=1954, subjects_of_study='Philosophy Of History', name='Henri Berr', birth_country='France'),
#  Philosopher(born=1854, died=1912, subjects_of_study='Relativity, Fuchsian Function, Automorphic Function, N-Body Problem', name='Henri Poincare', birth_country='France'),
#  Philosopher(born=1820, died=1871, subjects_of_study='Philosophy, Sir William Hamilton, 9Th Baronet, Knowledge', name='Henry Longueville Mansel', birth_country='England'),
#  Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'),
#  Philosopher(born=1820, died=1903, subjects_of_study='Evolution, Social Change, Social Structure, Cultural Evolution, Survival Of The Fittest', name='Herbert Spencer', birth_country='England'),
#  Philosopher(born=1842, died=1918, subjects_of_study='Judaism', name='Hermann Cohen', birth_country='Germany'),
#  Philosopher(born=1694, died=1768, subjects_of_study='Jesus', name='Hermann Samuel Reimarus', birth_country='Germany'),
#  Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany'),
#  Philosopher(born=1926, died=2016, subjects_of_study='Realism', name='Hilary Putnam', birth_country='Illinois'),
#  Philosopher(born=1225, died=1295, subjects_of_study='Moses Maimonides, Philosophy', name='Ibn Falaquera', birth_country='Spain'),
#  Philosopher(born=1022, died=1070, subjects_of_study='Neoplatonism', name='Ibn Gabirol', birth_country='Spain'),
#  Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia'),
#  Philosopher(born=1855, died=1944, subjects_of_study='Poetry, Japanese Philosophy', name='Inoue Tetsujiro', birth_country='Japan'),
#  Philosopher(born=1100, died=1169, subjects_of_study='Soul, Via Negativa', name='Isaac of Stella', birth_country='England'),
#  Philosopher(born=1809, died=1884, subjects_of_study='Protestantism, Kantianism', name='Isaak August Dorner', birth_country='Germany'),
#  Philosopher(born=1627, died=1705, subjects_of_study='Kogaku', name='Ito Jinsai', birth_country='Japan'),
#  Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands'),
#  Philosopher(born=1930, died=2004, subjects_of_study='Metaphysics, Deconstruction, Philosophy', name='Jacques Derrida', birth_country='Algeria'),
#  Philosopher(born=1882, died=1973, subjects_of_study='Thomas Aquinas, Saint', name='Jacques Maritain', birth_country='France'),
#  Philosopher(born=1810, died=1848, subjects_of_study='Roman Catholicism', name='Jaime Luciano Balmes', birth_country='Spain'),
#  Philosopher(born=1575, died=1624, subjects_of_study='Mysticism, Alchemy, Paracelsus, Dialectic, Free Will', name='Jakob Bohme', birth_country='Germany'),
#  Philosopher(born=1808, died=1864, subjects_of_study='Agnoiology', name='James Frederick Ferrier', birth_country='Scotland'),
#  Philosopher(born=1904, died=1979, subjects_of_study='Perception, “The Perception Of The Visual World”', name='James J. Gibson', birth_country='Ithaca'),
#  Philosopher(born=1861, died=1934, subjects_of_study='Individual Difference', name='James Mark Baldwin', birth_country='South Carolina'),
#  Philosopher(born=1805, died=1900, subjects_of_study='Unitarianism, Authority, Religion, Conscience', name='James Martineau', birth_country='England'),
#  Philosopher(born=1929, died=2007, subjects_of_study='Simulacrum, Hyperreality', name='Jean Baudrillard', birth_country='France'),
#  Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France'),
#  Philosopher(born=1712, died=1778, subjects_of_study='Cultural Evolution, General Will', name='Jean-Jacques Rousseau', birth_country='Switzerland'),
#  Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'),
#  Philosopher(born=1748, died=1832, subjects_of_study='Utility, Law', name='Jeremy Bentham', birth_country='England'),
#  Philosopher(born=1898, died=1955, subjects_of_study='Sociology, Phenomenology Of Religion, Religion, Comparative Religion', name='Joachim Wach', birth_country='Germany'),
#  Philosopher(born=1762, died=1814, subjects_of_study='Germany, Secondary Education, Elementary Education, Ego, Practical Reason', name='Johann Gottlieb Fichte', birth_country='Germany'),
#  Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace'),
#  Philosopher(born=1290, died=1346, subjects_of_study='Aristotelianism, Latin Averroism', name='John Baconthorpe', birth_country='England'),
#  Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont'),
#  Philosopher(born=1842, died=1901, subjects_of_study='Evolution', name='John Fiske', birth_country='Connecticut'),
#  Philosopher(born=1911, died=1960, subjects_of_study='Linguistics', name='John Langshaw Austin', birth_country='England'),
#  Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England'),
#  Philosopher(born=1852, died=1949, subjects_of_study='Economics, Deduction, Induction, Methodology', name='John Neville Keynes', birth_country='England'),
#  Philosopher(born=1860, died=1936, subjects_of_study='Coal Mining, Safety, Mine Gas, Gas Exchange', name='John Scott Haldane', birth_country='Scotland'),
#  Philosopher(born=810, died=877, subjects_of_study='Neoplatonism', name='John Scotus Erigena', birth_country='Ireland'),
#  Philosopher(born=1806, died=1873, subjects_of_study='Utilitarianism, Induction', name='John Stuart Mill', birth_country='England'),
#  Philosopher(born=1834, died=1923, subjects_of_study='Probability Theory, Venn Diagram, Categorical Proposition, Syllogism', name='John Venn', birth_country='England'),
#  Philosopher(born=1330, died=1384, subjects_of_study='Lollards, Predestination, Transubstantiation', name='John Wycliffe', birth_country='England'),
#  Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France'),
#  Philosopher(born=1120, died=1180, subjects_of_study='Political Philosophy', name='John of Salisbury', birth_country='England'),
#  Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut'),
#  Philosopher(born=1883, died=1955, subjects_of_study='Mass Society', name='Jose Ortega y Gasset', birth_country='Spain'),
#  Philosopher(born=1882, died=1959, subjects_of_study='Monism', name='Jose Vasconcelos', birth_country='Mexico'),
#  Philosopher(born=1692, died=1752, subjects_of_study='Ethics, Revelation, Religion', name='Joseph Butler', birth_country='England'),
#  Philosopher(born=1733, died=1804, subjects_of_study='Electricity, Gas, Atmosphere, Photosynthesis, Oxide', name='Joseph Priestley', birth_country='England'),
#  Philosopher(born=1855, died=1916, subjects_of_study='Truth, Will', name='Josiah Royce', birth_country='California'),
#  Philosopher(born=1887, died=1975, subjects_of_study='Evolution, Taxonomy, Embryo, Behaviour', name='Julian Huxley', birth_country='England'),
#  Philosopher(born=1547, died=1606, subjects_of_study='Stoicism', name='Justus Lipsius', birth_country='Belgium'),
#  Philosopher(born=1883, died=1969, subjects_of_study='Psychopathology', name='Karl Jaspers', birth_country='Germany'),
#  Philosopher(born=1818, died=1883, subjects_of_study='Philosophy Of History, Capitalism, Use Value, Exchange Value', name='Karl Marx', birth_country='Germany'),
#  Philosopher(born=1902, died=1994, subjects_of_study='Scientific Method, Criterion Of Falsifiability, Induction', name='Karl Popper', birth_country='Austria'),
#  Philosopher(born=1619, died=1691, subjects_of_study='Wang Yangming, Neo-Confucianism', name='Kumazawa Banzan', birth_country='Japan'),
#  Philosopher(born=1823, died=1891, subjects_of_study='Algebraic Equation, Algebraic Number, Elliptic Function', name='Leopold Kronecker', birth_country='Poland'),
#  Philosopher(born=1288, died=1344, subjects_of_study='Mathematics, Talmud', name='Levi ben Gershom', birth_country='France'),
#  Philosopher(born=772, died=841, subjects_of_study='Confucianism', name='Li Ao', birth_country='China'),
#  Philosopher(born=1893, died=1988, subjects_of_study='China, Peasantry, Neo-Confucianism', name='Liang Shuming', birth_country='China'),
#  Philosopher(born=1407, died=1457, subjects_of_study='Latin Language, Grammar, Donation Of Constantine', name='Lorenzo Valla', birth_country='Italy'),
#  Philosopher(born=1918, died=1990, subjects_of_study='Marxism, Structuralism', name='Louis Althusser', birth_country='Algeria'),
#  Philosopher(born=1883, died=1951, subjects_of_study='Ontology', name='Louis Lavelle', birth_country='France'),
#  Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France'),
#  Philosopher(born=1139, died=1193, subjects_of_study='Xinxue, Neo-Confucianism', name='Lu Jiuyuan', birth_country='China'),
#  Philosopher(born=1857, died=1939, subjects_of_study='Primitive Culture', name='Lucien Levy-Bruhl', birth_country='France'),
#  Philosopher(born=1872, died=1956, subjects_of_study='Geist', name='Ludwig Klages', birth_country='Germany'),
#  Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria'),
#  Philosopher(born=1238, died=1317, subjects_of_study='Hell, Heaven, Dvaita', name='Madhva', birth_country='India'),
#  Philosopher(born=1718, died=1799, subjects_of_study='Witch Of Agnesi', name='Maria Gaetana Agnesi', birth_country='Italy'),
#  Philosopher(born=1766, died=1824, subjects_of_study='Will', name='Marie-Francois-Pierre Maine de Biran', birth_country='France'),
#  Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France'),
#  Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin'),
#  Philosopher(born=1450, died=1524, subjects_of_study='Ethics', name='Marko Marulic', birth_country='Split'),
#  Philosopher(born=1433, died=1499, subjects_of_study='Plato, Plotinus, Soul', name='Marsilio Ficino', birth_country='Italy'),
#  Philosopher(born=1861, died=1949, subjects_of_study='Dialectic', name='Maurice Blondel', birth_country='France'),
#  Philosopher(born=1908, died=1961, subjects_of_study='Marxism', name='Maurice Merleau-Ponty', birth_country='France'),
#  Philosopher(born=1909, died=1988, subjects_of_study='Mathematics, Ludwig Wittgenstein', name='Max Black', birth_country='Azerbaijan'),
#  Philosopher(born=1874, died=1928, subjects_of_study='Ethics, Value', name='Max Scheler', birth_country='Germany'),
#  Philosopher(born=1806, died=1856, subjects_of_study='Ego', name='Max Stirner', birth_country='Germany'),
#  Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France'),
#  Philosopher(born=1824, died=1903, subjects_of_study='Judaism, Anti-Semitism, Comparative Psychology', name='Moritz Lazarus', birth_country='Germany'),
#  Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York'),
#  Philosopher(born=1135, died=1204, subjects_of_study='Judaism, Medicine, Philosophy Of Religion, Hebraic Law, Thirteen Articles Of Faith', name='Moses Maimonides', birth_country='Spain'),
#  Philosopher(born=1729, died=1786, subjects_of_study='Judaism, Immortality, Soul, Religious Toleration', name='Moses Mendelssohn', birth_country='Germany'),
#  Philosopher(born=1571, died=1640, subjects_of_study='Mysticism, Ishrāqīyah, Philosophy Of Nature', name='Mulla Sadra', birth_country='Iran'),
#  Philosopher(born=1658, died=1734, subjects_of_study='Confucianism, Zhu Xi', name='Muro Kyuso', birth_country='Japan'),
#  Philosopher(born=1618, died=1651, subjects_of_study='Rationalism, Reason', name='Nathanael Culverwel', birth_country='England'),
#  Philosopher(born=1401, died=1464, subjects_of_study='Conciliarism, Papal Primacy', name='Nicholas of Cusa', birth_country='Germany'),
#  Philosopher(born=1822, died=1885, subjects_of_study='Philosophy Of History, Civilization', name='Nikolay Yakovlevich Danilevsky', birth_country='Russia'),
#  Philosopher(born=1870, died=1945, subjects_of_study='Nothingness, Experience', name='Nishida Kitaro', birth_country='Japan'),
#  Philosopher(born=1880, died=1949, subjects_of_study='X-Ray, Measurement, Ionization', name='Norman Robert Campbell', birth_country='England'),
#  Philosopher(born=1862, died=1915, subjects_of_study='Thought', name='Oswald Kulpe', birth_country='Russia'),
#  Philosopher(born=1880, died=1936, subjects_of_study='Culture', name='Oswald Spengler', birth_country='Germany'),
#  Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia'),
#  Philosopher(born=1882, died=1945, subjects_of_study='Logical Positivism', name='Otto Neurath', birth_country='Austria'),
#  Philosopher(born=1857, died=1934, subjects_of_study='Plato, Platonism', name='Paul Shorey', birth_country='Iowa'),
#  Philosopher(born=1886, died=1965, subjects_of_study='Faith, Justification, Theonomy', name='Paul Tillich', birth_country='Germany'),
#  Philosopher(born=1372, died=1429, subjects_of_study='Logic', name='Paul of Venice', birth_country='Udine'),
#  Philosopher(born=1647, died=1706, subjects_of_study='Christianity, Heterodoxy', name='Pierre Bayle', birth_country='France'),
#  Philosopher(born=1592, died=1655, subjects_of_study='Epicurus', name='Pierre Gassendi', birth_country='France'),
#  Philosopher(born=1756, died=1837, subjects_of_study='Étienne Bonnot De Condillac', name='Pierre Laromiguiere', birth_country='France'),
#  Philosopher(born=1797, died=1871, subjects_of_study='Pantheism', name='Pierre Leroux', birth_country='France'),
#  Philosopher(born=1625, died=1695, subjects_of_study='Jansenism', name='Pierre Nicole', birth_country='France'),
#  Philosopher(born=1881, died=1955, subjects_of_study='Evolution, Peking Man, Noösphere', name='Pierre Teilhard de Chardin', birth_country='France'),
#  Philosopher(born=1930, died=1992, subjects_of_study='Psychiatry, Philosophy', name='Pierre-Felix Guattari', birth_country='France'),
#  Philosopher(born=1462, died=1525, subjects_of_study='Immortality', name='Pietro Pomponazzi', birth_country='Mantua'),
#  Philosopher(born=1475, died=1550, subjects_of_study='Navya-Nyaya', name='Raghunatha Shiromani', birth_country='India'),
#  Philosopher(born=1879, died=1950, subjects_of_study='Maya, Vichara, Monism', name='Ramana Maharshi', birth_country='India'),
#  Philosopher(born=1017, died=1137, subjects_of_study='Hinduism, Bhakti, Vishishtadvaita, Vedanta, Vishnu', name='Ramanuja', birth_country='India'),
#  Philosopher(born=1233, died=1316, subjects_of_study='Mysticism, Neoplatonism', name='Ramon Llull', birth_country='Spain'),
#  Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri'),
#  Philosopher(born=1596, died=1650, subjects_of_study='A Priori Knowledge, Mind-Body Dualism, Philosophy, Methodic Doubt, Innate Idea', name='Rene Descartes', birth_country='France'),
#  Philosopher(born=1554, died=1600, subjects_of_study='Church Of England', name='Richard Hooker', birth_country='England'),
#  Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales'),
#  Philosopher(born=1627, died=1691, subjects_of_study='Gas, Pressure, Air, Boyle’S Law, Vacuum', name='Robert Boyle', birth_country='Ireland'),
#  Philosopher(born=1175, died=1253, subjects_of_study='Aristotle', name='Robert Grosseteste', birth_country='England'),
#  Philosopher(born=1220, died=1292, subjects_of_study='Light, Gunpowder, Eyeglasses, Rainbow, Empirical Method', name='Roger Bacon', birth_country='England'),
#  Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany'),
#  Philosopher(born=1891, died=1970, subjects_of_study='Formal Logic, Probability Theory, A Priori Knowledge, Verifiability Principle, Analytic Proposition', name='Rudolf Carnap', birth_country='Germany'),
#  Philosopher(born=1869, died=1937, subjects_of_study='Sacred, Religion, Mysterium Tremendum Et Fascinans, Numinous', name='Rudolf Otto', birth_country='Germany'),
#  Philosopher(born=1754, died=1800, subjects_of_study='Skepticism, Moses Maimonides, Philosophy', name='Salomon Maimon', birth_country='Lithuania'),
#  Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia'),
#  Philosopher(born=1791, died=1870, subjects_of_study='Value', name='Samuel Bailey', birth_country='England'),
#  Philosopher(born=1815, died=1889, subjects_of_study='Judaism, Philosophy Of Religion, Reform Judaism', name='Samuel Hirsch', birth_country='Germany'),
#  Philosopher(born=700, died=750, subjects_of_study='Upanishad, “Brahma-Sutra-Bhashya”', name='Shankara', birth_country='India'),
#  Philosopher(born=1011, died=1077, subjects_of_study='“Yijing”, Numerology, Cyclicism, Neo-Confucianism', name='Shao Yong', birth_country='China'),
#  Philosopher(born=1872, died=1950, subjects_of_study='Yoga, Moksha, Enlightenment', name='Shri Aurobindo', birth_country='India'),
#  Philosopher(born=1902, died=1989, subjects_of_study='Marxism', name='Sidney Hook', birth_country='New York'),
#  Philosopher(born=1644, died=1696, subjects_of_study='Truth', name='Simon Foucher', birth_country='France'),
#  Philosopher(born=1909, died=1943, subjects_of_study='Religion', name='Simone Weil', birth_country='France'),
#  Philosopher(born=1808, died=1889, subjects_of_study='Judaism, Idealism', name='Solomon Formstecher', birth_country='Germany'),
#  Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark'),
#  Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia'),
#  Philosopher(born=1922, died=2009, subjects_of_study='Ethics, Prescriptive Grammar', name='Stephen Edelston Toulmin', birth_country='England'),
#  Philosopher(born=1895, died=1985, subjects_of_study='Semiotics, The Arts, Sign, Symbolism', name='Susanne K. Langer', birth_country='New York'),
#  Philosopher(born=1890, died=1947, subjects_of_study='Buddhism', name='Taixu', birth_country='China'),
#  Philosopher(born=360, died=434, subjects_of_study='Buddhism', name='Tao Sheng', birth_country='China'),
#  Philosopher(born=1832, died=1912, subjects_of_study='Greek Philosophy', name='Theodor Gomperz', birth_country='Czech Republic'),
#  Philosopher(born=1903, died=1969, subjects_of_study='Philosophy Of Art, Music', name='Theodor Wiesengrund Adorno', birth_country='Germany'),
#  Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine'),
#  Philosopher(born=1825, died=1895, subjects_of_study='Evolution, Taxonomy, Agnosticism, Religion, Darwinism', name='Thomas Henry Huxley', birth_country='England'),
#  Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England'),
#  Philosopher(born=1710, died=1796, subjects_of_study='Intuitionism', name='Thomas Reid', birth_country='Scotland'),
#  Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples'),
#  Philosopher(born=1585, died=1640, subjects_of_study='Rationalism, Religion', name='Uriel Acosta', birth_country='Portugal'),
#  Philosopher(born=1479, died=1531, subjects_of_study='Suddhadvaita', name='Vallabha', birth_country='India'),
#  Philosopher(born=1853, died=1900, subjects_of_study='Mysticism', name='Vladimir Sergeyevich Solovyov', birth_country='Russia'),
#  Philosopher(born=1892, died=1940, subjects_of_study='Aesthetics, Literature', name='Walter Benjamin', birth_country='Germany'),
#  Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China'),
#  Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China'),
#  Philosopher(born=1472, died=1529, subjects_of_study='Xinxue, Neo-Confucianism', name='Wang Yangming', birth_country='China'),
#  Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan'),
#  Philosopher(born=1901, died=1976, subjects_of_study='Uncertainty Principle, Complementarity Principle, Matrix Mechanics, Spinor Equation', name='Werner Heisenberg', birth_country='Germany'),
#  Philosopher(born=1912, died=1989, subjects_of_study='Philosophy Of Mind', name='Wilfrid Sellars', birth_country='Michigan'),
#  Philosopher(born=1833, died=1911, subjects_of_study='Social Science, Humanities, Methodology', name='Wilhelm Dilthey', birth_country='Germany'),
#  Philosopher(born=1908, died=2000, subjects_of_study='Formal Logic, Meaning', name='Willard Van Orman Quine', birth_country='Ohio'),
#  Philosopher(born=1756, died=1836, subjects_of_study='Individualism, Cultural Determinism', name='William Godwin', birth_country='England'),
#  Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York'),
#  Philosopher(born=1845, died=1879, subjects_of_study='Tribal Self, Biquaternion', name='William Kingdon Clifford', birth_country='England'),
#  Philosopher(born=1743, died=1805, subjects_of_study='Ethics, Utilitarianism, Argument From Design', name='William Paley', birth_country='England'),
#  Philosopher(born=1860, died=1954, subjects_of_study='Platonism', name='William Ralph Inge', birth_country='England'),
#  Philosopher(born=1794, died=1866, subjects_of_study='Induction', name='William Whewell', birth_country='England'),
#  Philosopher(born=1150, died=1231, subjects_of_study='Theology, Natural Law, Free Will, Liturgy', name='William of Auxerre', birth_country='France'),
#  Philosopher(born=1070, died=1121, subjects_of_study='Universal', name='William of Champeaux', birth_country='France'),
#  Philosopher(born=1285, died=1349, subjects_of_study='Roman Catholicism, Occam’S Razor, Heterodoxy', name='William of Ockham', birth_country='England'),
#  Philosopher(born=1885, died=1968, subjects_of_study='Ren', name='Xiong Shili', birth_country='China'),
#  Philosopher(born=1635, died=1704, subjects_of_study='Confucianism', name='Yan Yuan', birth_country='China'),
#  Philosopher(born=1020, died=1077, subjects_of_study='Ren, Qi', name='Zhang Zai', birth_country='China'),
#  Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China'),
#  Philosopher(born=1130, died=1200, subjects_of_study='Qi, Li', name='Zhu Xi', birth_country='China'),
#  Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan'),
#  Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]

# %%
philosophers[0]
# Out:
# Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine')

# %% [markdown]
# This definitely worked, but it is not what we need for our purposes because lists are mutable in Python

# %%
philosophers[0] = Philosopher(born=0, died=50, subjects_of_study="Nothing", name="Jim", birth_country="Unknown")
philosophers[0]
# Out:
# Philosopher(born=0, died=50, subjects_of_study='Nothing', name='Jim', birth_country='Unknown')

# %% [markdown]
# Instead, we should use tuples:

# %%
philosophers = tuple(Philosopher(*row) for row in new_df.itertuples(index=False, name=None))
philosophers[0] = Philosopher(born=0, died=50, subjects_of_study="Nothing", name="Jim", birth_country="Unknown")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 2
#       1 philosophers = tuple(Philosopher(*row) for row in new_df.itertuples(index=False, name=None))
# ----> 2 philosophers[0] = Philosopher(born=0, died=50, subjects_of_study="Nothing", name="Jim", birth_country="Unknown")
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Functional Primatives
#
# filter, map, and reduce

# %% [markdown]
# ## filter()

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function or None, iterable) --> filter object
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# What the hell does that mean?

# %%
filter(lambda x: x.subjects_of_study.contains("Existentialism"), philosophers)

# %%
fs = filter(lambda x: "Existentialism" in x.subjects_of_study, philosophers)

# %%
while True:
    try:
        print(next(fs))
    except:
        break
# Out:
# Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany')
# Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France')
# Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin')
# Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany')
# Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan')

# %%
next(fs)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 next(fs)
#
# StopIteration:

# %%
fs = filter(lambda x: "Existentialism" in x.subjects_of_study, philosophers)
tuple(fs)
# Out:
# (Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'),
#  Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'),
#  Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin'),
#  Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany'),
#  Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan'))

# %% [markdown]
# Why do it like this? Why not do a for loop?
#
# filter() allows for chaining of function calls which is more declarative

# %%
def existential_filter(x):
    return "Existentialism" in x.subjects_of_study

print(tuple(filter(existential_filter, philosophers)))

# This is not necessarily how Python was designed to be used, but is a useful paradigm to expand how you think about
# writing your code
# Out:
# (Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'), Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'), Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin'), Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany'), Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan'))

# %% [markdown]
# Pythonic replacement for filtering

# %%
tuple(x for x in philosophers if "Existentialism" in x.subjects_of_study)
# Out:
# (Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'),
#  Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'),
#  Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin'),
#  Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany'),
#  Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan'))

# %% [markdown]
# ## map()

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
names_and_ages = tuple(map(lambda x: {"name": x.name, "age": x.died - x.born}, philosophers))
names_and_ages
# Out:
# ({'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53})

# %%
# Pythonic version of above code

[{"name": x.name, "age": x.died - x.born} for x in philosophers]
# Out:
# [{'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53}]

# %%
# Pythonic version of above code in an immutable data structure (but dict still mutable, would need namedtuple
# for true immutability)

tuple({"name": x.name, "age": x.died - x.born} for x in philosophers)
# Out:
# ({'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53})

# %% [markdown]
# ## reduce()
#
# reduce has to be imported in Python3

# %%
from functools import reduce

help(reduce)
# Out:
# Help on built-in function reduce in module _functools:
#
# reduce(...)
#     reduce(function, iterable[, initial]) -> value
#
#     Apply a function of two arguments cumulatively to the items of a sequence
#     or iterable, from left to right, so as to reduce the iterable to a single
#     value.  For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
#     ((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
#     of the iterable in the calculation, and serves as a default when the
#     iterable is empty.

# %%
total_age = reduce(
    lambda acc, val: acc + val["age"],
    names_and_ages,
    0
)

# %%
total_age
# Out:
# 19529

# %%
sum(x["age"] for x in names_and_ages)
# Out:
# 19529

# %% [markdown]
# Why reduce? Because it goes deep and can be incredibly powerful

# %%
def country_reducer(acc, philosopher):
    acc[philosopher.birth_country].append(philosopher)
    return acc

all_countries_map = {k: [] for k in all_countries}

philosopher_by_country = reduce(
    country_reducer,
    philosophers,
    all_countries_map
)

for country, person in philosopher_by_country.items():
    print(f"{country}: \n\n{person}\n")
# Out:
# Portugal:
#
# [Philosopher(born=1585, died=1640, subjects_of_study='Rationalism, Religion', name='Uriel Acosta', birth_country='Portugal')]
#
# Czechoslovakia:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Consciousness, Eidetic Reduction, Phenomenological Reduction', name='Edmund Husserl', birth_country='Czechoslovakia'), Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia')]
#
# Turkey:
#
# [Philosopher(born=1403, died=1472, subjects_of_study='Greek Literature, Platonism', name='Bessarion', birth_country='Turkey'), Philosopher(born=1405, died=1473, subjects_of_study='Aristotelianism, Neoplatonism', name='Gennadios II Scholarios', birth_country='Turkey'), Philosopher(born=1355, died=1452, subjects_of_study='Aristotelianism, Neoplatonism', name='George Gemistus Plethon', birth_country='Turkey')]
#
# Belgium:
#
# [Philosopher(born=1547, died=1606, subjects_of_study='Stoicism', name='Justus Lipsius', birth_country='Belgium')]
#
# Canada:
#
# [Philosopher(born=1918, died=1988, subjects_of_study='Canada, Nationalism', name='George Grant', birth_country='Canada')]
#
# Algeria:
#
# [Philosopher(born=1930, died=2004, subjects_of_study='Metaphysics, Deconstruction, Philosophy', name='Jacques Derrida', birth_country='Algeria'), Philosopher(born=1918, died=1990, subjects_of_study='Marxism, Structuralism', name='Louis Althusser', birth_country='Algeria')]
#
# Netherlands:
#
# [Philosopher(born=1632, died=1677, subjects_of_study='Pantheism, Mind-Body Dualism', name='Benedict de Spinoza', birth_country='Netherlands'), Philosopher(born=1670, died=1733, subjects_of_study='Virtue', name='Bernard de Mandeville', birth_country='Netherlands'), Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands'), Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands')]
#
# Wales:
#
# [Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales'), Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales')]
#
# Ithaca:
#
# [Philosopher(born=1904, died=1979, subjects_of_study='Perception, “The Perception Of The Visual World”', name='James J. Gibson', birth_country='Ithaca')]
#
# England:
#
# [Philosopher(born=1861, died=1947, subjects_of_study='Education, Mathematics, Philosophy Of Science, Formal Logic, Materialism', name='Alfred North Whitehead', birth_country='England'), Philosopher(born=1923, died=2010, subjects_of_study='Atheism, Philosophy Of Religion, Theology', name='Antony Flew', birth_country='England'), Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England'), Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1705, died=1757, subjects_of_study='Associationism', name='David Hartley', birth_country='England'), Philosopher(born=1866, died=1957, subjects_of_study='Theism, Argument From Design', name='Frederick Robert Tennant', birth_country='England'), Philosopher(born=1817, died=1878, subjects_of_study='Science', name='George Henry Lewes', birth_country='England'), Philosopher(born=1820, died=1871, subjects_of_study='Philosophy, Sir William Hamilton, 9Th Baronet, Knowledge', name='Henry Longueville Mansel', birth_country='England'), Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'), Philosopher(born=1820, died=1903, subjects_of_study='Evolution, Social Change, Social Structure, Cultural Evolution, Survival Of The Fittest', name='Herbert Spencer', birth_country='England'), Philosopher(born=1100, died=1169, subjects_of_study='Soul, Via Negativa', name='Isaac of Stella', birth_country='England'), Philosopher(born=1805, died=1900, subjects_of_study='Unitarianism, Authority, Religion, Conscience', name='James Martineau', birth_country='England'), Philosopher(born=1748, died=1832, subjects_of_study='Utility, Law', name='Jeremy Bentham', birth_country='England'), Philosopher(born=1290, died=1346, subjects_of_study='Aristotelianism, Latin Averroism', name='John Baconthorpe', birth_country='England'), Philosopher(born=1911, died=1960, subjects_of_study='Linguistics', name='John Langshaw Austin', birth_country='England'), Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England'), Philosopher(born=1852, died=1949, subjects_of_study='Economics, Deduction, Induction, Methodology', name='John Neville Keynes', birth_country='England'), Philosopher(born=1806, died=1873, subjects_of_study='Utilitarianism, Induction', name='John Stuart Mill', birth_country='England'), Philosopher(born=1834, died=1923, subjects_of_study='Probability Theory, Venn Diagram, Categorical Proposition, Syllogism', name='John Venn', birth_country='England'), Philosopher(born=1330, died=1384, subjects_of_study='Lollards, Predestination, Transubstantiation', name='John Wycliffe', birth_country='England'), Philosopher(born=1120, died=1180, subjects_of_study='Political Philosophy', name='John of Salisbury', birth_country='England'), Philosopher(born=1692, died=1752, subjects_of_study='Ethics, Revelation, Religion', name='Joseph Butler', birth_country='England'), Philosopher(born=1733, died=1804, subjects_of_study='Electricity, Gas, Atmosphere, Photosynthesis, Oxide', name='Joseph Priestley', birth_country='England'), Philosopher(born=1887, died=1975, subjects_of_study='Evolution, Taxonomy, Embryo, Behaviour', name='Julian Huxley', birth_country='England'), Philosopher(born=1618, died=1651, subjects_of_study='Rationalism, Reason', name='Nathanael Culverwel', birth_country='England'), Philosopher(born=1880, died=1949, subjects_of_study='X-Ray, Measurement, Ionization', name='Norman Robert Campbell', birth_country='England'), Philosopher(born=1554, died=1600, subjects_of_study='Church Of England', name='Richard Hooker', birth_country='England'), Philosopher(born=1175, died ...
#
# Mexico:
#
# [Philosopher(born=1882, died=1959, subjects_of_study='Monism', name='Jose Vasconcelos', birth_country='Mexico')]
#
# Split:
#
# [Philosopher(born=1450, died=1524, subjects_of_study='Ethics', name='Marko Marulic', birth_country='Split')]
#
# New York:
#
# [Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York'), Philosopher(born=1902, died=1989, subjects_of_study='Marxism', name='Sidney Hook', birth_country='New York'), Philosopher(born=1895, died=1985, subjects_of_study='Semiotics, The Arts, Sign, Symbolism', name='Susanne K. Langer', birth_country='New York'), Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York')]
#
# Speyer:
#
# [Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer')]
#
# Australia:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia')]
#
# Scotland:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland'), Philosopher(born=1711, died=1776, subjects_of_study='England, Miracle, Idea, Neutral Monism, Causation', name='David Hume', birth_country='Scotland'), Philosopher(born=1877, died=1971, subjects_of_study='Aristotelianism', name='David Ross', birth_country='Scotland'), Philosopher(born=1835, died=1908, subjects_of_study='Immanuel Kant, Theology', name='Edward Caird', birth_country='Scotland'), Philosopher(born=1808, died=1864, subjects_of_study='Agnoiology', name='James Frederick Ferrier', birth_country='Scotland'), Philosopher(born=1860, died=1936, subjects_of_study='Coal Mining, Safety, Mine Gas, Gas Exchange', name='John Scott Haldane', birth_country='Scotland'), Philosopher(born=1710, died=1796, subjects_of_study='Intuitionism', name='Thomas Reid', birth_country='Scotland')]
#
# Mantua:
#
# [Philosopher(born=1462, died=1525, subjects_of_study='Immortality', name='Pietro Pomponazzi', birth_country='Mantua')]
#
# South Carolina:
#
# [Philosopher(born=1861, died=1934, subjects_of_study='Individual Difference', name='James Mark Baldwin', birth_country='South Carolina')]
#
# Russia:
#
# [Philosopher(born=1822, died=1885, subjects_of_study='Philosophy Of History, Civilization', name='Nikolay Yakovlevich Danilevsky', birth_country='Russia'), Philosopher(born=1862, died=1915, subjects_of_study='Thought', name='Oswald Kulpe', birth_country='Russia'), Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia'), Philosopher(born=1853, died=1900, subjects_of_study='Mysticism', name='Vladimir Sergeyevich Solovyov', birth_country='Russia')]
#
# Spain:
#
# [Philosopher(born=1126, died=1198, subjects_of_study='Islam, Platonism, Aristotelianism, Greek Philosophy', name='Averroes', birth_country='Spain'), Philosopher(born=1528, died=1580, subjects_of_study='Casuistry, Probabilism', name='Bartolome de Medina', birth_country='Spain'), Philosopher(born=1548, died=1617, subjects_of_study='Church And State, Theocracy', name='Francisco Suarez', birth_country='Spain'), Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain'), Philosopher(born=1225, died=1295, subjects_of_study='Moses Maimonides, Philosophy', name='Ibn Falaquera', birth_country='Spain'), Philosopher(born=1022, died=1070, subjects_of_study='Neoplatonism', name='Ibn Gabirol', birth_country='Spain'), Philosopher(born=1810, died=1848, subjects_of_study='Roman Catholicism', name='Jaime Luciano Balmes', birth_country='Spain'), Philosopher(born=1883, died=1955, subjects_of_study='Mass Society', name='Jose Ortega y Gasset', birth_country='Spain'), Philosopher(born=1135, died=1204, subjects_of_study='Judaism, Medicine, Philosophy Of Religion, Hebraic Law, Thirteen Articles Of Faith', name='Moses Maimonides', birth_country='Spain'), Philosopher(born=1233, died=1316, subjects_of_study='Mysticism, Neoplatonism', name='Ramon Llull', birth_country='Spain')]
#
# France:
#
# [Philosopher(born=1857, died=1940, subjects_of_study='Philosophy Of Religion, Modernism', name='Alfred Firmin Loisy', birth_country='France'), Philosopher(born=1798, died=1857, subjects_of_study='Sociology, Social Evolution', name='Auguste Comte', birth_country='France'), Philosopher(born=1623, died=1662, subjects_of_study='Probability, Conic Section, Pascal’S Triangle, Cycloid, Pascal’S Principle', name='Blaise Pascal', birth_country='France'), Philosopher(born=1715, died=1771, subjects_of_study='Education', name='Claude-Adrien Helvetius', birth_country='France'), Philosopher(born=1713, died=1784, subjects_of_study='Dramatic Literature', name='Denis Diderot', birth_country='France'), Philosopher(born=1823, died=1892, subjects_of_study='Judaism, Jesus, Rationalism, Religion, Early Church', name='Ernest Renan', birth_country='France'), Philosopher(born=1715, died=1780, subjects_of_study='John Locke, Sensation', name='Etienne Bonnot de Condillac', birth_country='France'), Philosopher(born=1884, died=1978, subjects_of_study='Middle Ages', name='Etienne Gilson', birth_country='France'), Philosopher(born=1620, died=1684, subjects_of_study='Animal Magnetism, Matter', name='Geraud de Cordemoy', birth_country='France'), Philosopher(born=1925, died=1995, subjects_of_study='Metaphysics', name='Gilles Deleuze', birth_country='France'), Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France'), Philosopher(born=1863, died=1954, subjects_of_study='Philosophy Of History', name='Henri Berr', birth_country='France'), Philosopher(born=1854, died=1912, subjects_of_study='Relativity, Fuchsian Function, Automorphic Function, N-Body Problem', name='Henri Poincare', birth_country='France'), Philosopher(born=1882, died=1973, subjects_of_study='Thomas Aquinas, Saint', name='Jacques Maritain', birth_country='France'), Philosopher(born=1929, died=2007, subjects_of_study='Simulacrum, Hyperreality', name='Jean Baudrillard', birth_country='France'), Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France'), Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'), Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France'), Philosopher(born=1288, died=1344, subjects_of_study='Mathematics, Talmud', name='Levi ben Gershom', birth_country='France'), Philosopher(born=1883, died=1951, subjects_of_study='Ontology', name='Louis Lavelle', birth_country='France'), Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France'), Philosopher(born=1857, died=1939, subjects_of_study='Primitive Culture', name='Lucien Levy-Bruhl', birth_country='France'), Philosopher(born=1766, died=1824, subjects_of_study='Will', name='Marie-Francois-Pierre Maine de Biran', birth_country='France'), Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France'), Philosopher(born=1861, died=1949, subjects_of_study='Dialectic', name='Maurice Blondel', birth_country='France'), Philosopher(born=1908, died=1961, subjects_of_study='Marxism', name='Maurice Merleau-Ponty', birth_country='France'), Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France'), Philosopher(born=1647, died=1706, subjects_of_study='Christianity, Heterodoxy', name='Pierre Bayle', birth_country='France'), Philosopher(born=1592, died=1655, subjects_of_study='Epicurus', name='Pierre Gassendi', birth_country='France'), Philosopher(born=1756, died=1837, s ...
#
# India:
#
# [Philosopher(born=80, died=150, subjects_of_study='Mahayana', name='Ashvaghosha', birth_country='India'), Philosopher(born=570, died=651, subjects_of_study='Philosophy Of Language, Shabdadvaita', name='Bhartrihari', birth_country='India'), Philosopher(born=1088, died=1172, subjects_of_study='Jainism', name='Hemachandra', birth_country='India'), Philosopher(born=1238, died=1317, subjects_of_study='Hell, Heaven, Dvaita', name='Madhva', birth_country='India'), Philosopher(born=1475, died=1550, subjects_of_study='Navya-Nyaya', name='Raghunatha Shiromani', birth_country='India'), Philosopher(born=1879, died=1950, subjects_of_study='Maya, Vichara, Monism', name='Ramana Maharshi', birth_country='India'), Philosopher(born=1017, died=1137, subjects_of_study='Hinduism, Bhakti, Vishishtadvaita, Vedanta, Vishnu', name='Ramanuja', birth_country='India'), Philosopher(born=700, died=750, subjects_of_study='Upanishad, “Brahma-Sutra-Bhashya”', name='Shankara', birth_country='India'), Philosopher(born=1872, died=1950, subjects_of_study='Yoga, Moksha, Enlightenment', name='Shri Aurobindo', birth_country='India'), Philosopher(born=1479, died=1531, subjects_of_study='Suddhadvaita', name='Vallabha', birth_country='India')]
#
# Vermont:
#
# [Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont')]
#
# Ireland:
#
# [Philosopher(born=1694, died=1746, subjects_of_study='Moral Sense', name='Francis Hutcheson', birth_country='Ireland'), Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland'), Philosopher(born=1861, died=1909, subjects_of_study='Theological Liberalism, Modernism', name='George Tyrrell', birth_country='Ireland'), Philosopher(born=810, died=877, subjects_of_study='Neoplatonism', name='John Scotus Erigena', birth_country='Ireland'), Philosopher(born=1627, died=1691, subjects_of_study='Gas, Pressure, Air, Boyle’S Law, Vacuum', name='Robert Boyle', birth_country='Ireland')]
#
# Turkistan:
#
# [Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan')]
#
# Michigan:
#
# [Philosopher(born=1912, died=1989, subjects_of_study='Philosophy Of Mind', name='Wilfrid Sellars', birth_country='Michigan')]
#
# California:
#
# [Philosopher(born=1855, died=1916, subjects_of_study='Truth, Will', name='Josiah Royce', birth_country='California')]
#
# Illinois:
#
# [Philosopher(born=1926, died=2016, subjects_of_study='Realism', name='Hilary Putnam', birth_country='Illinois')]
#
# Poland:
#
# [Philosopher(born=1907, died=1972, subjects_of_study='Judaism, Philosophy Of Religion', name='Abraham Joshua Heschel', birth_country='Poland'), Philosopher(born=1879, died=1950, subjects_of_study='Semantics, General Semantics', name='Alfred Korzybski', birth_country='Poland'), Philosopher(born=1788, died=1860, subjects_of_study='Philosophy Of Art, Panpsychism', name='Arthur Schopenhauer', birth_country='Poland'), Philosopher(born=1891, died=1942, subjects_of_study='Phenomenology, Thomism', name='Edith Stein', birth_country='Poland'), Philosopher(born=1768, died=1834, subjects_of_study='Protestantism', name='Friedrich Schleiermacher', birth_country='Poland'), Philosopher(born=1866, died=1942, subjects_of_study='Buddhism, Indian Philosophy, Logic', name='Fyodor Ippolitovich Shcherbatskoy', birth_country='Poland'), Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland'), Philosopher(born=1823, died=1891, subjects_of_study='Algebraic Equation, Algebraic Number, Elliptic Function', name='Leopold Kronecker', birth_country='Poland')]
#
# Ohio:
#
# [Philosopher(born=1842, died=1921, subjects_of_study='Biological Psychology, Functionalism, Experimental Psychology', name='George Trumbull Ladd', birth_country='Ohio'), Philosopher(born=1908, died=2000, subjects_of_study='Formal Logic, Meaning', name='Willard Van Orman Quine', birth_country='Ohio')]
#
# Azerbaijan:
#
# [Philosopher(born=1909, died=1988, subjects_of_study='Mathematics, Ludwig Wittgenstein', name='Max Black', birth_country='Azerbaijan')]
#
# Iowa:
#
# [Philosopher(born=1857, died=1934, subjects_of_study='Plato, Platonism', name='Paul Shorey', birth_country='Iowa')]
#
# Massachusetts:
#
# [Philosopher(born=1839, died=1914, subjects_of_study='Category, Induction, Abduction', name='Charles Sanders Peirce', birth_country='Massachusetts'), Philosopher(born=1863, died=1931, subjects_of_study='Language, Social Interaction', name='George Herbert Mead', birth_country='Massachusetts')]
#
# Bohemia:
#
# [Philosopher(born=1849, died=1923, subjects_of_study='Language, Epistemology', name='Fritz Mauthner', birth_country='Bohemia')]
#
# Alsace:
#
# [Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace')]
#
# Switzerland:
#
# [Philosopher(born=1862, died=1906, subjects_of_study='Theism', name='Gaston Frommel', birth_country='Switzerland'), Philosopher(born=1712, died=1778, subjects_of_study='Cultural Evolution, General Will', name='Jean-Jacques Rousseau', birth_country='Switzerland')]
#
# Missouri:
#
# [Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri')]
#
# Czech Republic:
#
# [Philosopher(born=1883, died=1949, subjects_of_study='Faith', name='Erich Frank', birth_country='Czech Republic'), Philosopher(born=1832, died=1912, subjects_of_study='Greek Philosophy', name='Theodor Gomperz', birth_country='Czech Republic')]
#
# Indiana:
#
# [Philosopher(born=1930, died=1992, subjects_of_study='Higher Education', name='Allan Bloom', birth_country='Indiana')]
#
# Prussia:
#
# [Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia'), Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]
#
# Wisconsin:
#
# [Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin')]
#
# Ukraine:
#
# [Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine'), Philosopher(born=1853, died=1920, subjects_of_study='Objectivism, Intentionality', name='Alexius Meinong', birth_country='Ukraine'), Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine')]
#
# Germany:
#
# [Philosopher(born=1316, died=1390, subjects_of_study='Gravity', name='Albert of Saxony', birth_country='Germany'), Philosopher(born=1714, died=1762, subjects_of_study='Aesthetics, Gottfried Wilhelm Leibniz, Feeling, Christian, Baron Von Wolff', name='Alexander Gottlieb Baumgarten', birth_country='Germany'), Philosopher(born=1873, died=1962, subjects_of_study='Great Chain Of Being', name='Arthur O. Lovejoy', birth_country='Germany'), Philosopher(born=1905, died=1997, subjects_of_study='Philosophy Of Science, Scientific Theory, Covering-Law Model', name='Carl Gustav Hempel', birth_country='Germany'), Philosopher(born=1808, died=1874, subjects_of_study='Rationalism, Religion, Dialectic', name='David Friedrich Strauss', birth_country='Germany'), Philosopher(born=1842, died=1906, subjects_of_study='Rationalism, Irrationalism, Unconscious', name='Eduard von Hartmann', birth_country='Germany'), Philosopher(born=1900, died=1980, subjects_of_study='Self-Image', name='Erich Fromm', birth_country='Germany'), Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany'), Philosopher(born=1792, died=1860, subjects_of_study='Christianity, Hegelianism', name='Ferdinand Christian Baur', birth_country='Germany'), Philosopher(born=1838, died=1917, subjects_of_study='Intentionality, Intentionalism', name='Franz Brentano', birth_country='Germany'), Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'), Philosopher(born=1844, died=1900, subjects_of_study='Philosophy Of Art', name='Friedrich Nietzsche', birth_country='Germany'), Philosopher(born=1807, died=1887, subjects_of_study='Literature, Realism', name='Friedrich Theodor von Vischer', birth_country='Germany'), Philosopher(born=1775, died=1854, subjects_of_study='Ego, Consciousness, Free Will, Absolute', name='Friedrich Wilhelm Joseph von Schelling', birth_country='Germany'), Philosopher(born=1693, died=1750, subjects_of_study='Gottfried Wilhelm Leibniz, Christian, Baron Von Wolff, Possibility, Monad', name='Georg Bernhard Bilfinger', birth_country='Germany'), Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany'), Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'), Philosopher(born=1646, died=1716, subjects_of_study='Problem Of Evil, Personalism, Differentiation, Best Of All Possible Worlds, Integration', name='Gottfried Wilhelm Leibniz', birth_country='Germany'), Philosopher(born=1729, died=1781, subjects_of_study='Dramatic Literature', name='Gotthold Ephraim Lessing', birth_country='Germany'), Philosopher(born=1848, died=1925, subjects_of_study='Variable, Quantifier', name='Gottlob Frege', birth_country='Germany'), Philosopher(born=1801, died=1887, subjects_of_study='Perception, Sensation, Weber’S Law', name='Gustav Theodor Fechner', birth_country='Germany'), Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany'), Philosopher(born=1891, died=1953, subjects_of_study='Probability Theory, Induction', name='Hans Reichenbach', birth_country='Germany'), Philosopher(born=1900, died=2002, subjects_of_study='Hermeneutics', name='Hans-Georg Gadamer', birth_country='Germany'), Philosopher(born=1842, died=1918, subjects_of_study='Judaism', name='Hermann Cohen', birth_country='Germany'), Philosopher(born=1694, died=1768, subjects_of_study='Jesus', name='Hermann Samuel Reimarus', birth_country='Germany'), Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany'), Philosopher ...
#
# Denmark:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark'), Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark')]
#
# Finland:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland')]
#
# Iran:
#
# [Philosopher(born=1798, died=1878, subjects_of_study='Ḥikmah', name='Hajji Hadi Sabzevari', birth_country='Iran'), Philosopher(born=1571, died=1640, subjects_of_study='Mysticism, Ishrāqīyah, Philosophy Of Nature', name='Mulla Sadra', birth_country='Iran'), Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]
#
# Kingdom of Naples:
#
# [Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Kingdom of the Two Sicilies:
#
# [Philosopher(born=1843, died=1904, subjects_of_study='Socialism, Historical Materialism', name='Antonio Labriola', birth_country='Kingdom of the Two Sicilies')]
#
# Uzbekistan:
#
# [Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan')]
#
# China:
#
# [Philosopher(born=1032, died=1085, subjects_of_study='Li, Neo-Confucianism', name='Cheng Hao', birth_country='China'), Philosopher(born=1033, died=1107, subjects_of_study='Li, Neo-Confucianism, Lixue', name='Cheng Yi', birth_country='China'), Philosopher(born=1942, died=2017, subjects_of_study='Personal Identity, Triple Theory', name='Derek Parfit', birth_country='China'), Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=1613, died=1682, subjects_of_study='Confucianism', name='Gu Yanwu', birth_country='China'), Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China'), Philosopher(born=772, died=841, subjects_of_study='Confucianism', name='Li Ao', birth_country='China'), Philosopher(born=1893, died=1988, subjects_of_study='China, Peasantry, Neo-Confucianism', name='Liang Shuming', birth_country='China'), Philosopher(born=1139, died=1193, subjects_of_study='Xinxue, Neo-Confucianism', name='Lu Jiuyuan', birth_country='China'), Philosopher(born=1011, died=1077, subjects_of_study='“Yijing”, Numerology, Cyclicism, Neo-Confucianism', name='Shao Yong', birth_country='China'), Philosopher(born=1890, died=1947, subjects_of_study='Buddhism', name='Taixu', birth_country='China'), Philosopher(born=360, died=434, subjects_of_study='Buddhism', name='Tao Sheng', birth_country='China'), Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China'), Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China'), Philosopher(born=1472, died=1529, subjects_of_study='Xinxue, Neo-Confucianism', name='Wang Yangming', birth_country='China'), Philosopher(born=1885, died=1968, subjects_of_study='Ren', name='Xiong Shili', birth_country='China'), Philosopher(born=1635, died=1704, subjects_of_study='Confucianism', name='Yan Yuan', birth_country='China'), Philosopher(born=1020, died=1077, subjects_of_study='Ren, Qi', name='Zhang Zai', birth_country='China'), Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China'), Philosopher(born=1130, died=1200, subjects_of_study='Qi, Li', name='Zhu Xi', birth_country='China')]
#
# Lithuania:
#
# [Philosopher(born=1906, died=1995, subjects_of_study='Judaism', name='Emmanuel Levinas', birth_country='Lithuania'), Philosopher(born=1754, died=1800, subjects_of_study='Skepticism, Moses Maimonides, Philosophy', name='Salomon Maimon', birth_country='Lithuania')]
#
# Austria:
#
# [Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria'), Philosopher(born=1887, died=1961, subjects_of_study='Quantum, Schrödinger Equation', name='Erwin Schrodinger', birth_country='Austria'), Philosopher(born=1902, died=1994, subjects_of_study='Scientific Method, Criterion Of Falsifiability, Induction', name='Karl Popper', birth_country='Austria'), Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria'), Philosopher(born=1882, died=1945, subjects_of_study='Logical Positivism', name='Otto Neurath', birth_country='Austria')]
#
# Japan:
#
# [Philosopher(born=1877, died=1950, subjects_of_study='Christianity', name='Hatano Seiichi', birth_country='Japan'), Philosopher(born=1583, died=1657, subjects_of_study='Shintō, Zhu Xi, Neo-Confucianism', name='Hayashi Razan', birth_country='Japan'), Philosopher(born=1855, died=1944, subjects_of_study='Poetry, Japanese Philosophy', name='Inoue Tetsujiro', birth_country='Japan'), Philosopher(born=1627, died=1705, subjects_of_study='Kogaku', name='Ito Jinsai', birth_country='Japan'), Philosopher(born=1619, died=1691, subjects_of_study='Wang Yangming, Neo-Confucianism', name='Kumazawa Banzan', birth_country='Japan'), Philosopher(born=1658, died=1734, subjects_of_study='Confucianism, Zhu Xi', name='Muro Kyuso', birth_country='Japan'), Philosopher(born=1870, died=1945, subjects_of_study='Nothingness, Experience', name='Nishida Kitaro', birth_country='Japan'), Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan')]
#
# Connecticut:
#
# [Philosopher(born=1842, died=1901, subjects_of_study='Evolution', name='John Fiske', birth_country='Connecticut'), Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut')]
#
# Udine:
#
# [Philosopher(born=1372, died=1429, subjects_of_study='Logic', name='Paul of Venice', birth_country='Udine')]
#
# Italy:
#
# [Philosopher(born=1463, died=1512, subjects_of_study='William Of Ockham', name='Alessandro Achillini', birth_country='Italy'), Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy'), Philosopher(born=1797, died=1855, subjects_of_study='Philosophy Of Religion', name='Antonio Rosmini-Serbati', birth_country='Italy'), Philosopher(born=1878, died=1959, subjects_of_study='Phenomenon', name='Armando Carlini', birth_country='Italy'), Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy'), Philosopher(born=1668, died=1744, subjects_of_study='Philosophical Anthropology, Providence, Social Evolution', name='Giambattista Vico', birth_country='Italy'), Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy'), Philosopher(born=1300, died=1358, subjects_of_study='Grace', name='Gregory of Rimini', birth_country='Italy'), Philosopher(born=1407, died=1457, subjects_of_study='Latin Language, Grammar, Donation Of Constantine', name='Lorenzo Valla', birth_country='Italy'), Philosopher(born=1718, died=1799, subjects_of_study='Witch Of Agnesi', name='Maria Gaetana Agnesi', birth_country='Italy'), Philosopher(born=1433, died=1499, subjects_of_study='Plato, Plotinus, Soul', name='Marsilio Ficino', birth_country='Italy')]

# %% [markdown]
# We can still make this cooler

# %%
philosopher_by_country = reduce(
    country_reducer,
    philosophers,
    collections.defaultdict(list)
)

for country, person in philosopher_by_country.items():
    print(f"{country}: \n\n{person}\n")
# Out:
# Ukraine:
#
# [Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine'), Philosopher(born=1853, died=1920, subjects_of_study='Objectivism, Intentionality', name='Alexius Meinong', birth_country='Ukraine'), Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine')]
#
# Poland:
#
# [Philosopher(born=1907, died=1972, subjects_of_study='Judaism, Philosophy Of Religion', name='Abraham Joshua Heschel', birth_country='Poland'), Philosopher(born=1879, died=1950, subjects_of_study='Semantics, General Semantics', name='Alfred Korzybski', birth_country='Poland'), Philosopher(born=1788, died=1860, subjects_of_study='Philosophy Of Art, Panpsychism', name='Arthur Schopenhauer', birth_country='Poland'), Philosopher(born=1891, died=1942, subjects_of_study='Phenomenology, Thomism', name='Edith Stein', birth_country='Poland'), Philosopher(born=1768, died=1834, subjects_of_study='Protestantism', name='Friedrich Schleiermacher', birth_country='Poland'), Philosopher(born=1866, died=1942, subjects_of_study='Buddhism, Indian Philosophy, Logic', name='Fyodor Ippolitovich Shcherbatskoy', birth_country='Poland'), Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland'), Philosopher(born=1823, died=1891, subjects_of_study='Algebraic Equation, Algebraic Number, Elliptic Function', name='Leopold Kronecker', birth_country='Poland')]
#
# Germany:
#
# [Philosopher(born=1316, died=1390, subjects_of_study='Gravity', name='Albert of Saxony', birth_country='Germany'), Philosopher(born=1714, died=1762, subjects_of_study='Aesthetics, Gottfried Wilhelm Leibniz, Feeling, Christian, Baron Von Wolff', name='Alexander Gottlieb Baumgarten', birth_country='Germany'), Philosopher(born=1873, died=1962, subjects_of_study='Great Chain Of Being', name='Arthur O. Lovejoy', birth_country='Germany'), Philosopher(born=1905, died=1997, subjects_of_study='Philosophy Of Science, Scientific Theory, Covering-Law Model', name='Carl Gustav Hempel', birth_country='Germany'), Philosopher(born=1808, died=1874, subjects_of_study='Rationalism, Religion, Dialectic', name='David Friedrich Strauss', birth_country='Germany'), Philosopher(born=1842, died=1906, subjects_of_study='Rationalism, Irrationalism, Unconscious', name='Eduard von Hartmann', birth_country='Germany'), Philosopher(born=1900, died=1980, subjects_of_study='Self-Image', name='Erich Fromm', birth_country='Germany'), Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany'), Philosopher(born=1792, died=1860, subjects_of_study='Christianity, Hegelianism', name='Ferdinand Christian Baur', birth_country='Germany'), Philosopher(born=1838, died=1917, subjects_of_study='Intentionality, Intentionalism', name='Franz Brentano', birth_country='Germany'), Philosopher(born=1886, died=1929, subjects_of_study='Judaism, Existentialism', name='Franz Rosenzweig', birth_country='Germany'), Philosopher(born=1844, died=1900, subjects_of_study='Philosophy Of Art', name='Friedrich Nietzsche', birth_country='Germany'), Philosopher(born=1807, died=1887, subjects_of_study='Literature, Realism', name='Friedrich Theodor von Vischer', birth_country='Germany'), Philosopher(born=1775, died=1854, subjects_of_study='Ego, Consciousness, Free Will, Absolute', name='Friedrich Wilhelm Joseph von Schelling', birth_country='Germany'), Philosopher(born=1693, died=1750, subjects_of_study='Gottfried Wilhelm Leibniz, Christian, Baron Von Wolff, Possibility, Monad', name='Georg Bernhard Bilfinger', birth_country='Germany'), Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany'), Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'), Philosopher(born=1646, died=1716, subjects_of_study='Problem Of Evil, Personalism, Differentiation, Best Of All Possible Worlds, Integration', name='Gottfried Wilhelm Leibniz', birth_country='Germany'), Philosopher(born=1729, died=1781, subjects_of_study='Dramatic Literature', name='Gotthold Ephraim Lessing', birth_country='Germany'), Philosopher(born=1848, died=1925, subjects_of_study='Variable, Quantifier', name='Gottlob Frege', birth_country='Germany'), Philosopher(born=1801, died=1887, subjects_of_study='Perception, Sensation, Weber’S Law', name='Gustav Theodor Fechner', birth_country='Germany'), Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany'), Philosopher(born=1891, died=1953, subjects_of_study='Probability Theory, Induction', name='Hans Reichenbach', birth_country='Germany'), Philosopher(born=1900, died=2002, subjects_of_study='Hermeneutics', name='Hans-Georg Gadamer', birth_country='Germany'), Philosopher(born=1842, died=1918, subjects_of_study='Judaism', name='Hermann Cohen', birth_country='Germany'), Philosopher(born=1694, died=1768, subjects_of_study='Jesus', name='Hermann Samuel Reimarus', birth_country='Germany'), Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany'), Philosopher ...
#
# Italy:
#
# [Philosopher(born=1463, died=1512, subjects_of_study='William Of Ockham', name='Alessandro Achillini', birth_country='Italy'), Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy'), Philosopher(born=1797, died=1855, subjects_of_study='Philosophy Of Religion', name='Antonio Rosmini-Serbati', birth_country='Italy'), Philosopher(born=1878, died=1959, subjects_of_study='Phenomenon', name='Armando Carlini', birth_country='Italy'), Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy'), Philosopher(born=1668, died=1744, subjects_of_study='Philosophical Anthropology, Providence, Social Evolution', name='Giambattista Vico', birth_country='Italy'), Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy'), Philosopher(born=1300, died=1358, subjects_of_study='Grace', name='Gregory of Rimini', birth_country='Italy'), Philosopher(born=1407, died=1457, subjects_of_study='Latin Language, Grammar, Donation Of Constantine', name='Lorenzo Valla', birth_country='Italy'), Philosopher(born=1718, died=1799, subjects_of_study='Witch Of Agnesi', name='Maria Gaetana Agnesi', birth_country='Italy'), Philosopher(born=1433, died=1499, subjects_of_study='Plato, Plotinus, Soul', name='Marsilio Ficino', birth_country='Italy')]
#
# France:
#
# [Philosopher(born=1857, died=1940, subjects_of_study='Philosophy Of Religion, Modernism', name='Alfred Firmin Loisy', birth_country='France'), Philosopher(born=1798, died=1857, subjects_of_study='Sociology, Social Evolution', name='Auguste Comte', birth_country='France'), Philosopher(born=1623, died=1662, subjects_of_study='Probability, Conic Section, Pascal’S Triangle, Cycloid, Pascal’S Principle', name='Blaise Pascal', birth_country='France'), Philosopher(born=1715, died=1771, subjects_of_study='Education', name='Claude-Adrien Helvetius', birth_country='France'), Philosopher(born=1713, died=1784, subjects_of_study='Dramatic Literature', name='Denis Diderot', birth_country='France'), Philosopher(born=1823, died=1892, subjects_of_study='Judaism, Jesus, Rationalism, Religion, Early Church', name='Ernest Renan', birth_country='France'), Philosopher(born=1715, died=1780, subjects_of_study='John Locke, Sensation', name='Etienne Bonnot de Condillac', birth_country='France'), Philosopher(born=1884, died=1978, subjects_of_study='Middle Ages', name='Etienne Gilson', birth_country='France'), Philosopher(born=1620, died=1684, subjects_of_study='Animal Magnetism, Matter', name='Geraud de Cordemoy', birth_country='France'), Philosopher(born=1925, died=1995, subjects_of_study='Metaphysics', name='Gilles Deleuze', birth_country='France'), Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France'), Philosopher(born=1863, died=1954, subjects_of_study='Philosophy Of History', name='Henri Berr', birth_country='France'), Philosopher(born=1854, died=1912, subjects_of_study='Relativity, Fuchsian Function, Automorphic Function, N-Body Problem', name='Henri Poincare', birth_country='France'), Philosopher(born=1882, died=1973, subjects_of_study='Thomas Aquinas, Saint', name='Jacques Maritain', birth_country='France'), Philosopher(born=1929, died=2007, subjects_of_study='Simulacrum, Hyperreality', name='Jean Baudrillard', birth_country='France'), Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France'), Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'), Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France'), Philosopher(born=1288, died=1344, subjects_of_study='Mathematics, Talmud', name='Levi ben Gershom', birth_country='France'), Philosopher(born=1883, died=1951, subjects_of_study='Ontology', name='Louis Lavelle', birth_country='France'), Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France'), Philosopher(born=1857, died=1939, subjects_of_study='Primitive Culture', name='Lucien Levy-Bruhl', birth_country='France'), Philosopher(born=1766, died=1824, subjects_of_study='Will', name='Marie-Francois-Pierre Maine de Biran', birth_country='France'), Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France'), Philosopher(born=1861, died=1949, subjects_of_study='Dialectic', name='Maurice Blondel', birth_country='France'), Philosopher(born=1908, died=1961, subjects_of_study='Marxism', name='Maurice Merleau-Ponty', birth_country='France'), Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France'), Philosopher(born=1647, died=1706, subjects_of_study='Christianity, Heterodoxy', name='Pierre Bayle', birth_country='France'), Philosopher(born=1592, died=1655, subjects_of_study='Epicurus', name='Pierre Gassendi', birth_country='France'), Philosopher(born=1756, died=1837, s ...
#
# England:
#
# [Philosopher(born=1861, died=1947, subjects_of_study='Education, Mathematics, Philosophy Of Science, Formal Logic, Materialism', name='Alfred North Whitehead', birth_country='England'), Philosopher(born=1923, died=2010, subjects_of_study='Atheism, Philosophy Of Religion, Theology', name='Antony Flew', birth_country='England'), Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England'), Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1705, died=1757, subjects_of_study='Associationism', name='David Hartley', birth_country='England'), Philosopher(born=1866, died=1957, subjects_of_study='Theism, Argument From Design', name='Frederick Robert Tennant', birth_country='England'), Philosopher(born=1817, died=1878, subjects_of_study='Science', name='George Henry Lewes', birth_country='England'), Philosopher(born=1820, died=1871, subjects_of_study='Philosophy, Sir William Hamilton, 9Th Baronet, Knowledge', name='Henry Longueville Mansel', birth_country='England'), Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'), Philosopher(born=1820, died=1903, subjects_of_study='Evolution, Social Change, Social Structure, Cultural Evolution, Survival Of The Fittest', name='Herbert Spencer', birth_country='England'), Philosopher(born=1100, died=1169, subjects_of_study='Soul, Via Negativa', name='Isaac of Stella', birth_country='England'), Philosopher(born=1805, died=1900, subjects_of_study='Unitarianism, Authority, Religion, Conscience', name='James Martineau', birth_country='England'), Philosopher(born=1748, died=1832, subjects_of_study='Utility, Law', name='Jeremy Bentham', birth_country='England'), Philosopher(born=1290, died=1346, subjects_of_study='Aristotelianism, Latin Averroism', name='John Baconthorpe', birth_country='England'), Philosopher(born=1911, died=1960, subjects_of_study='Linguistics', name='John Langshaw Austin', birth_country='England'), Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England'), Philosopher(born=1852, died=1949, subjects_of_study='Economics, Deduction, Induction, Methodology', name='John Neville Keynes', birth_country='England'), Philosopher(born=1806, died=1873, subjects_of_study='Utilitarianism, Induction', name='John Stuart Mill', birth_country='England'), Philosopher(born=1834, died=1923, subjects_of_study='Probability Theory, Venn Diagram, Categorical Proposition, Syllogism', name='John Venn', birth_country='England'), Philosopher(born=1330, died=1384, subjects_of_study='Lollards, Predestination, Transubstantiation', name='John Wycliffe', birth_country='England'), Philosopher(born=1120, died=1180, subjects_of_study='Political Philosophy', name='John of Salisbury', birth_country='England'), Philosopher(born=1692, died=1752, subjects_of_study='Ethics, Revelation, Religion', name='Joseph Butler', birth_country='England'), Philosopher(born=1733, died=1804, subjects_of_study='Electricity, Gas, Atmosphere, Photosynthesis, Oxide', name='Joseph Priestley', birth_country='England'), Philosopher(born=1887, died=1975, subjects_of_study='Evolution, Taxonomy, Embryo, Behaviour', name='Julian Huxley', birth_country='England'), Philosopher(born=1618, died=1651, subjects_of_study='Rationalism, Reason', name='Nathanael Culverwel', birth_country='England'), Philosopher(born=1880, died=1949, subjects_of_study='X-Ray, Measurement, Ionization', name='Norman Robert Campbell', birth_country='England'), Philosopher(born=1554, died=1600, subjects_of_study='Church Of England', name='Richard Hooker', birth_country='England'), Philosopher(born=1175, died ...
#
# Indiana:
#
# [Philosopher(born=1930, died=1992, subjects_of_study='Higher Education', name='Allan Bloom', birth_country='Indiana')]
#
# Kingdom of the Two Sicilies:
#
# [Philosopher(born=1843, died=1904, subjects_of_study='Socialism, Historical Materialism', name='Antonio Labriola', birth_country='Kingdom of the Two Sicilies')]
#
# India:
#
# [Philosopher(born=80, died=150, subjects_of_study='Mahayana', name='Ashvaghosha', birth_country='India'), Philosopher(born=570, died=651, subjects_of_study='Philosophy Of Language, Shabdadvaita', name='Bhartrihari', birth_country='India'), Philosopher(born=1088, died=1172, subjects_of_study='Jainism', name='Hemachandra', birth_country='India'), Philosopher(born=1238, died=1317, subjects_of_study='Hell, Heaven, Dvaita', name='Madhva', birth_country='India'), Philosopher(born=1475, died=1550, subjects_of_study='Navya-Nyaya', name='Raghunatha Shiromani', birth_country='India'), Philosopher(born=1879, died=1950, subjects_of_study='Maya, Vichara, Monism', name='Ramana Maharshi', birth_country='India'), Philosopher(born=1017, died=1137, subjects_of_study='Hinduism, Bhakti, Vishishtadvaita, Vedanta, Vishnu', name='Ramanuja', birth_country='India'), Philosopher(born=700, died=750, subjects_of_study='Upanishad, “Brahma-Sutra-Bhashya”', name='Shankara', birth_country='India'), Philosopher(born=1872, died=1950, subjects_of_study='Yoga, Moksha, Enlightenment', name='Shri Aurobindo', birth_country='India'), Philosopher(born=1479, died=1531, subjects_of_study='Suddhadvaita', name='Vallabha', birth_country='India')]
#
# Spain:
#
# [Philosopher(born=1126, died=1198, subjects_of_study='Islam, Platonism, Aristotelianism, Greek Philosophy', name='Averroes', birth_country='Spain'), Philosopher(born=1528, died=1580, subjects_of_study='Casuistry, Probabilism', name='Bartolome de Medina', birth_country='Spain'), Philosopher(born=1548, died=1617, subjects_of_study='Church And State, Theocracy', name='Francisco Suarez', birth_country='Spain'), Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain'), Philosopher(born=1225, died=1295, subjects_of_study='Moses Maimonides, Philosophy', name='Ibn Falaquera', birth_country='Spain'), Philosopher(born=1022, died=1070, subjects_of_study='Neoplatonism', name='Ibn Gabirol', birth_country='Spain'), Philosopher(born=1810, died=1848, subjects_of_study='Roman Catholicism', name='Jaime Luciano Balmes', birth_country='Spain'), Philosopher(born=1883, died=1955, subjects_of_study='Mass Society', name='Jose Ortega y Gasset', birth_country='Spain'), Philosopher(born=1135, died=1204, subjects_of_study='Judaism, Medicine, Philosophy Of Religion, Hebraic Law, Thirteen Articles Of Faith', name='Moses Maimonides', birth_country='Spain'), Philosopher(born=1233, died=1316, subjects_of_study='Mysticism, Neoplatonism', name='Ramon Llull', birth_country='Spain')]
#
# Uzbekistan:
#
# [Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan')]
#
# Netherlands:
#
# [Philosopher(born=1632, died=1677, subjects_of_study='Pantheism, Mind-Body Dualism', name='Benedict de Spinoza', birth_country='Netherlands'), Philosopher(born=1670, died=1733, subjects_of_study='Virtue', name='Bernard de Mandeville', birth_country='Netherlands'), Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands'), Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands')]
#
# Wales:
#
# [Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales'), Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales')]
#
# Turkey:
#
# [Philosopher(born=1403, died=1472, subjects_of_study='Greek Literature, Platonism', name='Bessarion', birth_country='Turkey'), Philosopher(born=1405, died=1473, subjects_of_study='Aristotelianism, Neoplatonism', name='Gennadios II Scholarios', birth_country='Turkey'), Philosopher(born=1355, died=1452, subjects_of_study='Aristotelianism, Neoplatonism', name='George Gemistus Plethon', birth_country='Turkey')]
#
# Scotland:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland'), Philosopher(born=1711, died=1776, subjects_of_study='England, Miracle, Idea, Neutral Monism, Causation', name='David Hume', birth_country='Scotland'), Philosopher(born=1877, died=1971, subjects_of_study='Aristotelianism', name='David Ross', birth_country='Scotland'), Philosopher(born=1835, died=1908, subjects_of_study='Immanuel Kant, Theology', name='Edward Caird', birth_country='Scotland'), Philosopher(born=1808, died=1864, subjects_of_study='Agnoiology', name='James Frederick Ferrier', birth_country='Scotland'), Philosopher(born=1860, died=1936, subjects_of_study='Coal Mining, Safety, Mine Gas, Gas Exchange', name='John Scott Haldane', birth_country='Scotland'), Philosopher(born=1710, died=1796, subjects_of_study='Intuitionism', name='Thomas Reid', birth_country='Scotland')]
#
# Massachusetts:
#
# [Philosopher(born=1839, died=1914, subjects_of_study='Category, Induction, Abduction', name='Charles Sanders Peirce', birth_country='Massachusetts'), Philosopher(born=1863, died=1931, subjects_of_study='Language, Social Interaction', name='George Herbert Mead', birth_country='Massachusetts')]
#
# China:
#
# [Philosopher(born=1032, died=1085, subjects_of_study='Li, Neo-Confucianism', name='Cheng Hao', birth_country='China'), Philosopher(born=1033, died=1107, subjects_of_study='Li, Neo-Confucianism, Lixue', name='Cheng Yi', birth_country='China'), Philosopher(born=1942, died=2017, subjects_of_study='Personal Identity, Triple Theory', name='Derek Parfit', birth_country='China'), Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=1613, died=1682, subjects_of_study='Confucianism', name='Gu Yanwu', birth_country='China'), Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China'), Philosopher(born=772, died=841, subjects_of_study='Confucianism', name='Li Ao', birth_country='China'), Philosopher(born=1893, died=1988, subjects_of_study='China, Peasantry, Neo-Confucianism', name='Liang Shuming', birth_country='China'), Philosopher(born=1139, died=1193, subjects_of_study='Xinxue, Neo-Confucianism', name='Lu Jiuyuan', birth_country='China'), Philosopher(born=1011, died=1077, subjects_of_study='“Yijing”, Numerology, Cyclicism, Neo-Confucianism', name='Shao Yong', birth_country='China'), Philosopher(born=1890, died=1947, subjects_of_study='Buddhism', name='Taixu', birth_country='China'), Philosopher(born=360, died=434, subjects_of_study='Buddhism', name='Tao Sheng', birth_country='China'), Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China'), Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China'), Philosopher(born=1472, died=1529, subjects_of_study='Xinxue, Neo-Confucianism', name='Wang Yangming', birth_country='China'), Philosopher(born=1885, died=1968, subjects_of_study='Ren', name='Xiong Shili', birth_country='China'), Philosopher(born=1635, died=1704, subjects_of_study='Confucianism', name='Yan Yuan', birth_country='China'), Philosopher(born=1020, died=1077, subjects_of_study='Ren, Qi', name='Zhang Zai', birth_country='China'), Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China'), Philosopher(born=1130, died=1200, subjects_of_study='Qi, Li', name='Zhu Xi', birth_country='China')]
#
# Czechoslovakia:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Consciousness, Eidetic Reduction, Phenomenological Reduction', name='Edmund Husserl', birth_country='Czechoslovakia'), Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia')]
#
# Finland:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland')]
#
# Lithuania:
#
# [Philosopher(born=1906, died=1995, subjects_of_study='Judaism', name='Emmanuel Levinas', birth_country='Lithuania'), Philosopher(born=1754, died=1800, subjects_of_study='Skepticism, Moses Maimonides, Philosophy', name='Salomon Maimon', birth_country='Lithuania')]
#
# Czech Republic:
#
# [Philosopher(born=1883, died=1949, subjects_of_study='Faith', name='Erich Frank', birth_country='Czech Republic'), Philosopher(born=1832, died=1912, subjects_of_study='Greek Philosophy', name='Theodor Gomperz', birth_country='Czech Republic')]
#
# Austria:
#
# [Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria'), Philosopher(born=1887, died=1961, subjects_of_study='Quantum, Schrödinger Equation', name='Erwin Schrodinger', birth_country='Austria'), Philosopher(born=1902, died=1994, subjects_of_study='Scientific Method, Criterion Of Falsifiability, Induction', name='Karl Popper', birth_country='Austria'), Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria'), Philosopher(born=1882, died=1945, subjects_of_study='Logical Positivism', name='Otto Neurath', birth_country='Austria')]
#
# Ireland:
#
# [Philosopher(born=1694, died=1746, subjects_of_study='Moral Sense', name='Francis Hutcheson', birth_country='Ireland'), Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland'), Philosopher(born=1861, died=1909, subjects_of_study='Theological Liberalism, Modernism', name='George Tyrrell', birth_country='Ireland'), Philosopher(born=810, died=877, subjects_of_study='Neoplatonism', name='John Scotus Erigena', birth_country='Ireland'), Philosopher(born=1627, died=1691, subjects_of_study='Gas, Pressure, Air, Boyle’S Law, Vacuum', name='Robert Boyle', birth_country='Ireland')]
#
# Bohemia:
#
# [Philosopher(born=1849, died=1923, subjects_of_study='Language, Epistemology', name='Fritz Mauthner', birth_country='Bohemia')]
#
# Speyer:
#
# [Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer')]
#
# Switzerland:
#
# [Philosopher(born=1862, died=1906, subjects_of_study='Theism', name='Gaston Frommel', birth_country='Switzerland'), Philosopher(born=1712, died=1778, subjects_of_study='Cultural Evolution, General Will', name='Jean-Jacques Rousseau', birth_country='Switzerland')]
#
# Denmark:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark'), Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark')]
#
# Canada:
#
# [Philosopher(born=1918, died=1988, subjects_of_study='Canada, Nationalism', name='George Grant', birth_country='Canada')]
#
# Ohio:
#
# [Philosopher(born=1842, died=1921, subjects_of_study='Biological Psychology, Functionalism, Experimental Psychology', name='George Trumbull Ladd', birth_country='Ohio'), Philosopher(born=1908, died=2000, subjects_of_study='Formal Logic, Meaning', name='Willard Van Orman Quine', birth_country='Ohio')]
#
# Iran:
#
# [Philosopher(born=1798, died=1878, subjects_of_study='Ḥikmah', name='Hajji Hadi Sabzevari', birth_country='Iran'), Philosopher(born=1571, died=1640, subjects_of_study='Mysticism, Ishrāqīyah, Philosophy Of Nature', name='Mulla Sadra', birth_country='Iran'), Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]
#
# Japan:
#
# [Philosopher(born=1877, died=1950, subjects_of_study='Christianity', name='Hatano Seiichi', birth_country='Japan'), Philosopher(born=1583, died=1657, subjects_of_study='Shintō, Zhu Xi, Neo-Confucianism', name='Hayashi Razan', birth_country='Japan'), Philosopher(born=1855, died=1944, subjects_of_study='Poetry, Japanese Philosophy', name='Inoue Tetsujiro', birth_country='Japan'), Philosopher(born=1627, died=1705, subjects_of_study='Kogaku', name='Ito Jinsai', birth_country='Japan'), Philosopher(born=1619, died=1691, subjects_of_study='Wang Yangming, Neo-Confucianism', name='Kumazawa Banzan', birth_country='Japan'), Philosopher(born=1658, died=1734, subjects_of_study='Confucianism, Zhu Xi', name='Muro Kyuso', birth_country='Japan'), Philosopher(born=1870, died=1945, subjects_of_study='Nothingness, Experience', name='Nishida Kitaro', birth_country='Japan'), Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan')]
#
# Illinois:
#
# [Philosopher(born=1926, died=2016, subjects_of_study='Realism', name='Hilary Putnam', birth_country='Illinois')]
#
# Prussia:
#
# [Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia'), Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]
#
# Algeria:
#
# [Philosopher(born=1930, died=2004, subjects_of_study='Metaphysics, Deconstruction, Philosophy', name='Jacques Derrida', birth_country='Algeria'), Philosopher(born=1918, died=1990, subjects_of_study='Marxism, Structuralism', name='Louis Althusser', birth_country='Algeria')]
#
# Ithaca:
#
# [Philosopher(born=1904, died=1979, subjects_of_study='Perception, “The Perception Of The Visual World”', name='James J. Gibson', birth_country='Ithaca')]
#
# South Carolina:
#
# [Philosopher(born=1861, died=1934, subjects_of_study='Individual Difference', name='James Mark Baldwin', birth_country='South Carolina')]
#
# Alsace:
#
# [Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace')]
#
# Vermont:
#
# [Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont')]
#
# Connecticut:
#
# [Philosopher(born=1842, died=1901, subjects_of_study='Evolution', name='John Fiske', birth_country='Connecticut'), Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut')]
#
# Mexico:
#
# [Philosopher(born=1882, died=1959, subjects_of_study='Monism', name='Jose Vasconcelos', birth_country='Mexico')]
#
# California:
#
# [Philosopher(born=1855, died=1916, subjects_of_study='Truth, Will', name='Josiah Royce', birth_country='California')]
#
# Belgium:
#
# [Philosopher(born=1547, died=1606, subjects_of_study='Stoicism', name='Justus Lipsius', birth_country='Belgium')]
#
# Wisconsin:
#
# [Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin')]
#
# Split:
#
# [Philosopher(born=1450, died=1524, subjects_of_study='Ethics', name='Marko Marulic', birth_country='Split')]
#
# Azerbaijan:
#
# [Philosopher(born=1909, died=1988, subjects_of_study='Mathematics, Ludwig Wittgenstein', name='Max Black', birth_country='Azerbaijan')]
#
# New York:
#
# [Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York'), Philosopher(born=1902, died=1989, subjects_of_study='Marxism', name='Sidney Hook', birth_country='New York'), Philosopher(born=1895, died=1985, subjects_of_study='Semiotics, The Arts, Sign, Symbolism', name='Susanne K. Langer', birth_country='New York'), Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York')]
#
# Russia:
#
# [Philosopher(born=1822, died=1885, subjects_of_study='Philosophy Of History, Civilization', name='Nikolay Yakovlevich Danilevsky', birth_country='Russia'), Philosopher(born=1862, died=1915, subjects_of_study='Thought', name='Oswald Kulpe', birth_country='Russia'), Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia'), Philosopher(born=1853, died=1900, subjects_of_study='Mysticism', name='Vladimir Sergeyevich Solovyov', birth_country='Russia')]
#
# Iowa:
#
# [Philosopher(born=1857, died=1934, subjects_of_study='Plato, Platonism', name='Paul Shorey', birth_country='Iowa')]
#
# Udine:
#
# [Philosopher(born=1372, died=1429, subjects_of_study='Logic', name='Paul of Venice', birth_country='Udine')]
#
# Mantua:
#
# [Philosopher(born=1462, died=1525, subjects_of_study='Immortality', name='Pietro Pomponazzi', birth_country='Mantua')]
#
# Missouri:
#
# [Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri')]
#
# Australia:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia')]
#
# Kingdom of Naples:
#
# [Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Portugal:
#
# [Philosopher(born=1585, died=1640, subjects_of_study='Rationalism, Religion', name='Uriel Acosta', birth_country='Portugal')]
#
# Michigan:
#
# [Philosopher(born=1912, died=1989, subjects_of_study='Philosophy Of Mind', name='Wilfrid Sellars', birth_country='Michigan')]
#
# Turkistan:
#
# [Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan')]

# %% [markdown]
# More Pythonic way? Maybe...

# %%
import itertools

philosopher_by_country = {
    item[0]: list(item[1])
    for item in itertools.groupby(philosophers, lambda x: x.birth_country)
}

for country, person in philosopher_by_country.items():
    print(f"{country}: \n\n{person}\n")
# Out:
# Ukraine:
#
# [Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine')]
#
# Poland:
#
# [Philosopher(born=1823, died=1891, subjects_of_study='Algebraic Equation, Algebraic Number, Elliptic Function', name='Leopold Kronecker', birth_country='Poland')]
#
# Germany:
#
# [Philosopher(born=1833, died=1911, subjects_of_study='Social Science, Humanities, Methodology', name='Wilhelm Dilthey', birth_country='Germany')]
#
# Italy:
#
# [Philosopher(born=1433, died=1499, subjects_of_study='Plato, Plotinus, Soul', name='Marsilio Ficino', birth_country='Italy')]
#
# France:
#
# [Philosopher(born=1150, died=1231, subjects_of_study='Theology, Natural Law, Free Will, Liturgy', name='William of Auxerre', birth_country='France'), Philosopher(born=1070, died=1121, subjects_of_study='Universal', name='William of Champeaux', birth_country='France')]
#
# England:
#
# [Philosopher(born=1285, died=1349, subjects_of_study='Roman Catholicism, Occam’S Razor, Heterodoxy', name='William of Ockham', birth_country='England')]
#
# Indiana:
#
# [Philosopher(born=1930, died=1992, subjects_of_study='Higher Education', name='Allan Bloom', birth_country='Indiana')]
#
# Kingdom of the Two Sicilies:
#
# [Philosopher(born=1843, died=1904, subjects_of_study='Socialism, Historical Materialism', name='Antonio Labriola', birth_country='Kingdom of the Two Sicilies')]
#
# India:
#
# [Philosopher(born=1479, died=1531, subjects_of_study='Suddhadvaita', name='Vallabha', birth_country='India')]
#
# Spain:
#
# [Philosopher(born=1233, died=1316, subjects_of_study='Mysticism, Neoplatonism', name='Ramon Llull', birth_country='Spain')]
#
# Uzbekistan:
#
# [Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan')]
#
# Netherlands:
#
# [Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands')]
#
# Wales:
#
# [Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales')]
#
# Turkey:
#
# [Philosopher(born=1355, died=1452, subjects_of_study='Aristotelianism, Neoplatonism', name='George Gemistus Plethon', birth_country='Turkey')]
#
# Scotland:
#
# [Philosopher(born=1710, died=1796, subjects_of_study='Intuitionism', name='Thomas Reid', birth_country='Scotland')]
#
# Massachusetts:
#
# [Philosopher(born=1863, died=1931, subjects_of_study='Language, Social Interaction', name='George Herbert Mead', birth_country='Massachusetts')]
#
# China:
#
# [Philosopher(born=1885, died=1968, subjects_of_study='Ren', name='Xiong Shili', birth_country='China'), Philosopher(born=1635, died=1704, subjects_of_study='Confucianism', name='Yan Yuan', birth_country='China'), Philosopher(born=1020, died=1077, subjects_of_study='Ren, Qi', name='Zhang Zai', birth_country='China'), Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China'), Philosopher(born=1130, died=1200, subjects_of_study='Qi, Li', name='Zhu Xi', birth_country='China')]
#
# Czechoslovakia:
#
# [Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia')]
#
# Finland:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland')]
#
# Lithuania:
#
# [Philosopher(born=1754, died=1800, subjects_of_study='Skepticism, Moses Maimonides, Philosophy', name='Salomon Maimon', birth_country='Lithuania')]
#
# Czech Republic:
#
# [Philosopher(born=1832, died=1912, subjects_of_study='Greek Philosophy', name='Theodor Gomperz', birth_country='Czech Republic')]
#
# Austria:
#
# [Philosopher(born=1882, died=1945, subjects_of_study='Logical Positivism', name='Otto Neurath', birth_country='Austria')]
#
# Ireland:
#
# [Philosopher(born=1627, died=1691, subjects_of_study='Gas, Pressure, Air, Boyle’S Law, Vacuum', name='Robert Boyle', birth_country='Ireland')]
#
# Bohemia:
#
# [Philosopher(born=1849, died=1923, subjects_of_study='Language, Epistemology', name='Fritz Mauthner', birth_country='Bohemia')]
#
# Speyer:
#
# [Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer')]
#
# Switzerland:
#
# [Philosopher(born=1712, died=1778, subjects_of_study='Cultural Evolution, General Will', name='Jean-Jacques Rousseau', birth_country='Switzerland')]
#
# Denmark:
#
# [Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark')]
#
# Canada:
#
# [Philosopher(born=1918, died=1988, subjects_of_study='Canada, Nationalism', name='George Grant', birth_country='Canada')]
#
# Ohio:
#
# [Philosopher(born=1908, died=2000, subjects_of_study='Formal Logic, Meaning', name='Willard Van Orman Quine', birth_country='Ohio')]
#
# Iran:
#
# [Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]
#
# Japan:
#
# [Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan')]
#
# Illinois:
#
# [Philosopher(born=1926, died=2016, subjects_of_study='Realism', name='Hilary Putnam', birth_country='Illinois')]
#
# Prussia:
#
# [Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]
#
# Algeria:
#
# [Philosopher(born=1918, died=1990, subjects_of_study='Marxism, Structuralism', name='Louis Althusser', birth_country='Algeria')]
#
# Ithaca:
#
# [Philosopher(born=1904, died=1979, subjects_of_study='Perception, “The Perception Of The Visual World”', name='James J. Gibson', birth_country='Ithaca')]
#
# South Carolina:
#
# [Philosopher(born=1861, died=1934, subjects_of_study='Individual Difference', name='James Mark Baldwin', birth_country='South Carolina')]
#
# Alsace:
#
# [Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace')]
#
# Vermont:
#
# [Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont')]
#
# Connecticut:
#
# [Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut')]
#
# Mexico:
#
# [Philosopher(born=1882, died=1959, subjects_of_study='Monism', name='Jose Vasconcelos', birth_country='Mexico')]
#
# California:
#
# [Philosopher(born=1855, died=1916, subjects_of_study='Truth, Will', name='Josiah Royce', birth_country='California')]
#
# Belgium:
#
# [Philosopher(born=1547, died=1606, subjects_of_study='Stoicism', name='Justus Lipsius', birth_country='Belgium')]
#
# Wisconsin:
#
# [Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin')]
#
# Split:
#
# [Philosopher(born=1450, died=1524, subjects_of_study='Ethics', name='Marko Marulic', birth_country='Split')]
#
# Azerbaijan:
#
# [Philosopher(born=1909, died=1988, subjects_of_study='Mathematics, Ludwig Wittgenstein', name='Max Black', birth_country='Azerbaijan')]
#
# New York:
#
# [Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York')]
#
# Russia:
#
# [Philosopher(born=1853, died=1900, subjects_of_study='Mysticism', name='Vladimir Sergeyevich Solovyov', birth_country='Russia')]
#
# Iowa:
#
# [Philosopher(born=1857, died=1934, subjects_of_study='Plato, Platonism', name='Paul Shorey', birth_country='Iowa')]
#
# Udine:
#
# [Philosopher(born=1372, died=1429, subjects_of_study='Logic', name='Paul of Venice', birth_country='Udine')]
#
# Mantua:
#
# [Philosopher(born=1462, died=1525, subjects_of_study='Immortality', name='Pietro Pomponazzi', birth_country='Mantua')]
#
# Missouri:
#
# [Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri')]
#
# Australia:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia')]
#
# Kingdom of Naples:
#
# [Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Portugal:
#
# [Philosopher(born=1585, died=1640, subjects_of_study='Rationalism, Religion', name='Uriel Acosta', birth_country='Portugal')]
#
# Michigan:
#
# [Philosopher(born=1912, died=1989, subjects_of_study='Philosophy Of Mind', name='Wilfrid Sellars', birth_country='Michigan')]
#
# Turkistan:
#
# [Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan')]

# %%
def reducer(acc, philosopher):
    subjects = philosopher.subjects_of_study.split(", ")
    for subject in subjects:
        acc[subject].append(philosopher)
    return acc

all_subject_map = {k: [] for k in all_subjects}

philosopher_by_field = reduce(
    reducer,
    philosophers,
    all_subject_map
)

for subject, person in philosopher_by_field.items():
    print(f"{subject}: \n\n{person}\n")
# Out:
# Emotion:
#
# [Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands'), Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China')]
#
# Marxism:
#
# [Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France'), Philosopher(born=1918, died=1990, subjects_of_study='Marxism, Structuralism', name='Louis Althusser', birth_country='Algeria'), Philosopher(born=1908, died=1961, subjects_of_study='Marxism', name='Maurice Merleau-Ponty', birth_country='France'), Philosopher(born=1902, died=1989, subjects_of_study='Marxism', name='Sidney Hook', birth_country='New York')]
#
# Functionalism:
#
# [Philosopher(born=1842, died=1921, subjects_of_study='Biological Psychology, Functionalism, Experimental Psychology', name='George Trumbull Ladd', birth_country='Ohio')]
#
# Sensationalism:
#
# [Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands')]
#
# Literature:
#
# [Philosopher(born=1807, died=1887, subjects_of_study='Literature, Realism', name='Friedrich Theodor von Vischer', birth_country='Germany'), Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark'), Philosopher(born=1892, died=1940, subjects_of_study='Aesthetics, Literature', name='Walter Benjamin', birth_country='Germany')]
#
# Devolution:
#
# [Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]
#
# Puritanism:
#
# [Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut')]
#
# Covering-Law Model:
#
# [Philosopher(born=1905, died=1997, subjects_of_study='Philosophy Of Science, Scientific Theory, Covering-Law Model', name='Carl Gustav Hempel', birth_country='Germany')]
#
# Pluralism:
#
# [Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]
#
# Sovereignty:
#
# [Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England')]
#
# Categorical Imperative:
#
# [Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England')]
#
# Formal System:
#
# [Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France'), Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia')]
#
# Symbolism:
#
# [Philosopher(born=1895, died=1985, subjects_of_study='Semiotics, The Arts, Sign, Symbolism', name='Susanne K. Langer', birth_country='New York')]
#
# Heaven:
#
# [Philosopher(born=1238, died=1317, subjects_of_study='Hell, Heaven, Dvaita', name='Madhva', birth_country='India')]
#
# Government:
#
# [Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England')]
#
# Sharif:
#
# [Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]
#
# Mine Gas:
#
# [Philosopher(born=1860, died=1936, subjects_of_study='Coal Mining, Safety, Mine Gas, Gas Exchange', name='John Scott Haldane', birth_country='Scotland')]
#
# Ishrāqīyah:
#
# [Philosopher(born=1571, died=1640, subjects_of_study='Mysticism, Ishrāqīyah, Philosophy Of Nature', name='Mulla Sadra', birth_country='Iran')]
#
# Vichara:
#
# [Philosopher(born=1879, died=1950, subjects_of_study='Maya, Vichara, Monism', name='Ramana Maharshi', birth_country='India')]
#
# Rationalism:
#
# [Philosopher(born=1808, died=1874, subjects_of_study='Rationalism, Religion, Dialectic', name='David Friedrich Strauss', birth_country='Germany'), Philosopher(born=1842, died=1906, subjects_of_study='Rationalism, Irrationalism, Unconscious', name='Eduard von Hartmann', birth_country='Germany'), Philosopher(born=1823, died=1892, subjects_of_study='Judaism, Jesus, Rationalism, Religion, Early Church', name='Ernest Renan', birth_country='France'), Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands'), Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'), Philosopher(born=1618, died=1651, subjects_of_study='Rationalism, Reason', name='Nathanael Culverwel', birth_country='England'), Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark'), Philosopher(born=1585, died=1640, subjects_of_study='Rationalism, Religion', name='Uriel Acosta', birth_country='Portugal'), Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China')]
#
# Logical Positivism:
#
# [Philosopher(born=1882, died=1945, subjects_of_study='Logical Positivism', name='Otto Neurath', birth_country='Austria')]
#
# Relativity:
#
# [Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England'), Philosopher(born=1854, died=1912, subjects_of_study='Relativity, Fuchsian Function, Automorphic Function, N-Body Problem', name='Henri Poincare', birth_country='France')]
#
# Relativism:
#
# [Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany')]
#
# Theology:
#
# [Philosopher(born=1923, died=2010, subjects_of_study='Atheism, Philosophy Of Religion, Theology', name='Antony Flew', birth_country='England'), Philosopher(born=1835, died=1908, subjects_of_study='Immanuel Kant, Theology', name='Edward Caird', birth_country='Scotland'), Philosopher(born=1150, died=1231, subjects_of_study='Theology, Natural Law, Free Will, Liturgy', name='William of Auxerre', birth_country='France')]
#
# Civilization:
#
# [Philosopher(born=1822, died=1885, subjects_of_study='Philosophy Of History, Civilization', name='Nikolay Yakovlevich Danilevsky', birth_country='Russia')]
#
# Social Science:
#
# [Philosopher(born=1833, died=1911, subjects_of_study='Social Science, Humanities, Methodology', name='Wilhelm Dilthey', birth_country='Germany')]
#
# Conservation Of Energy:
#
# [Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany')]
#
# Deconstruction:
#
# [Philosopher(born=1930, died=2004, subjects_of_study='Metaphysics, Deconstruction, Philosophy', name='Jacques Derrida', birth_country='Algeria')]
#
# Meaning:
#
# [Philosopher(born=1908, died=2000, subjects_of_study='Formal Logic, Meaning', name='Willard Van Orman Quine', birth_country='Ohio')]
#
# Church Of England:
#
# [Philosopher(born=1554, died=1600, subjects_of_study='Church Of England', name='Richard Hooker', birth_country='England')]
#
# Disarmament:
#
# [Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales')]
#
# Utilitarianism:
#
# [Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'), Philosopher(born=1806, died=1873, subjects_of_study='Utilitarianism, Induction', name='John Stuart Mill', birth_country='England'), Philosopher(born=1743, died=1805, subjects_of_study='Ethics, Utilitarianism, Argument From Design', name='William Paley', birth_country='England')]
#
# Protothetic:
#
# [Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia')]
#
# Historicism:
#
# [Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany')]
#
# Non-Euclidean Geometry:
#
# [Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany')]
#
# Papal Primacy:
#
# [Philosopher(born=1401, died=1464, subjects_of_study='Conciliarism, Papal Primacy', name='Nicholas of Cusa', birth_country='Germany')]
#
# Transubstantiation:
#
# [Philosopher(born=1330, died=1384, subjects_of_study='Lollards, Predestination, Transubstantiation', name='John Wycliffe', birth_country='England')]
#
# Vision:
#
# [Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland')]
#
# Nuclear Weapon:
#
# [Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales')]
#
# 9Th Baronet:
#
# [Philosopher(born=1820, died=1871, subjects_of_study='Philosophy, Sir William Hamilton, 9Th Baronet, Knowledge', name='Henry Longueville Mansel', birth_country='England')]
#
# Incarnation:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland')]
#
# Music:
#
# [Philosopher(born=1903, died=1969, subjects_of_study='Philosophy Of Art, Music', name='Theodor Wiesengrund Adorno', birth_country='Germany')]
#
# Human Intelligence:
#
# [Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France')]
#
# Memory:
#
# [Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France')]
#
# Innate Idea:
#
# [Philosopher(born=1596, died=1650, subjects_of_study='A Priori Knowledge, Mind-Body Dualism, Philosophy, Methodic Doubt, Innate Idea', name='Rene Descartes', birth_country='France')]
#
# Soul:
#
# [Philosopher(born=1100, died=1169, subjects_of_study='Soul, Via Negativa', name='Isaac of Stella', birth_country='England'), Philosopher(born=1433, died=1499, subjects_of_study='Plato, Plotinus, Soul', name='Marsilio Ficino', birth_country='Italy'), Philosopher(born=1729, died=1786, subjects_of_study='Judaism, Immortality, Soul, Religious Toleration', name='Moses Mendelssohn', birth_country='Germany')]
#
# Greek Literature:
#
# [Philosopher(born=1403, died=1472, subjects_of_study='Greek Literature, Platonism', name='Bessarion', birth_country='Turkey')]
#
# Measurement:
#
# [Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria'), Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace'), Philosopher(born=1880, died=1949, subjects_of_study='X-Ray, Measurement, Ionization', name='Norman Robert Campbell', birth_country='England')]
#
# Casuistry:
#
# [Philosopher(born=1528, died=1580, subjects_of_study='Casuistry, Probabilism', name='Bartolome de Medina', birth_country='Spain')]
#
# Early Church:
#
# [Philosopher(born=1823, died=1892, subjects_of_study='Judaism, Jesus, Rationalism, Religion, Early Church', name='Ernest Renan', birth_country='France')]
#
# Dramatic Literature:
#
# [Philosopher(born=1713, died=1784, subjects_of_study='Dramatic Literature', name='Denis Diderot', birth_country='France'), Philosopher(born=1729, died=1781, subjects_of_study='Dramatic Literature', name='Gotthold Ephraim Lessing', birth_country='Germany')]
#
# National Economy:
#
# [Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales')]
#
# Motion:
#
# [Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France')]
#
# Philosophical Anthropology:
#
# [Philosopher(born=1668, died=1744, subjects_of_study='Philosophical Anthropology, Providence, Social Evolution', name='Giambattista Vico', birth_country='Italy')]
#
# Pragmatism:
#
# [Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Instinct:
#
# [Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France')]
#
# Universal:
#
# [Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy'), Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England'), Philosopher(born=1070, died=1121, subjects_of_study='Universal', name='William of Champeaux', birth_country='France')]
#
# Political Economy:
#
# [Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer')]
#
# Jansenism:
#
# [Philosopher(born=1625, died=1695, subjects_of_study='Jansenism', name='Pierre Nicole', birth_country='France')]
#
# Hermeneutics:
#
# [Philosopher(born=1900, died=2002, subjects_of_study='Hermeneutics', name='Hans-Georg Gadamer', birth_country='Germany')]
#
# Philosophy Of Mind:
#
# [Philosopher(born=1912, died=1989, subjects_of_study='Philosophy Of Mind', name='Wilfrid Sellars', birth_country='Michigan')]
#
# Martin Heidegger:
#
# [Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin')]
#
# Numinous:
#
# [Philosopher(born=1869, died=1937, subjects_of_study='Sacred, Religion, Mysterium Tremendum Et Fascinans, Numinous', name='Rudolf Otto', birth_country='Germany')]
#
# Society:
#
# [Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany'), Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France')]
#
# Sexuality:
#
# [Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France')]
#
# Intentionalism:
#
# [Philosopher(born=1838, died=1917, subjects_of_study='Intentionality, Intentionalism', name='Franz Brentano', birth_country='Germany')]
#
# Boyle’S Law:
#
# [Philosopher(born=1627, died=1691, subjects_of_study='Gas, Pressure, Air, Boyle’S Law, Vacuum', name='Robert Boyle', birth_country='Ireland')]
#
# Grammar:
#
# [Philosopher(born=1407, died=1457, subjects_of_study='Latin Language, Grammar, Donation Of Constantine', name='Lorenzo Valla', birth_country='Italy')]
#
# Social Change:
#
# [Philosopher(born=1820, died=1903, subjects_of_study='Evolution, Social Change, Social Structure, Cultural Evolution, Survival Of The Fittest', name='Herbert Spencer', birth_country='England')]
#
# Methodic Doubt:
#
# [Philosopher(born=1596, died=1650, subjects_of_study='A Priori Knowledge, Mind-Body Dualism, Philosophy, Methodic Doubt, Innate Idea', name='Rene Descartes', birth_country='France')]
#
# Theological Existentialism:
#
# [Philosopher(born=1884, died=1976, subjects_of_study='Theological Existentialism', name='Rudolf Bultmann', birth_country='Germany')]
#
# Wang Yangming:
#
# [Philosopher(born=1619, died=1691, subjects_of_study='Wang Yangming, Neo-Confucianism', name='Kumazawa Banzan', birth_country='Japan')]
#
# Psychology:
#
# [Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland'), Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York')]
#
# Comparative Religion:
#
# [Philosopher(born=1898, died=1955, subjects_of_study='Sociology, Phenomenology Of Religion, Religion, Comparative Religion', name='Joachim Wach', birth_country='Germany')]
#
# Atheism:
#
# [Philosopher(born=1923, died=2010, subjects_of_study='Atheism, Philosophy Of Religion, Theology', name='Antony Flew', birth_country='England')]
#
# Elliptic Function:
#
# [Philosopher(born=1823, died=1891, subjects_of_study='Algebraic Equation, Algebraic Number, Elliptic Function', name='Leopold Kronecker', birth_country='Poland')]
#
# “Yijing”:
#
# [Philosopher(born=1011, died=1077, subjects_of_study='“Yijing”, Numerology, Cyclicism, Neo-Confucianism', name='Shao Yong', birth_country='China'), Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China')]
#
# Personalism:
#
# [Philosopher(born=1646, died=1716, subjects_of_study='Problem Of Evil, Personalism, Differentiation, Best Of All Possible Worlds, Integration', name='Gottfried Wilhelm Leibniz', birth_country='Germany')]
#
# Faith:
#
# [Philosopher(born=1883, died=1949, subjects_of_study='Faith', name='Erich Frank', birth_country='Czech Republic'), Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain'), Philosopher(born=1886, died=1965, subjects_of_study='Faith, Justification, Theonomy', name='Paul Tillich', birth_country='Germany')]
#
# Phenomenology:
#
# [Philosopher(born=1891, died=1942, subjects_of_study='Phenomenology, Thomism', name='Edith Stein', birth_country='Poland'), Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France')]
#
# Self-Image:
#
# [Philosopher(born=1900, died=1980, subjects_of_study='Self-Image', name='Erich Fromm', birth_country='Germany')]
#
# Daoism:
#
# [Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China')]
#
# Probabilism:
#
# [Philosopher(born=1528, died=1580, subjects_of_study='Casuistry, Probabilism', name='Bartolome de Medina', birth_country='Spain')]
#
# Wave:
#
# [Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria'), Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany')]
#
# Grace:
#
# [Philosopher(born=1300, died=1358, subjects_of_study='Grace', name='Gregory of Rimini', birth_country='Italy')]
#
# Sociology:
#
# [Philosopher(born=1798, died=1857, subjects_of_study='Sociology, Social Evolution', name='Auguste Comte', birth_country='France'), Philosopher(born=1898, died=1955, subjects_of_study='Sociology, Phenomenology Of Religion, Religion, Comparative Religion', name='Joachim Wach', birth_country='Germany')]
#
# Marriage:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland')]
#
# Money:
#
# [Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany')]
#
# Evolution:
#
# [Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France'), Philosopher(born=1820, died=1903, subjects_of_study='Evolution, Social Change, Social Structure, Cultural Evolution, Survival Of The Fittest', name='Herbert Spencer', birth_country='England'), Philosopher(born=1842, died=1901, subjects_of_study='Evolution', name='John Fiske', birth_country='Connecticut'), Philosopher(born=1887, died=1975, subjects_of_study='Evolution, Taxonomy, Embryo, Behaviour', name='Julian Huxley', birth_country='England'), Philosopher(born=1910, died=2009, subjects_of_study='Evolution, Philosophy Of Biology, Existentialism, Martin Heidegger, Karl Jaspers', name='Marjorie Grene', birth_country='Wisconsin'), Philosopher(born=1881, died=1955, subjects_of_study='Evolution, Peking Man, Noösphere', name='Pierre Teilhard de Chardin', birth_country='France'), Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia'), Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine'), Philosopher(born=1825, died=1895, subjects_of_study='Evolution, Taxonomy, Agnosticism, Religion, Darwinism', name='Thomas Henry Huxley', birth_country='England')]
#
# Revivalism:
#
# [Philosopher(born=1703, died=1758, subjects_of_study='Puritanism, Revivalism', name='Jonathan Edwards', birth_country='Connecticut')]
#
# Proposition:
#
# [Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria')]
#
# Theism:
#
# [Philosopher(born=1866, died=1957, subjects_of_study='Theism, Argument From Design', name='Frederick Robert Tennant', birth_country='England'), Philosopher(born=1862, died=1906, subjects_of_study='Theism', name='Gaston Frommel', birth_country='Switzerland'), Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland')]
#
# Naturalism:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark'), Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China')]
#
# Higher Education:
#
# [Philosopher(born=1930, died=1992, subjects_of_study='Higher Education', name='Allan Bloom', birth_country='Indiana')]
#
# Mysterium Tremendum Et Fascinans:
#
# [Philosopher(born=1869, died=1937, subjects_of_study='Sacred, Religion, Mysterium Tremendum Et Fascinans, Numinous', name='Rudolf Otto', birth_country='Germany')]
#
# Primitive Culture:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland'), Philosopher(born=1857, died=1939, subjects_of_study='Primitive Culture', name='Lucien Levy-Bruhl', birth_country='France')]
#
# Littérature Engagée:
#
# [Philosopher(born=1905, died=1980, subjects_of_study='Marxism, Existentialism, Phenomenology, Gustave Flaubert, Littérature Engagée', name='Jean-Paul Sartre', birth_country='France')]
#
# Medicine:
#
# [Philosopher(born=1135, died=1204, subjects_of_study='Judaism, Medicine, Philosophy Of Religion, Hebraic Law, Thirteen Articles Of Faith', name='Moses Maimonides', birth_country='Spain')]
#
# Voltaire:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark')]
#
# Paideia:
#
# [Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York')]
#
# Sacred:
#
# [Philosopher(born=1869, died=1937, subjects_of_study='Sacred, Religion, Mysterium Tremendum Et Fascinans, Numinous', name='Rudolf Otto', birth_country='Germany')]
#
# Intentionality:
#
# [Philosopher(born=1853, died=1920, subjects_of_study='Objectivism, Intentionality', name='Alexius Meinong', birth_country='Ukraine'), Philosopher(born=1838, died=1917, subjects_of_study='Intentionality, Intentionalism', name='Franz Brentano', birth_country='Germany')]
#
# Michelangelo:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark')]
#
# International Language:
#
# [Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France')]
#
# Prime:
#
# [Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France')]
#
# General Semantics:
#
# [Philosopher(born=1879, died=1950, subjects_of_study='Semantics, General Semantics', name='Alfred Korzybski', birth_country='Poland')]
#
# Differentiation:
#
# [Philosopher(born=1646, died=1716, subjects_of_study='Problem Of Evil, Personalism, Differentiation, Best Of All Possible Worlds, Integration', name='Gottfried Wilhelm Leibniz', birth_country='Germany')]
#
# Shabdadvaita:
#
# [Philosopher(born=570, died=651, subjects_of_study='Philosophy Of Language, Shabdadvaita', name='Bhartrihari', birth_country='India')]
#
# Germany:
#
# [Philosopher(born=1762, died=1814, subjects_of_study='Germany, Secondary Education, Elementary Education, Ego, Practical Reason', name='Johann Gottlieb Fichte', birth_country='Germany')]
#
# Nothingness:
#
# [Philosopher(born=1870, died=1945, subjects_of_study='Nothingness, Experience', name='Nishida Kitaro', birth_country='Japan')]
#
# Christianity:
#
# [Philosopher(born=1865, died=1923, subjects_of_study='Christianity, Philosophy Of Religion, Historicism, Society, Relativism', name='Ernst Troeltsch', birth_country='Germany'), Philosopher(born=1792, died=1860, subjects_of_study='Christianity, Hegelianism', name='Ferdinand Christian Baur', birth_country='Germany'), Philosopher(born=1877, died=1950, subjects_of_study='Christianity', name='Hatano Seiichi', birth_country='Japan'), Philosopher(born=1632, died=1704, subjects_of_study='Christianity, Language, Government, Universal, Personal Identity', name='John Locke', birth_country='England'), Philosopher(born=1647, died=1706, subjects_of_study='Christianity, Heterodoxy', name='Pierre Bayle', birth_country='France'), Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark')]
#
# Thought:
#
# [Philosopher(born=1822, died=1893, subjects_of_study='Thought, Emotion', name='Jacob Moleschott', birth_country='Netherlands'), Philosopher(born=1862, died=1915, subjects_of_study='Thought', name='Oswald Kulpe', birth_country='Russia')]
#
# Metaphysics:
#
# [Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1925, died=1995, subjects_of_study='Metaphysics', name='Gilles Deleuze', birth_country='France'), Philosopher(born=1930, died=2004, subjects_of_study='Metaphysics, Deconstruction, Philosophy', name='Jacques Derrida', birth_country='Algeria'), Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Argument From Design:
#
# [Philosopher(born=1866, died=1957, subjects_of_study='Theism, Argument From Design', name='Frederick Robert Tennant', birth_country='England'), Philosopher(born=1743, died=1805, subjects_of_study='Ethics, Utilitarianism, Argument From Design', name='William Paley', birth_country='England')]
#
# Protestantism:
#
# [Philosopher(born=1768, died=1834, subjects_of_study='Protestantism', name='Friedrich Schleiermacher', birth_country='Poland'), Philosopher(born=1809, died=1884, subjects_of_study='Protestantism, Kantianism', name='Isaak August Dorner', birth_country='Germany'), Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri')]
#
# Totalitarianism:
#
# [Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany')]
#
# Trial:
#
# [Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany')]
#
# Variable:
#
# [Philosopher(born=1848, died=1925, subjects_of_study='Variable, Quantifier', name='Gottlob Frege', birth_country='Germany')]
#
# Sound:
#
# [Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany')]
#
# Triple Theory:
#
# [Philosopher(born=1942, died=2017, subjects_of_study='Personal Identity, Triple Theory', name='Derek Parfit', birth_country='China')]
#
# Moral Sense:
#
# [Philosopher(born=1694, died=1746, subjects_of_study='Moral Sense', name='Francis Hutcheson', birth_country='Ireland')]
#
# Complementarity Principle:
#
# [Philosopher(born=1901, died=1976, subjects_of_study='Uncertainty Principle, Complementarity Principle, Matrix Mechanics, Spinor Equation', name='Werner Heisenberg', birth_country='Germany')]
#
# Coal Mining:
#
# [Philosopher(born=1860, died=1936, subjects_of_study='Coal Mining, Safety, Mine Gas, Gas Exchange', name='John Scott Haldane', birth_country='Scotland')]
#
# Mach Number:
#
# [Philosopher(born=1838, died=1916, subjects_of_study='Measurement, Wave, Sensation, Mach Number, Mach’S Principle', name='Ernst Mach', birth_country='Austria')]
#
# Pendulum:
#
# [Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France')]
#
# Roman Catholicism:
#
# [Philosopher(born=1810, died=1848, subjects_of_study='Roman Catholicism', name='Jaime Luciano Balmes', birth_country='Spain'), Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples'), Philosopher(born=1285, died=1349, subjects_of_study='Roman Catholicism, Occam’S Razor, Heterodoxy', name='William of Ockham', birth_country='England')]
#
# Law:
#
# [Philosopher(born=1748, died=1832, subjects_of_study='Utility, Law', name='Jeremy Bentham', birth_country='England')]
#
# Islam:
#
# [Philosopher(born=1126, died=1198, subjects_of_study='Islam, Platonism, Aristotelianism, Greek Philosophy', name='Averroes', birth_country='Spain'), Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan'), Philosopher(born=1058, died=1111, subjects_of_study='Islam, Sufism, Sharif', name='al-Ghazali', birth_country='Iran')]
#
# Immortality:
#
# [Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia'), Philosopher(born=1729, died=1786, subjects_of_study='Judaism, Immortality, Soul, Religious Toleration', name='Moses Mendelssohn', birth_country='Germany'), Philosopher(born=1462, died=1525, subjects_of_study='Immortality', name='Pietro Pomponazzi', birth_country='Mantua')]
#
# Wuwei:
#
# [Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China')]
#
# Scientific Method:
#
# [Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia'), Philosopher(born=1902, died=1994, subjects_of_study='Scientific Method, Criterion Of Falsifiability, Induction', name='Karl Popper', birth_country='Austria')]
#
# Lixue:
#
# [Philosopher(born=1033, died=1107, subjects_of_study='Li, Neo-Confucianism, Lixue', name='Cheng Yi', birth_country='China')]
#
# Philosophy Of History:
#
# [Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy'), Philosopher(born=1863, died=1954, subjects_of_study='Philosophy Of History', name='Henri Berr', birth_country='France'), Philosopher(born=1818, died=1883, subjects_of_study='Philosophy Of History, Capitalism, Use Value, Exchange Value', name='Karl Marx', birth_country='Germany'), Philosopher(born=1822, died=1885, subjects_of_study='Philosophy Of History, Civilization', name='Nikolay Yakovlevich Danilevsky', birth_country='Russia')]
#
# Unconscious:
#
# [Philosopher(born=1842, died=1906, subjects_of_study='Rationalism, Irrationalism, Unconscious', name='Eduard von Hartmann', birth_country='Germany')]
#
# Scholasticism:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland'), Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer'), Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy')]
#
# Individual Difference:
#
# [Philosopher(born=1861, died=1934, subjects_of_study='Individual Difference', name='James Mark Baldwin', birth_country='South Carolina')]
#
# Philosophy Of Education:
#
# [Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland'), Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont')]
#
# Cycloid:
#
# [Philosopher(born=1623, died=1662, subjects_of_study='Probability, Conic Section, Pascal’S Triangle, Cycloid, Pascal’S Principle', name='Blaise Pascal', birth_country='France'), Philosopher(born=1588, died=1648, subjects_of_study='Vibration, Pendulum, Mersenne Prime, Cycloid, Prime', name='Marin Mersenne', birth_country='France')]
#
# Truth:
#
# [Philosopher(born=1855, died=1916, subjects_of_study='Truth, Will', name='Josiah Royce', birth_country='California'), Philosopher(born=1644, died=1696, subjects_of_study='Truth', name='Simon Foucher', birth_country='France')]
#
# Perception:
#
# [Philosopher(born=1685, died=1753, subjects_of_study='Perception, Theism, Sense-Data, Vision', name='George Berkeley', birth_country='Ireland'), Philosopher(born=1801, died=1887, subjects_of_study='Perception, Sensation, Weber’S Law', name='Gustav Theodor Fechner', birth_country='Germany'), Philosopher(born=1904, died=1979, subjects_of_study='Perception, “The Perception Of The Visual World”', name='James J. Gibson', birth_country='Ithaca')]
#
# Skepticism:
#
# [Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain'), Philosopher(born=1754, died=1800, subjects_of_study='Skepticism, Moses Maimonides, Philosophy', name='Salomon Maimon', birth_country='Lithuania')]
#
# Indian Philosophy:
#
# [Philosopher(born=1866, died=1942, subjects_of_study='Buddhism, Indian Philosophy, Logic', name='Fyodor Ippolitovich Shcherbatskoy', birth_country='Poland')]
#
# Intuitionism:
#
# [Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'), Philosopher(born=1710, died=1796, subjects_of_study='Intuitionism', name='Thomas Reid', birth_country='Scotland')]
#
# Categorical Proposition:
#
# [Philosopher(born=1834, died=1923, subjects_of_study='Probability Theory, Venn Diagram, Categorical Proposition, Syllogism', name='John Venn', birth_country='England')]
#
# Axiomatic Method:
#
# [Philosopher(born=1872, died=1970, subjects_of_study='Formal Logic, Nuclear Weapon, Russell’S Paradox, Disarmament, Axiomatic Method', name='Bertrand Russell', birth_country='Wales')]
#
# Porphyry:
#
# [Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy')]
#
# Dread:
#
# [Philosopher(born=1813, died=1855, subjects_of_study='Christianity, Rationalism, Free Will, Dread, Leap Of Faith', name='Soren Kierkegaard', birth_country='Denmark')]
#
# Fuchsian Function:
#
# [Philosopher(born=1854, died=1912, subjects_of_study='Relativity, Fuchsian Function, Automorphic Function, N-Body Problem', name='Henri Poincare', birth_country='France')]
#
# Picture Theory Of Meaning:
#
# [Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria')]
#
# Economics:
#
# [Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany'), Philosopher(born=1852, died=1949, subjects_of_study='Economics, Deduction, Induction, Methodology', name='John Neville Keynes', birth_country='England')]
#
# Light:
#
# [Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace'), Philosopher(born=1220, died=1292, subjects_of_study='Light, Gunpowder, Eyeglasses, Rainbow, Empirical Method', name='Roger Bacon', birth_country='England')]
#
# Realism:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland'), Philosopher(born=1807, died=1887, subjects_of_study='Literature, Realism', name='Friedrich Theodor von Vischer', birth_country='Germany'), Philosopher(born=1926, died=2016, subjects_of_study='Realism', name='Hilary Putnam', birth_country='Illinois')]
#
# Matrix Mechanics:
#
# [Philosopher(born=1901, died=1976, subjects_of_study='Uncertainty Principle, Complementarity Principle, Matrix Mechanics, Spinor Equation', name='Werner Heisenberg', birth_country='Germany')]
#
# Divine Union:
#
# [Philosopher(born=1266, died=1308, subjects_of_study='Scholasticism, Realism, Incarnation, Immaculate Conception, Divine Union', name='Blessed John Duns Scotus', birth_country='Scotland')]
#
# Justification:
#
# [Philosopher(born=1886, died=1965, subjects_of_study='Faith, Justification, Theonomy', name='Paul Tillich', birth_country='Germany')]
#
# Globular Cluster:
#
# [Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England')]
#
# Miracle:
#
# [Philosopher(born=1711, died=1776, subjects_of_study='England, Miracle, Idea, Neutral Monism, Causation', name='David Hume', birth_country='Scotland')]
#
# Mind-Body Dualism:
#
# [Philosopher(born=1632, died=1677, subjects_of_study='Pantheism, Mind-Body Dualism', name='Benedict de Spinoza', birth_country='Netherlands'), Philosopher(born=1596, died=1650, subjects_of_study='A Priori Knowledge, Mind-Body Dualism, Philosophy, Methodic Doubt, Innate Idea', name='Rene Descartes', birth_country='France')]
#
# Greek Philosophy:
#
# [Philosopher(born=1126, died=1198, subjects_of_study='Islam, Platonism, Aristotelianism, Greek Philosophy', name='Averroes', birth_country='Spain'), Philosopher(born=980, died=1037, subjects_of_study='Islam, History Of Medicine, Aristotelianism, Greek Philosophy', name='Avicenna', birth_country='Uzbekistan'), Philosopher(born=1832, died=1912, subjects_of_study='Greek Philosophy', name='Theodor Gomperz', birth_country='Czech Republic'), Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan')]
#
# Peasantry:
#
# [Philosopher(born=1893, died=1988, subjects_of_study='China, Peasantry, Neo-Confucianism', name='Liang Shuming', birth_country='China')]
#
# Pascal’S Triangle:
#
# [Philosopher(born=1623, died=1662, subjects_of_study='Probability, Conic Section, Pascal’S Triangle, Cycloid, Pascal’S Principle', name='Blaise Pascal', birth_country='France')]
#
# Zhu Xi:
#
# [Philosopher(born=1583, died=1657, subjects_of_study='Shintō, Zhu Xi, Neo-Confucianism', name='Hayashi Razan', birth_country='Japan'), Philosopher(born=1658, died=1734, subjects_of_study='Confucianism, Zhu Xi', name='Muro Kyuso', birth_country='Japan')]
#
# Utility:
#
# [Philosopher(born=1748, died=1832, subjects_of_study='Utility, Law', name='Jeremy Bentham', birth_country='England')]
#
# Political Philosophy:
#
# [Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy'), Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia'), Philosopher(born=1120, died=1180, subjects_of_study='Political Philosophy', name='John of Salisbury', birth_country='England'), Philosopher(born=878, died=950, subjects_of_study='Political Philosophy, Greek Philosophy', name='al-Farabi', birth_country='Turkistan')]
#
# Teleology:
#
# [Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia')]
#
# Social Contract:
#
# [Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England')]
#
# Zionism:
#
# [Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine')]
#
# Eidetic Reduction:
#
# [Philosopher(born=1859, died=1938, subjects_of_study='Consciousness, Eidetic Reduction, Phenomenological Reduction', name='Edmund Husserl', birth_country='Czechoslovakia')]
#
# Speciation:
#
# [Philosopher(born=1900, died=1975, subjects_of_study='Evolution, Speciation, Drosophila, Synthetic Theory Of Evolution', name='Theodosius Dobzhansky', birth_country='Ukraine')]
#
# Julius Caesar:
#
# [Philosopher(born=1842, died=1927, subjects_of_study='Literature, Michelangelo, Julius Caesar, Voltaire, Naturalism', name='Georg Brandes', birth_country='Denmark')]
#
# Monism:
#
# [Philosopher(born=1882, died=1959, subjects_of_study='Monism', name='Jose Vasconcelos', birth_country='Mexico'), Philosopher(born=1879, died=1950, subjects_of_study='Maya, Vichara, Monism', name='Ramana Maharshi', birth_country='India')]
#
# Prison:
#
# [Philosopher(born=1926, died=1984, subjects_of_study='Mental Disorder, Prison, Sexuality, Society', name='Michel Foucault', birth_country='France')]
#
# “Brahma-Sutra-Bhashya”:
#
# [Philosopher(born=700, died=750, subjects_of_study='Upanishad, “Brahma-Sutra-Bhashya”', name='Shankara', birth_country='India')]
#
# Semantics:
#
# [Philosopher(born=1879, died=1950, subjects_of_study='Semantics, General Semantics', name='Alfred Korzybski', birth_country='Poland')]
#
# Absolutism:
#
# [Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England')]
#
# Trinity:
#
# [Philosopher(born=475, died=524, subjects_of_study='Aristotelianism, Universal, Trinity, Porphyry, Free Will', name='Anicius Manlius Severinus Boethius', birth_country='Italy')]
#
# Liberal Arts:
#
# [Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York')]
#
# American Revolution:
#
# [Philosopher(born=1723, died=1791, subjects_of_study='American Revolution, French Revolution, National Economy', name='Richard Price', birth_country='Wales')]
#
# Theonomy:
#
# [Philosopher(born=1886, died=1965, subjects_of_study='Faith, Justification, Theonomy', name='Paul Tillich', birth_country='Germany')]
#
# Psychopathology:
#
# [Philosopher(born=1883, died=1969, subjects_of_study='Psychopathology', name='Karl Jaspers', birth_country='Germany')]
#
# Foundations Of Mathematics:
#
# [Philosopher(born=1886, died=1939, subjects_of_study='Foundations Of Mathematics, Formal System, Mereology, Protothetic', name='Stanislaw Lesniewski', birth_country='Russia')]
#
# Absolute Spirit:
#
# [Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany')]
#
# Philosophy Of Language:
#
# [Philosopher(born=570, died=651, subjects_of_study='Philosophy Of Language, Shabdadvaita', name='Bhartrihari', birth_country='India')]
#
# Neutral Monism:
#
# [Philosopher(born=1711, died=1776, subjects_of_study='England, Miracle, Idea, Neutral Monism, Causation', name='David Hume', birth_country='Scotland'), Philosopher(born=1842, died=1910, subjects_of_study='Religious Experience, Psychology, Neutral Monism, Free Will, Religious Belief', name='William James', birth_country='New York')]
#
# Venn Diagram:
#
# [Philosopher(born=1834, died=1923, subjects_of_study='Probability Theory, Venn Diagram, Categorical Proposition, Syllogism', name='John Venn', birth_country='England')]
#
# Enlightenment:
#
# [Philosopher(born=1872, died=1950, subjects_of_study='Yoga, Moksha, Enlightenment', name='Shri Aurobindo', birth_country='India')]
#
# Culture:
#
# [Philosopher(born=1880, died=1936, subjects_of_study='Culture', name='Oswald Spengler', birth_country='Germany')]
#
# Prescriptive Grammar:
#
# [Philosopher(born=1922, died=2009, subjects_of_study='Ethics, Prescriptive Grammar', name='Stephen Edelston Toulmin', birth_country='England')]
#
# Thomism:
#
# [Philosopher(born=1891, died=1942, subjects_of_study='Phenomenology, Thomism', name='Edith Stein', birth_country='Poland'), Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy'), Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France')]
#
# Moksha:
#
# [Philosopher(born=1872, died=1950, subjects_of_study='Yoga, Moksha, Enlightenment', name='Shri Aurobindo', birth_country='India')]
#
# Shintō:
#
# [Philosopher(born=1583, died=1657, subjects_of_study='Shintō, Zhu Xi, Neo-Confucianism', name='Hayashi Razan', birth_country='Japan')]
#
# Scientific Theory:
#
# [Philosopher(born=1905, died=1997, subjects_of_study='Philosophy Of Science, Scientific Theory, Covering-Law Model', name='Carl Gustav Hempel', birth_country='Germany')]
#
# Wu:
#
# [Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China')]
#
# Time:
#
# [Philosopher(born=1859, died=1941, subjects_of_study='Evolution, Time, Human Intelligence, Memory, Instinct', name='Henri Bergson', birth_country='France')]
#
# Aristotelianism:
#
# ...
#
# Pi:
#
# [Philosopher(born=1728, died=1777, subjects_of_study='Light, Measurement, Pi, Hyperbolic Functions, Irrational Number', name='Johann Heinrich Lambert', birth_country='Alsace')]
#
# Saint:
#
# [Philosopher(born=1882, died=1973, subjects_of_study='Thomas Aquinas, Saint', name='Jacques Maritain', birth_country='France')]
#
# Suddhadvaita:
#
# [Philosopher(born=1479, died=1531, subjects_of_study='Suddhadvaita', name='Vallabha', birth_country='India')]
#
# Spinor Equation:
#
# [Philosopher(born=1901, died=1976, subjects_of_study='Uncertainty Principle, Complementarity Principle, Matrix Mechanics, Spinor Equation', name='Werner Heisenberg', birth_country='Germany')]
#
# Spiritualism:
#
# [Philosopher(born=1866, died=1952, subjects_of_study='Political Philosophy, Philosophy Of History, Spiritualism', name='Benedetto Croce', birth_country='Italy')]
#
# Kantianism:
#
# [Philosopher(born=1809, died=1884, subjects_of_study='Protestantism, Kantianism', name='Isaak August Dorner', birth_country='Germany')]
#
# Idealism:
#
# [Philosopher(born=1808, died=1889, subjects_of_study='Judaism, Idealism', name='Solomon Formstecher', birth_country='Germany')]
#
# Biquaternion:
#
# [Philosopher(born=1845, died=1879, subjects_of_study='Tribal Self, Biquaternion', name='William Kingdon Clifford', birth_country='England')]
#
# Revelation:
#
# [Philosopher(born=1692, died=1752, subjects_of_study='Ethics, Revelation, Religion', name='Joseph Butler', birth_country='England')]
#
# Dark Learning:
#
# [Philosopher(born=226, died=249, subjects_of_study='Emotion, “Yijing”, “Tao-Te Ching”, Dark Learning', name='Wang Bi', birth_country='China'), Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China')]
#
# Natural Law:
#
# [Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England'), Philosopher(born=1150, died=1231, subjects_of_study='Theology, Natural Law, Free Will, Liturgy', name='William of Auxerre', birth_country='France')]
#
# Logic:
#
# [Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1901, died=1985, subjects_of_study='Logic, Scientific Method', name='Ernest Nagel', birth_country='Czechoslovakia'), Philosopher(born=1866, died=1942, subjects_of_study='Buddhism, Indian Philosophy, Logic', name='Fyodor Ippolitovich Shcherbatskoy', birth_country='Poland'), Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France'), Philosopher(born=1868, died=1914, subjects_of_study='Logic, Gottfried Wilhelm Leibniz, Formal System, International Language', name='Louis-Alexandre Couturat', birth_country='France'), Philosopher(born=1372, died=1429, subjects_of_study='Logic', name='Paul of Venice', birth_country='Udine')]
#
# Thirteen Articles Of Faith:
#
# [Philosopher(born=1135, died=1204, subjects_of_study='Judaism, Medicine, Philosophy Of Religion, Hebraic Law, Thirteen Articles Of Faith', name='Moses Maimonides', birth_country='Spain')]
#
# Authority:
#
# [Philosopher(born=1243, died=1316, subjects_of_study='Aristotelianism, Scholasticism, Papacy, Thomism, Authority', name='Giles of Rome', birth_country='Italy'), Philosopher(born=1805, died=1900, subjects_of_study='Unitarianism, Authority, Religion, Conscience', name='James Martineau', birth_country='England'), Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France')]
#
# Ethical Relativism:
#
# [Philosopher(born=1862, died=1939, subjects_of_study='Primitive Culture, Marriage, Ethical Relativism, Morality', name='Edward Westermarck', birth_country='Finland')]
#
# Methodology:
#
# [Philosopher(born=1852, died=1949, subjects_of_study='Economics, Deduction, Induction, Methodology', name='John Neville Keynes', birth_country='England'), Philosopher(born=1833, died=1911, subjects_of_study='Social Science, Humanities, Methodology', name='Wilhelm Dilthey', birth_country='Germany')]
#
# Rainbow:
#
# [Philosopher(born=1220, died=1292, subjects_of_study='Light, Gunpowder, Eyeglasses, Rainbow, Empirical Method', name='Roger Bacon', birth_country='England')]
#
# Reform Judaism:
#
# [Philosopher(born=1815, died=1889, subjects_of_study='Judaism, Philosophy Of Religion, Reform Judaism', name='Samuel Hirsch', birth_country='Germany')]
#
# Upanishad:
#
# [Philosopher(born=700, died=750, subjects_of_study='Upanishad, “Brahma-Sutra-Bhashya”', name='Shankara', birth_country='India')]
#
# Behaviour:
#
# [Philosopher(born=1887, died=1975, subjects_of_study='Evolution, Taxonomy, Embryo, Behaviour', name='Julian Huxley', birth_country='England')]
#
# Criterion Of Falsifiability:
#
# [Philosopher(born=1902, died=1994, subjects_of_study='Scientific Method, Criterion Of Falsifiability, Induction', name='Karl Popper', birth_country='Austria')]
#
# Neoorthodoxy:
#
# [Philosopher(born=1892, died=1971, subjects_of_study='Protestantism, Socialism, Pacifism, Neoorthodoxy', name='Reinhold Niebuhr', birth_country='Missouri')]
#
# Epicurus:
#
# [Philosopher(born=1592, died=1655, subjects_of_study='Epicurus', name='Pierre Gassendi', birth_country='France')]
#
# Alchemy:
#
# [Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=1575, died=1624, subjects_of_study='Mysticism, Alchemy, Paracelsus, Dialectic, Free Will', name='Jakob Bohme', birth_country='Germany')]
#
# Witch Of Agnesi:
#
# [Philosopher(born=1718, died=1799, subjects_of_study='Witch Of Agnesi', name='Maria Gaetana Agnesi', birth_country='Italy')]
#
# Absolute Idealism:
#
# [Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany')]
#
# Philosophy Of Nature:
#
# [Philosopher(born=1571, died=1640, subjects_of_study='Mysticism, Ishrāqīyah, Philosophy Of Nature', name='Mulla Sadra', birth_country='Iran')]
#
# Dialectic:
#
# [Philosopher(born=1808, died=1874, subjects_of_study='Rationalism, Religion, Dialectic', name='David Friedrich Strauss', birth_country='Germany'), Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'), Philosopher(born=1575, died=1624, subjects_of_study='Mysticism, Alchemy, Paracelsus, Dialectic, Free Will', name='Jakob Bohme', birth_country='Germany'), Philosopher(born=1861, died=1949, subjects_of_study='Dialectic', name='Maurice Blondel', birth_country='France')]
#
# Education:
#
# [Philosopher(born=1861, died=1947, subjects_of_study='Education, Mathematics, Philosophy Of Science, Formal Logic, Materialism', name='Alfred North Whitehead', birth_country='England'), Philosopher(born=1715, died=1771, subjects_of_study='Education', name='Claude-Adrien Helvetius', birth_country='France'), Philosopher(born=1905, died=1998, subjects_of_study='Education, Philosophy Of Education, Psychology', name='Harry S. Broudy', birth_country='Poland')]
#
# Electricity:
#
# [Philosopher(born=1821, died=1894, subjects_of_study='Electricity, Sound, Wave, Non-Euclidean Geometry, Conservation Of Energy', name='Hermann von Helmholtz', birth_country='Germany'), Philosopher(born=1733, died=1804, subjects_of_study='Electricity, Gas, Atmosphere, Photosynthesis, Oxide', name='Joseph Priestley', birth_country='England')]
#
# Elementary Education:
#
# [Philosopher(born=1762, died=1814, subjects_of_study='Germany, Secondary Education, Elementary Education, Ego, Practical Reason', name='Johann Gottlieb Fichte', birth_country='Germany'), Philosopher(born=1902, died=2001, subjects_of_study='Secondary Education, Adult Education, Elementary Education, Liberal Arts, Paideia', name='Mortimer J. Adler', birth_country='New York')]
#
# Feeling:
#
# [Philosopher(born=1714, died=1762, subjects_of_study='Aesthetics, Gottfried Wilhelm Leibniz, Feeling, Christian, Baron Von Wolff', name='Alexander Gottlieb Baumgarten', birth_country='Germany')]
#
# Star:
#
# [Philosopher(born=1882, died=1944, subjects_of_study='Star, Relativity, Globular Cluster, Physical Constant, Special Relativity', name='Arthur Stanley Eddington', birth_country='England')]
#
# Church And State:
#
# [Philosopher(born=1548, died=1617, subjects_of_study='Church And State, Theocracy', name='Francisco Suarez', birth_country='Spain'), Philosopher(born=1255, died=1306, subjects_of_study='Papacy, Thomism, Authority, Church And State, Eucharist', name='John of Paris', birth_country='France'), Philosopher(born=1588, died=1679, subjects_of_study='Sovereignty, Natural Law, Church And State, Absolutism, Social Contract', name='Thomas Hobbes', birth_country='England')]
#
# Confucianism:
#
# [Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=1613, died=1682, subjects_of_study='Confucianism', name='Gu Yanwu', birth_country='China'), Philosopher(born=193, died=249, subjects_of_study='Daoism, Confucianism, Wuwei, Wu, Qingtan', name='He Yan', birth_country='China'), Philosopher(born=772, died=841, subjects_of_study='Confucianism', name='Li Ao', birth_country='China'), Philosopher(born=1658, died=1734, subjects_of_study='Confucianism, Zhu Xi', name='Muro Kyuso', birth_country='Japan'), Philosopher(born=27, died=100, subjects_of_study='Confucianism, Rationalism, Naturalism', name='Wang Chong', birth_country='China'), Philosopher(born=1635, died=1704, subjects_of_study='Confucianism', name='Yan Yuan', birth_country='China'), Philosopher(born=1017, died=1073, subjects_of_study='Confucianism, Dark Learning', name='Zhou Dunyi', birth_country='China')]
#
# Humanism:
#
# [Philosopher(born=1568, died=1639, subjects_of_study='Roman Catholicism, Metaphysics, Humanism, Pragmatism', name='Tommaso Campanella', birth_country='Kingdom of Naples')]
#
# Abduction:
#
# [Philosopher(born=1839, died=1914, subjects_of_study='Category, Induction, Abduction', name='Charles Sanders Peirce', birth_country='Massachusetts')]
#
# Cultural Determinism:
#
# [Philosopher(born=1756, died=1836, subjects_of_study='Individualism, Cultural Determinism', name='William Godwin', birth_country='England')]
#
# Latin Language:
#
# [Philosopher(born=1407, died=1457, subjects_of_study='Latin Language, Grammar, Donation Of Constantine', name='Lorenzo Valla', birth_country='Italy')]
#
# Essence:
#
# [Philosopher(born=1863, died=1952, subjects_of_study='Skepticism, Poetry, Faith, Reason, Essence', name='George Santayana', birth_country='Spain')]
#
# Capitalism:
#
# [Philosopher(born=1818, died=1883, subjects_of_study='Philosophy Of History, Capitalism, Use Value, Exchange Value', name='Karl Marx', birth_country='Germany')]
#
# Photosynthesis:
#
# [Philosopher(born=1733, died=1804, subjects_of_study='Electricity, Gas, Atmosphere, Photosynthesis, Oxide', name='Joseph Priestley', birth_country='England')]
#
# Adolf Eichmann:
#
# [Philosopher(born=1906, died=1975, subjects_of_study='Anti-Semitism, Adolf Eichmann, Totalitarianism, Trial', name='Hannah Arendt', birth_country='Germany')]
#
# Social Interaction:
#
# [Philosopher(born=1858, died=1918, subjects_of_study='Economics, Money, Human Being, Social Interaction', name='Georg Simmel', birth_country='Germany'), Philosopher(born=1863, died=1931, subjects_of_study='Language, Social Interaction', name='George Herbert Mead', birth_country='Massachusetts')]
#
# Language Game:
#
# [Philosopher(born=1889, died=1951, subjects_of_study='Picture Theory Of Meaning, Proposition, Language Game, Certainty', name='Ludwig Wittgenstein', birth_country='Austria')]
#
# Matter:
#
# [Philosopher(born=1620, died=1684, subjects_of_study='Animal Magnetism, Matter', name='Geraud de Cordemoy', birth_country='France')]
#
# Economic Theory:
#
# [Philosopher(born=1420, died=1495, subjects_of_study='Scholasticism, Political Economy, William Of Ockham, Economic Theory', name='Gabriel Biel', birth_country='Speyer')]
#
# Geist:
#
# [Philosopher(born=1770, died=1831, subjects_of_study='Rationalism, Absolute Idealism, Dialectic, Absolute Spirit, Geist', name='Georg Wilhelm Friedrich Hegel', birth_country='Germany'), Philosopher(born=1872, died=1956, subjects_of_study='Geist', name='Ludwig Klages', birth_country='Germany')]
#
# Absolute:
#
# [Philosopher(born=1775, died=1854, subjects_of_study='Ego, Consciousness, Free Will, Absolute', name='Friedrich Wilhelm Joseph von Schelling', birth_country='Germany')]
#
# Category:
#
# [Philosopher(born=1839, died=1914, subjects_of_study='Category, Induction, Abduction', name='Charles Sanders Peirce', birth_country='Massachusetts'), Philosopher(born=1724, died=1804, subjects_of_study='Political Philosophy, Immortality, Existence Of God, Teleology, Category', name='Immanuel Kant', birth_country='Prussia')]
#
# Optics:
#
# [Philosopher(born=1300, died=1358, subjects_of_study='Optics, Logic, Motion', name='Jean Buridan', birth_country='France')]
#
# Agriculture:
#
# [Philosopher(born=1856, died=1922, subjects_of_study='Agriculture, Zionism', name='Aaron David Gordon', birth_country='Ukraine')]
#
# Progressive Education:
#
# [Philosopher(born=1859, died=1952, subjects_of_study='Philosophy Of Education, Progressive Education', name='John Dewey', birth_country='Vermont')]
#
# Verifiability Principle:
#
# [Philosopher(born=1891, died=1970, subjects_of_study='Formal Logic, Probability Theory, A Priori Knowledge, Verifiability Principle, Analytic Proposition', name='Rudolf Carnap', birth_country='Germany')]
#
# Phenomenon:
#
# [Philosopher(born=1878, died=1959, subjects_of_study='Phenomenon', name='Armando Carlini', birth_country='Italy')]
#
# Aesthetics:
#
# [Philosopher(born=1714, died=1762, subjects_of_study='Aesthetics, Gottfried Wilhelm Leibniz, Feeling, Christian, Baron Von Wolff', name='Alexander Gottlieb Baumgarten', birth_country='Germany'), Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=1721, died=1790, subjects_of_study='Aesthetics, Rationalism, Sensationalism', name='Franciscus Hemsterhuis', birth_country='Netherlands'), Philosopher(born=1892, died=1940, subjects_of_study='Aesthetics, Literature', name='Walter Benjamin', birth_country='Germany')]
#
# Ethics:
#
# [Philosopher(born=1848, died=1923, subjects_of_study='Ethics, Metaphysics, Aesthetics, Political Philosophy, Logic', name='Bernard Bosanquet', birth_country='England'), Philosopher(born=283, died=343, subjects_of_study='Ethics, Daoism, Confucianism, Alchemy', name='Ge Hong', birth_country='China'), Philosopher(born=1838, died=1900, subjects_of_study='Ethics, Utilitarianism, Egoism, Categorical Imperative, Intuitionism', name='Henry Sidgwick', birth_country='England'), Philosopher(born=1692, died=1752, subjects_of_study='Ethics, Revelation, Religion', name='Joseph Butler', birth_country='England'), Philosopher(born=1450, died=1524, subjects_of_study='Ethics', name='Marko Marulic', birth_country='Split'), Philosopher(born=1874, died=1928, subjects_of_study='Ethics, Value', name='Max Scheler', birth_country='Germany'), Philosopher(born=1859, died=1938, subjects_of_study='Ethics, Evolution, Space-Time', name='Samuel Alexander', birth_country='Australia'), Philosopher(born=1922, died=2009, subjects_of_study='Ethics, Prescriptive Grammar', name='Stephen Edelston Toulmin', birth_country='England'), Philosopher(born=1889, died=1960, subjects_of_study='Ethics, Buddhism, Existentialism', name='Watsuji Tetsuro', birth_country='Japan'), Philosopher(born=1743, died=1805, subjects_of_study='Ethics, Utilitarianism, Argument From Design', name='William Paley', birth_country='England')]
#
# Historical Jurisprudence:
#
# [Philosopher(born=1841, died=1921, subjects_of_study='Devolution, Pluralism, Historical Jurisprudence', name='Otto Friedrich von Gierke', birth_country='Prussia')]

# %% [markdown]
# ## Parallel Processing with Functional Programming

# %% [markdown]
# ### Multiprocessing

# %%
# Simple example; if this involved I/O wait or intense computations
def transform(x):
    return {"name": x.name, "age": x.died - x.born}

result = tuple(map(
    transform,
    philosophers
))

result
# Out:
# ({'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53})

# %%
# %%time
import time 


def transform(x):
    print(f"Processing philosopher: {x.name}")
    time.sleep(.01)
    return {"name": x.name, "age": x.died - x.born}

result = tuple(map(
    transform,
    philosophers
))

result
# Out:
# Processing philosopher: Aaron David Gordon
# Processing philosopher: Abraham Joshua Heschel
# Processing philosopher: Albert of Saxony
# Processing philosopher: Alessandro Achillini
# Processing philosopher: Alexander Gottlieb Baumgarten
# Processing philosopher: Alexius Meinong
# Processing philosopher: Alfred Firmin Loisy
# Processing philosopher: Alfred Korzybski
# Processing philosopher: Alfred North Whitehead
# Processing philosopher: Allan Bloom
# Processing philosopher: Anicius Manlius Severinus Boethius
# Processing philosopher: Antonio Labriola
# Processing philosopher: Antonio Rosmini-Serbati
# Processing philosopher: Antony Flew
# Processing philosopher: Armando Carlini
# Processing philosopher: Arthur O. Lovejoy
# Processing philosopher: Arthur Schopenhauer
# Processing philosopher: Arthur Stanley Eddington
# Processing philosopher: Ashvaghosha
# Processing philosopher: Auguste Comte
# Processing philosopher: Averroes
# Processing philosopher: Avicenna
# Processing philosopher: Bartolome de Medina
# Processing philosopher: Benedetto Croce
# Processing philosopher: Benedict de Spinoza
# Processing philosopher: Bernard Bosanquet
# Processing philosopher: Bernard de Mandeville
# Processing philosopher: Bertrand Russell
# Processing philosopher: Bessarion
# Processing philosopher: Bhartrihari
# Processing philosopher: Blaise Pascal
# Processing philosopher: Blessed John Duns Scotus
# Processing philosopher: Carl Gustav Hempel
# Processing philosopher: Charles Sanders Peirce
# Processing philosopher: Cheng Hao
# Processing philosopher: Cheng Yi
# Processing philosopher: Claude-Adrien Helvetius
# Processing philosopher: David Friedrich Strauss
# Processing philosopher: David Hartley
# Processing philosopher: David Hume
# Processing philosopher: David Ross
# Processing philosopher: Denis Diderot
# Processing philosopher: Derek Parfit
# Processing philosopher: Edith Stein
# Processing philosopher: Edmund Husserl
# Processing philosopher: Eduard von Hartmann
# Processing philosopher: Edward Caird
# Processing philosopher: Edward Westermarck
# Processing philosopher: Emmanuel Levinas
# Processing philosopher: Erich Frank
# Processing philosopher: Erich Fromm
# Processing philosopher: Ernest Nagel
# Processing philosopher: Ernest Renan
# Processing philosopher: Ernst Mach
# Processing philosopher: Ernst Troeltsch
# Processing philosopher: Erwin Schrodinger
# Processing philosopher: Etienne Bonnot de Condillac
# Processing philosopher: Etienne Gilson
# Processing philosopher: Ferdinand Christian Baur
# Processing philosopher: Francis Hutcheson
# Processing philosopher: Francisco Suarez
# Processing philosopher: Franciscus Hemsterhuis
# Processing philosopher: Franz Brentano
# Processing philosopher: Franz Rosenzweig
# Processing philosopher: Frederick Robert Tennant
# Processing philosopher: Friedrich Nietzsche
# Processing philosopher: Friedrich Schleiermacher
# Processing philosopher: Friedrich Theodor von Vischer
# Processing philosopher: Friedrich Wilhelm Joseph von Schelling
# Processing philosopher: Fritz Mauthner
# Processing philosopher: Fyodor Ippolitovich Shcherbatskoy
# Processing philosopher: Gabriel Biel
# Processing philosopher: Gaston Frommel
# Processing philosopher: Ge Hong
# Processing philosopher: Gennadios II Scholarios
# Processing philosopher: Georg Bernhard Bilfinger
# Processing philosopher: Georg Brandes
# Processing philosopher: Georg Simmel
# Processing philosopher: Georg Wilhelm Friedrich Hegel
# Processing philosopher: George Berkeley
# Processing philosopher: George Gemistus Plethon
# Processing philosopher: George Grant
# Processing philosopher: George Henry Lewes
# Processing philosopher: George Herbert Mead
# Processing philosopher: George Santayana
# Processing philosopher: George Trumbull Ladd
# Processing philosopher: George Tyrrell
# Processing philosopher: Geraud de Cordemoy
# Processing philosopher: Giambattista Vico
# Processing philosopher: Giles of Rome
# Processing philosopher: Gilles Deleuze
# Processing philosopher: Gottfried Wilhelm Leibniz
# Processing philosopher: Gotthold Ephraim Lessing
# Processing philosopher: Gottlob Frege
# Processing philosopher: Gregory of Rimini
# Processing philosopher: Gu Yanwu
# Processing philosopher: Gustav Theodor Fechner
# Processing philosopher: Hajji Hadi Sabzevari
# Processing philosopher: Hannah Arendt
# Processing philosopher: Hans Reichenbach
# Processing philosopher: Hans-Georg Gadamer
# Processing philosopher: Harry S. Broudy
# Processing philosopher: Hatano Seiichi
# Processing philosopher: Hayashi Razan
# Processing philosopher: He Yan
# Processing philosopher: Hemachandra
# Processing philosopher: Henri Bergson
# Processing philosopher: Henri Berr
# Processing philosopher: Henri Poincare
# Processing philosopher: Henry Longueville Mansel
# Processing philosopher: Henry Sidgwick
# Processing philosopher: Herbert Spencer
# Processing philosopher: Hermann Cohen
# Processing philosopher: Hermann Samuel Reimarus
# Processing philosopher: Hermann von Helmholtz
# Processing philosopher: Hilary Putnam
# Processing philosopher: Ibn Falaquera
# Processing philosopher: Ibn Gabirol
# Processing philosopher: Immanuel Kant
# Processing philosopher: Inoue Tetsujiro
# Processing philosopher: Isaac of Stella
# Processing philosopher: Isaak August Dorner
# Processing philosopher: Ito Jinsai
# Processing philosopher: Jacob Moleschott
# Processing philosopher: Jacques Derrida
# Processing philosopher: Jacques Maritain
# Processing philosopher: Jaime Luciano Balmes
# Processing philosopher: Jakob Bohme
# Processing philosopher: James Frederick Ferrier
# Processing philosopher: James J. Gibson
# Processing philosopher: James Mark Baldwin
# Processing philosopher: James Martineau
# Processing philosopher: Jean Baudrillard
# Processing philosopher: Jean Buridan
# Processing philosopher: Jean-Jacques Rousseau
# Processing philosopher: Jean-Paul Sartre
# Processing philosopher: Jeremy Bentham
# Processing philosopher: Joachim Wach
# Processing philosopher: Johann Gottlieb Fichte
# Processing philosopher: Johann Heinrich Lambert
# Processing philosopher: John Baconthorpe
# Processing philosopher: John Dewey
# Processing philosopher: John Fiske
# Processing philosopher: John Langshaw Austin
# Processing philosopher: John Locke
# Processing philosopher: John Neville Keynes
# Processing philosopher: John Scott Haldane
# Processing philosopher: John Scotus Erigena
# Processing philosopher: John Stuart Mill
# Processing philosopher: John Venn
# Processing philosopher: John Wycliffe
# Processing philosopher: John of Paris
# Processing philosopher: John of Salisbury
# Processing philosopher: Jonathan Edwards
# Processing philosopher: Jose Ortega y Gasset
# Processing philosopher: Jose Vasconcelos
# Processing philosopher: Joseph Butler
# Processing philosopher: Joseph Priestley
# Processing philosopher: Josiah Royce
# Processing philosopher: Julian Huxley
# Processing philosopher: Justus Lipsius
# Processing philosopher: Karl Jaspers
# Processing philosopher: Karl Marx
# Processing philosopher: Karl Popper
# Processing philosopher: Kumazawa Banzan
# Processing philosopher: Leopold Kronecker
# Processing philosopher: Levi ben Gershom
# Processing philosopher: Li Ao
# Processing philosopher: Liang Shuming
# Processing philosopher: Lorenzo Valla
# Processing philosopher: Louis Althusser
# Processing philosopher: Louis Lavelle
# Processing philosopher: Louis-Alexandre Couturat
# Processing philosopher: Lu Jiuyuan
# Processing philosopher: Lucien Levy-Bruhl
# Processing philosopher: Ludwig Klages
# Processing philosopher: Ludwig Wittgenstein
# Processing philosopher: Madhva
# Processing philosopher: Maria Gaetana Agnesi
# Processing philosopher: Marie-Francois-Pierre Maine de Biran
# Processing philosopher: Marin Mersenne
# Processing philosopher: Marjorie Grene
# Processing philosopher: Marko Marulic
# Processing philosopher: Marsilio Ficino
# Processing philosopher: Maurice Blondel
# Processing philosopher: Maurice Merleau-Ponty
# Processing philosopher: Max Black
# Processing philosopher: Max Scheler
# Processing philosopher: Max Stirner
# Processing philosopher: Michel Foucault
# Processing philosopher: Moritz Lazarus
# Processing philosopher: Mortimer J. Adler
# Processing philosopher: Moses Maimonides
# Processing philosopher: Moses Mendelssohn
# Processing philosopher: Mulla Sadra
# Processing philosopher: Muro Kyuso
# Processing philosopher: Nathanael Culverwel
# Processing philosopher: Nicholas of Cusa
# Processing philosopher: Nikolay Yakovlevich Danilevsky
# Processing philosopher: Nishida Kitaro
# Processing philosopher: Norman Robert Campbell
# Processing philosopher: Oswald Kulpe
# Processing philosopher: Oswald Spengler
# Processing philosopher: Otto Friedrich von Gierke
# Processing philosopher: Otto Neurath
# Processing philosopher: Paul Shorey
# Processing philosopher: Paul Tillich
# Processing philosopher: Paul of Venice
# Processing philosopher: Pierre Bayle
# Processing philosopher: Pierre Gassendi
# Processing philosopher: Pierre Laromiguiere
# Processing philosopher: Pierre Leroux
# Processing philosopher: Pierre Nicole
# Processing philosopher: Pierre Teilhard de Chardin
# Processing philosopher: Pierre-Felix Guattari
# Processing philosopher: Pietro Pomponazzi
# Processing philosopher: Raghunatha Shiromani
# Processing philosopher: Ramana Maharshi
# Processing philosopher: Ramanuja
# Processing philosopher: Ramon Llull
# Processing philosopher: Reinhold Niebuhr
# Processing philosopher: Rene Descartes
# Processing philosopher: Richard Hooker
# Processing philosopher: Richard Price
# Processing philosopher: Robert Boyle
# Processing philosopher: Robert Grosseteste
# Processing philosopher: Roger Bacon
# Processing philosopher: Rudolf Bultmann
# Processing philosopher: Rudolf Carnap
# Processing philosopher: Rudolf Otto
# Processing philosopher: Salomon Maimon
# Processing philosopher: Samuel Alexander
# Processing philosopher: Samuel Bailey
# Processing philosopher: Samuel Hirsch
# Processing philosopher: Shankara
# Processing philosopher: Shao Yong
# Processing philosopher: Shri Aurobindo
# Processing philosopher: Sidney Hook
# Processing philosopher: Simon Foucher
# Processing philosopher: Simone Weil
# Processing philosopher: Solomon Formstecher
# Processing philosopher: Soren Kierkegaard
# Processing philosopher: Stanislaw Lesniewski
# Processing philosopher: Stephen Edelston Toulmin
# Processing philosopher: Susanne K. Langer
# Processing philosopher: Taixu
# Processing philosopher: Tao Sheng
# Processing philosopher: Theodor Gomperz
# Processing philosopher: Theodor Wiesengrund Adorno
# Processing philosopher: Theodosius Dobzhansky
# Processing philosopher: Thomas Henry Huxley
# Processing philosopher: Thomas Hobbes
# Processing philosopher: Thomas Reid
# Processing philosopher: Tommaso Campanella
# Processing philosopher: Uriel Acosta
# Processing philosopher: Vallabha
# Processing philosopher: Vladimir Sergeyevich Solovyov
# Processing philosopher: Walter Benjamin
# Processing philosopher: Wang Bi
# Processing philosopher: Wang Chong
# Processing philosopher: Wang Yangming
# Processing philosopher: Watsuji Tetsuro
# Processing philosopher: Werner Heisenberg
# Processing philosopher: Wilfrid Sellars
# Processing philosopher: Wilhelm Dilthey
# Processing philosopher: Willard Van Orman Quine
# Processing philosopher: William Godwin
# Processing philosopher: William James
# Processing philosopher: William Kingdon Clifford
# Processing philosopher: William Paley
# Processing philosopher: William Ralph Inge
# Processing philosopher: William Whewell
# Processing philosopher: William of Auxerre
# Processing philosopher: William of Champeaux
# Processing philosopher: William of Ockham
# Processing philosopher: Xiong Shili
# Processing philosopher: Yan Yuan
# Processing philosopher: Zhang Zai
# Processing philosopher: Zhou Dunyi
# Processing philosopher: Zhu Xi
# Processing philosopher: al-Farabi
# Processing philosopher: al-Ghazali
# CPU times: user 68.8 ms, sys: 20.1 ms, total: 88.8 ms
# Wall time: 3.35 s
# ({'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53})

# %% [markdown]
# Why do we care? The fact that we wrote in a  functional style, we can leverage parralelism

# %%
# %%time
import multiprocess

def transform(x):
    print(f"Processing philosopher: {x.name}")
    time.sleep(.01)
    return {"name": x.name, "age": x.died - x.born}

pool = multiprocess.Pool()

result = pool.map(transform, philosophers)

result
# Out:
# Processing philosopher: Aaron David Gordon
# Processing philosopher: Alfred North WhiteheadProcessing philosopher: Benedict de SpinozaProcessing philosopher: Arthur Schopenhauer
# Processing philosopher: Carl Gustav HempelProcessing philosopher: Emmanuel LevinasProcessing philosopher: Frederick Robert TennantProcessing philosopher: Etienne Bonnot de Condillac
# Processing philosopher: David Ross
#
#
# Processing philosopher: Gaston Frommel
#
#
#
# Processing philosopher: Abraham Joshua HeschelProcessing philosopher: Allan BloomProcessing philosopher: Charles Sanders Peirce
# Processing philosopher: Erich FrankProcessing philosopher: Arthur Stanley EddingtonProcessing philosopher: Friedrich NietzscheProcessing philosopher: Bernard BosanquetProcessing philosopher: Denis DiderotProcessing philosopher: Etienne Gilson
# Processing philosopher: Ge Hong
#
#
#
#
#
#
#
# Processing philosopher: Albert of Saxony
# Processing philosopher: Friedrich SchleiermacherProcessing philosopher: AshvaghoshaProcessing philosopher: Derek ParfitProcessing philosopher: Erich FrommProcessing philosopher: Cheng HaoProcessing philosopher: Anicius Manlius Severinus BoethiusProcessing philosopher: Bernard de MandevilleProcessing philosopher: Gennadios II Scholarios
# Processing philosopher: Ferdinand Christian Baur
#
#
#
#
#
#
#
# Processing philosopher: Alessandro Achillini
# Processing philosopher: Bertrand RussellProcessing philosopher: Cheng YiProcessing philosopher: Auguste ComteProcessing philosopher: Antonio LabriolaProcessing philosopher: Friedrich Theodor von VischerProcessing philosopher: Edith SteinProcessing philosopher: Ernest NagelProcessing philosopher: Georg Bernhard Bilfinger
# Processing philosopher: Francis Hutcheson
#
#
#
#
#
#
#
# Processing philosopher: Alexander Gottlieb Baumgarten
# Processing philosopher: Edmund HusserlProcessing philosopher: BessarionProcessing philosopher: Antonio Rosmini-SerbatiProcessing philosopher: Georg BrandesProcessing philosopher: Claude-Adrien HelvetiusProcessing philosopher: AverroesProcessing philosopher: Ernest RenanProcessing philosopher: Francisco SuarezProcessing philosopher: Friedrich Wilhelm Joseph von Schelling
#
#
#
#
#
#
#
#
# Processing philosopher: Alexius Meinong
# Processing philosopher: Eduard von HartmannProcessing philosopher: BhartrihariProcessing philosopher: Antony FlewProcessing philosopher: Ernst MachProcessing philosopher: David Friedrich StraussProcessing philosopher: Georg SimmelProcessing philosopher: Franciscus HemsterhuisProcessing philosopher: Fritz MauthnerProcessing philosopher: Avicenna
#
#
#
#
#
#
#
#
# Processing philosopher: Alfred Firmin Loisy
# Processing philosopher: Armando CarliniProcessing philosopher: Blaise PascalProcessing philosopher: Franz BrentanoProcessing philosopher: David HartleyProcessing philosopher: Ernst TroeltschProcessing philosopher: Georg Wilhelm Friedrich HegelProcessing philosopher: Edward CairdProcessing philosopher: Fyodor Ippolitovich ShcherbatskoyProcessing philosopher: Bartolome de Medina
#
#
#
#
#
#
#
#
# Processing philosopher: Alfred Korzybski
# Processing philosopher: Franz RosenzweigProcessing philosopher: David HumeProcessing philosopher: Erwin SchrodingerProcessing philosopher: Blessed John Duns ScotusProcessing philosopher: Gabriel BielProcessing philosopher: George BerkeleyProcessing philosopher: Arthur O. LovejoyProcessing philosopher: Edward WestermarckProcessing philosopher: Benedetto Croce
#
#
#
#
#
#
#
#
# Processing philosopher: George Gemistus Plethon
# Processing philosopher: Giambattista VicoProcessing philosopher: Gustav Theodor FechnerProcessing philosopher: He YanProcessing philosopher: Hermann CohenProcessing philosopher: Isaac of StellaProcessing philosopher: James Frederick FerrierProcessing philosopher: John LockeProcessing philosopher: Jeremy BenthamProcessing philosopher: John of Salisbury
#
#
#
#
#
#
#
#
# Processing philosopher: George Grant
# Processing philosopher: Giles of RomeProcessing philosopher: Hajji Hadi SabzevariProcessing philosopher: Hermann Samuel ReimarusProcessing philosopher: HemachandraProcessing philosopher: Joachim WachProcessing philosopher: John Neville KeynesProcessing philosopher: Jonathan EdwardsProcessing philosopher: Isaak August DornerProcessing philosopher: James J. Gibson
#
#
#
#
#
#
#
# Processing philosopher: George Henry Lewes
#
# Processing philosopher: John Scott HaldaneProcessing philosopher: Ito JinsaiProcessing philosopher: Gilles DeleuzeProcessing philosopher: Hannah ArendtProcessing philosopher: Hermann von HelmholtzProcessing philosopher: Johann Gottlieb FichteProcessing philosopher: James Mark BaldwinProcessing philosopher: Jose Ortega y GassetProcessing philosopher: Henri BergsonProcessing philosopher: George Herbert Mead
#
#
#
#
#
#
#
#
#
# Processing philosopher: Hilary PutnamProcessing philosopher: Jacob MoleschottProcessing philosopher: John Scotus ErigenaProcessing philosopher: Henri BerrProcessing philosopher: Jose VasconcelosProcessing philosopher: Gottfried Wilhelm LeibnizProcessing philosopher: James MartineauProcessing philosopher: Johann Heinrich LambertProcessing philosopher: George SantayanaProcessing philosopher: Hans Reichenbach
#
#
#
#
#
#
#
#
#
# Processing philosopher: John Stuart MillProcessing philosopher: Joseph ButlerProcessing philosopher: Henri PoincareProcessing philosopher: Ibn FalaqueraProcessing philosopher: Jacques DerridaProcessing philosopher: Gotthold Ephraim LessingProcessing philosopher: George Trumbull LaddProcessing philosopher: Hans-Georg GadamerProcessing philosopher: Jean BaudrillardProcessing philosopher: John Baconthorpe
#
#
#
#
#
#
#
#
#
# Processing philosopher: Henry Longueville ManselProcessing philosopher: George TyrrellProcessing philosopher: Harry S. BroudyProcessing philosopher: Jacques MaritainProcessing philosopher: John DeweyProcessing philosopher: Ibn GabirolProcessing philosopher: Gottlob FregeProcessing philosopher: Joseph PriestleyProcessing philosopher: John VennProcessing philosopher: Jean Buridan
#
#
#
#
#
#
#
#
#
# Processing philosopher: Henry SidgwickProcessing philosopher: Jaime Luciano BalmesProcessing philosopher: Hatano SeiichiProcessing philosopher: Geraud de Cordemoy
# Processing philosopher: Gregory of RiminiProcessing philosopher: John WycliffeProcessing philosopher: Josiah Royce
# Processing philosopher: Jean-Jacques RousseauProcessing philosopher: Immanuel KantProcessing philosopher: John Fiske
#
#
#
#
#
#
#
# Processing philosopher: Herbert SpencerProcessing philosopher: Jakob Bohme
#
# Processing philosopher: Hayashi RazanProcessing philosopher: John of ParisProcessing philosopher: Gu YanwuProcessing philosopher: Julian HuxleyProcessing philosopher: Justus LipsiusProcessing philosopher: John Langshaw AustinProcessing philosopher: Inoue TetsujiroProcessing philosopher: Jean-Paul Sartre
#
#
#
#
#
#
#
# Processing philosopher: Liang ShumingProcessing philosopher: Ludwig Wittgenstein
#
# Processing philosopher: Maurice BlondelProcessing philosopher: Moses MaimonidesProcessing philosopher: Karl JaspersProcessing philosopher: Pierre BayleProcessing philosopher: Norman Robert CampbellProcessing philosopher: Raghunatha ShiromaniProcessing philosopher: Robert BoyleProcessing philosopher: Samuel Bailey
#
#
#
#
#
#
#
# Processing philosopher: MadhvaProcessing philosopher: Lorenzo Valla
#
# Processing philosopher: Maurice Merleau-PontyProcessing philosopher: Karl MarxProcessing philosopher: Moses MendelssohnProcessing philosopher: Ramana MaharshiProcessing philosopher: Pierre GassendiProcessing philosopher: Samuel HirschProcessing philosopher: Oswald Kulpe
# Processing philosopher: Robert Grosseteste
#
#
#
#
#
#
# Processing philosopher: Louis AlthusserProcessing philosopher: Maria Gaetana Agnesi
#
# Processing philosopher: Max BlackProcessing philosopher: Mulla SadraProcessing philosopher: RamanujaProcessing philosopher: Oswald SpenglerProcessing philosopher: Karl PopperProcessing philosopher: ShankaraProcessing philosopher: Roger BaconProcessing philosopher: Pierre Laromiguiere
#
#
#
#
#
#
#
# Processing philosopher: Louis LavelleProcessing philosopher: Marie-Francois-Pierre Maine de Biran
# Processing philosopher: Max SchelerProcessing philosopher: Ramon LlullProcessing philosopher: Muro KyusoProcessing philosopher: Pierre LerouxProcessing philosopher: Shao YongProcessing philosopher: Rudolf BultmannProcessing philosopher: Otto Friedrich von GierkeProcessing philosopher: Kumazawa Banzan
#
#
#
#
#
#
#
# Processing philosopher: Marin MersenneProcessing philosopher: Louis-Alexandre Couturat
#
# Processing philosopher: Max StirnerProcessing philosopher: Nathanael CulverwelProcessing philosopher: Reinhold NiebuhrProcessing philosopher: Shri AurobindoProcessing philosopher: Pierre NicoleProcessing philosopher: Rudolf CarnapProcessing philosopher: Otto NeurathProcessing philosopher: Leopold Kronecker
#
#
#
#
#
#
#
# Processing philosopher: Marjorie GreneProcessing philosopher: Lu Jiuyuan
#
# Processing philosopher: Michel FoucaultProcessing philosopher: Pierre Teilhard de ChardinProcessing philosopher: Rene DescartesProcessing philosopher: Sidney HookProcessing philosopher: Nicholas of CusaProcessing philosopher: Paul ShoreyProcessing philosopher: Levi ben GershomProcessing philosopher: Rudolf Otto
#
#
#
#
#
#
#
# Processing philosopher: Marko MarulicProcessing philosopher: Lucien Levy-Bruhl
#
# Processing philosopher: Richard HookerProcessing philosopher: Moritz LazarusProcessing philosopher: Simon FoucherProcessing philosopher: Nikolay Yakovlevich DanilevskyProcessing philosopher: Salomon MaimonProcessing philosopher: Paul TillichProcessing philosopher: Pierre-Felix Guattari
#
# Processing philosopher: Li Ao
#
#
#
#
#
# Processing philosopher: Ludwig KlagesProcessing philosopher: Marsilio Ficino
#
# Processing philosopher: Richard PriceProcessing philosopher: Pietro PomponazziProcessing philosopher: Mortimer J. AdlerProcessing philosopher: Simone WeilProcessing philosopher: Samuel AlexanderProcessing philosopher: Nishida KitaroProcessing philosopher: Paul of Venice
# Processing philosopher: Solomon Formstecher
#
#
#
#
#
#
# Processing philosopher: Theodor Wiesengrund AdornoProcessing philosopher: Vladimir Sergeyevich Solovyov
#
# Processing philosopher: Wilhelm DiltheyProcessing philosopher: William of AuxerreProcessing philosopher: al-Farabi
# Processing philosopher: Soren Kierkegaard
#
# Processing philosopher: Theodosius DobzhanskyProcessing philosopher: Walter Benjamin
#
#
# Processing philosopher: Willard Van Orman QuineProcessing philosopher: al-GhazaliProcessing philosopher: William of Champeaux
#
#
# Processing philosopher: Stanislaw LesniewskiProcessing philosopher: Thomas Henry HuxleyProcessing philosopher: Wang Bi
#
#
# Processing philosopher: William GodwinProcessing philosopher: William of OckhamProcessing philosopher: Stephen Edelston ToulminProcessing philosopher: Wang Chong
# Processing philosopher: Thomas Hobbes
#
#
#
# Processing philosopher: William JamesProcessing philosopher: Susanne K. LangerProcessing philosopher: Wang YangmingProcessing philosopher: Xiong ShiliProcessing philosopher: Thomas Reid
#
#
#
#
# Processing philosopher: Watsuji TetsuroProcessing philosopher: Yan YuanProcessing philosopher: William Kingdon CliffordProcessing philosopher: TaixuProcessing philosopher: Tommaso Campanella
#
#
#
#
# Processing philosopher: Werner HeisenbergProcessing philosopher: Zhang ZaiProcessing philosopher: Uriel AcostaProcessing philosopher: Tao ShengProcessing philosopher: William Paley
#
#
#
#
# Processing philosopher: Wilfrid SellarsProcessing philosopher: Zhou DunyiProcessing philosopher: VallabhaProcessing philosopher: Theodor GomperzProcessing philosopher: William Ralph Inge
#
#
#
#
# Processing philosopher: Zhu XiProcessing philosopher: William Whewell
#
# CPU times: user 127 ms, sys: 109 ms, total: 236 ms
# Wall time: 491 ms
# [{'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53}]

# %%
# %%time
import multiprocess
import os

def transform(x):
    print(f"Process ID {os.getpid()} is processing philosopher: {x.name}")
    time.sleep(.01)
    return {"name": x.name, "age": x.died - x.born}

pool = multiprocess.Pool()

result = pool.map(transform, philosophers)

result
# Out:
# Process ID 93443 is processing philosopher: Aaron David GordonProcess ID 93444 is processing philosopher: Alfred North WhiteheadProcess ID 93445 is processing philosopher: Arthur SchopenhauerProcess ID 93446 is processing philosopher: Benedict de SpinozaProcess ID 93447 is processing philosopher: Carl Gustav HempelProcess ID 93448 is processing philosopher: David RossProcess ID 93449 is processing philosopher: Emmanuel LevinasProcess ID 93450 is processing philosopher: Etienne Bonnot de CondillacProcess ID 93451 is processing philosopher: Frederick Robert Tennant
#
#
#
# Process ID 93452 is processing philosopher: Gaston Frommel
#
#
#
#
#
# Process ID 93443 is processing philosopher: Abraham Joshua HeschelProcess ID 93444 is processing philosopher: Allan BloomProcess ID 93445 is processing philosopher: Arthur Stanley EddingtonProcess ID 93449 is processing philosopher: Erich FrankProcess ID 93450 is processing philosopher: Etienne GilsonProcess ID 93448 is processing philosopher: Denis DiderotProcess ID 93447 is processing philosopher: Charles Sanders PeirceProcess ID 93446 is processing philosopher: Bernard BosanquetProcess ID 93451 is processing philosopher: Friedrich NietzscheProcess ID 93452 is processing philosopher: Ge Hong
#
#
#
#
#
#
#
#
#
# Process ID 93447 is processing philosopher: Cheng HaoProcess ID 93449 is processing philosopher: Erich FrommProcess ID 93445 is processing philosopher: AshvaghoshaProcess ID 93450 is processing philosopher: Ferdinand Christian BaurProcess ID 93448 is processing philosopher: Derek ParfitProcess ID 93443 is processing philosopher: Albert of SaxonyProcess ID 93444 is processing philosopher: Anicius Manlius Severinus BoethiusProcess ID 93446 is processing philosopher: Bernard de MandevilleProcess ID 93451 is processing philosopher: Friedrich SchleiermacherProcess ID 93452 is processing philosopher: Gennadios II Scholarios
#
#
#
#
#
#
#
#
#
# Process ID 93447 is processing philosopher: Cheng YiProcess ID 93446 is processing philosopher: Bertrand RussellProcess ID 93451 is processing philosopher: Friedrich Theodor von VischerProcess ID 93444 is processing philosopher: Antonio LabriolaProcess ID 93448 is processing philosopher: Edith SteinProcess ID 93443 is processing philosopher: Alessandro AchilliniProcess ID 93445 is processing philosopher: Auguste ComteProcess ID 93452 is processing philosopher: Georg Bernhard BilfingerProcess ID 93449 is processing philosopher: Ernest Nagel
# Process ID 93450 is processing philosopher: Francis Hutcheson
#
#
#
#
#
#
#
#
# Process ID 93447 is processing philosopher: Claude-Adrien HelvetiusProcess ID 93451 is processing philosopher: Friedrich Wilhelm Joseph von SchellingProcess ID 93452 is processing philosopher: Georg BrandesProcess ID 93443 is processing philosopher: Alexander Gottlieb BaumgartenProcess ID 93448 is processing philosopher: Edmund HusserlProcess ID 93446 is processing philosopher: BessarionProcess ID 93445 is processing philosopher: AverroesProcess ID 93450 is processing philosopher: Francisco SuarezProcess ID 93449 is processing philosopher: Ernest RenanProcess ID 93444 is processing philosopher: Antonio Rosmini-Serbati
#
#
#
#
#
#
#
#
#
# Process ID 93451 is processing philosopher: Fritz MauthnerProcess ID 93443 is processing philosopher: Alexius MeinongProcess ID 93447 is processing philosopher: David Friedrich StraussProcess ID 93448 is processing philosopher: Eduard von HartmannProcess ID 93446 is processing philosopher: BhartrihariProcess ID 93452 is processing philosopher: Georg SimmelProcess ID 93449 is processing philosopher: Ernst MachProcess ID 93450 is processing philosopher: Franciscus HemsterhuisProcess ID 93444 is processing philosopher: Antony FlewProcess ID 93445 is processing philosopher: Avicenna
#
#
#
#
#
#
#
#
#
# Process ID 93449 is processing philosopher: Ernst TroeltschProcess ID 93446 is processing philosopher: Blaise PascalProcess ID 93447 is processing philosopher: David HartleyProcess ID 93444 is processing philosopher: Armando CarliniProcess ID 93451 is processing philosopher: Fyodor Ippolitovich ShcherbatskoyProcess ID 93452 is processing philosopher: Georg Wilhelm Friedrich HegelProcess ID 93450 is processing philosopher: Franz BrentanoProcess ID 93443 is processing philosopher: Alfred Firmin LoisyProcess ID 93448 is processing philosopher: Edward CairdProcess ID 93445 is processing philosopher: Bartolome de Medina
#
#
#
#
#
#
#
#
#
# Process ID 93446 is processing philosopher: Blessed John Duns ScotusProcess ID 93451 is processing philosopher: Gabriel BielProcess ID 93452 is processing philosopher: George BerkeleyProcess ID 93449 is processing philosopher: Erwin SchrodingerProcess ID 93450 is processing philosopher: Franz RosenzweigProcess ID 93447 is processing philosopher: David HumeProcess ID 93444 is processing philosopher: Arthur O. LovejoyProcess ID 93445 is processing philosopher: Benedetto CroceProcess ID 93448 is processing philosopher: Edward Westermarck
# Process ID 93443 is processing philosopher: Alfred Korzybski
#
#
#
#
#
#
#
#
# Process ID 93446 is processing philosopher: George Gemistus PlethonProcess ID 93450 is processing philosopher: Giambattista VicoProcess ID 93451 is processing philosopher: Gustav Theodor FechnerProcess ID 93449 is processing philosopher: He YanProcess ID 93443 is processing philosopher: Hermann CohenProcess ID 93452 is processing philosopher: Isaac of StellaProcess ID 93447 is processing philosopher: Jeremy BenthamProcess ID 93448 is processing philosopher: John LockeProcess ID 93444 is processing philosopher: James Frederick FerrierProcess ID 93445 is processing philosopher: John of Salisbury
#
#
#
#
#
#
#
#
#
# Process ID 93450 is processing philosopher: Giles of RomeProcess ID 93446 is processing philosopher: George GrantProcess ID 93451 is processing philosopher: Hajji Hadi SabzevariProcess ID 93444 is processing philosopher: James J. GibsonProcess ID 93448 is processing philosopher: John Neville KeynesProcess ID 93443 is processing philosopher: Hermann Samuel ReimarusProcess ID 93449 is processing philosopher: HemachandraProcess ID 93452 is processing philosopher: Isaak August DornerProcess ID 93447 is processing philosopher: Joachim WachProcess ID 93445 is processing philosopher: Jonathan Edwards
#
#
#
#
#
#
#
#
#
# Process ID 93443 is processing philosopher: Hermann von HelmholtzProcess ID 93450 is processing philosopher: Gilles DeleuzeProcess ID 93445 is processing philosopher: Jose Ortega y GassetProcess ID 93448 is processing philosopher: John Scott HaldaneProcess ID 93446 is processing philosopher: George Henry LewesProcess ID 93452 is processing philosopher: Ito JinsaiProcess ID 93451 is processing philosopher: Hannah ArendtProcess ID 93449 is processing philosopher: Henri BergsonProcess ID 93444 is processing philosopher: James Mark BaldwinProcess ID 93447 is processing philosopher: Johann Gottlieb Fichte
#
#
#
#
#
#
#
#
#
# Process ID 93443 is processing philosopher: Hilary PutnamProcess ID 93448 is processing philosopher: John Scotus ErigenaProcess ID 93446 is processing philosopher: George Herbert MeadProcess ID 93452 is processing philosopher: Jacob MoleschottProcess ID 93450 is processing philosopher: Gottfried Wilhelm LeibnizProcess ID 93445 is processing philosopher: Jose VasconcelosProcess ID 93447 is processing philosopher: Johann Heinrich LambertProcess ID 93444 is processing philosopher: James MartineauProcess ID 93449 is processing philosopher: Henri BerrProcess ID 93451 is processing philosopher: Hans Reichenbach
#
#
#
#
#
#
#
#
#
# Process ID 93443 is processing philosopher: Ibn FalaqueraProcess ID 93452 is processing philosopher: Jacques DerridaProcess ID 93446 is processing philosopher: George SantayanaProcess ID 93448 is processing philosopher: John Stuart MillProcess ID 93447 is processing philosopher: John BaconthorpeProcess ID 93450 is processing philosopher: Gotthold Ephraim LessingProcess ID 93451 is processing philosopher: Hans-Georg GadamerProcess ID 93444 is processing philosopher: Jean BaudrillardProcess ID 93445 is processing philosopher: Joseph ButlerProcess ID 93449 is processing philosopher: Henri Poincare
# Process ID 93443 is processing philosopher: Ibn GabirolProcess ID 93447 is processing philosopher: John DeweyProcess ID 93446 is processing philosopher: George Trumbull LaddProcess ID 93445 is processing philosopher: Joseph PriestleyProcess ID 93448 is processing philosopher: John VennProcess ID 93444 is processing philosopher: Jean BuridanProcess ID 93452 is processing philosopher: Jacques Maritain
# Process ID 93449 is processing philosopher: Henry Longueville ManselProcess ID 93451 is processing philosopher: Harry S. BroudyProcess ID 93450 is processing philosopher: Gottlob Frege
#
#
#
#
#
#
#
#
# Process ID 93443 is processing philosopher: Immanuel KantProcess ID 93445 is processing philosopher: Josiah RoyceProcess ID 93446 is processing philosopher: George TyrrellProcess ID 93448 is processing philosopher: John WycliffeProcess ID 93447 is processing philosopher: John FiskeProcess ID 93451 is processing philosopher: Hatano SeiichiProcess ID 93452 is processing philosopher: Jaime Luciano BalmesProcess ID 93450 is processing philosopher: Gregory of RiminiProcess ID 93444 is processing philosopher: Jean-Jacques RousseauProcess ID 93449 is processing philosopher: Henry Sidgwick
#
#
#
#
#
#
#
#
#
# Process ID 93446 is processing philosopher: Geraud de CordemoyProcess ID 93443 is processing philosopher: Inoue TetsujiroProcess ID 93447 is processing philosopher: John Langshaw AustinProcess ID 93452 is processing philosopher: Jakob BohmeProcess ID 93445 is processing philosopher: Julian HuxleyProcess ID 93448 is processing philosopher: John of ParisProcess ID 93451 is processing philosopher: Hayashi RazanProcess ID 93449 is processing philosopher: Herbert SpencerProcess ID 93444 is processing philosopher: Jean-Paul SartreProcess ID 93450 is processing philosopher: Gu Yanwu
#
#
#
#
#
#
#
#
#
# Process ID 93450 is processing philosopher: Liang ShumingProcess ID 93443 is processing philosopher: Justus LipsiusProcess ID 93446 is processing philosopher: Ludwig WittgensteinProcess ID 93452 is processing philosopher: Maurice BlondelProcess ID 93448 is processing philosopher: Norman Robert CampbellProcess ID 93451 is processing philosopher: Raghunatha ShiromaniProcess ID 93447 is processing philosopher: Moses MaimonidesProcess ID 93449 is processing philosopher: Pierre BayleProcess ID 93444 is processing philosopher: Robert BoyleProcess ID 93445 is processing philosopher: Samuel Bailey
#
#
#
#
#
#
#
#
#
# Process ID 93450 is processing philosopher: Lorenzo VallaProcess ID 93451 is processing philosopher: Ramana MaharshiProcess ID 93446 is processing philosopher: MadhvaProcess ID 93443 is processing philosopher: Karl JaspersProcess ID 93452 is processing philosopher: Maurice Merleau-PontyProcess ID 93447 is processing philosopher: Moses MendelssohnProcess ID 93445 is processing philosopher: Samuel HirschProcess ID 93444 is processing philosopher: Robert GrossetesteProcess ID 93448 is processing philosopher: Oswald KulpeProcess ID 93449 is processing philosopher: Pierre Gassendi
#
#
#
#
#
#
#
#
#
# Process ID 93443 is processing philosopher: Karl MarxProcess ID 93450 is processing philosopher: Louis AlthusserProcess ID 93451 is processing philosopher: RamanujaProcess ID 93446 is processing philosopher: Maria Gaetana AgnesiProcess ID 93452 is processing philosopher: Max BlackProcess ID 93444 is processing philosopher: Roger BaconProcess ID 93445 is processing philosopher: ShankaraProcess ID 93447 is processing philosopher: Mulla SadraProcess ID 93449 is processing philosopher: Pierre LaromiguiereProcess ID 93448 is processing philosopher: Oswald Spengler
#
#
#
#
#
#
#
#
#
# Process ID 93451 is processing philosopher: Ramon LlullProcess ID 93443 is processing philosopher: Karl PopperProcess ID 93447 is processing philosopher: Muro KyusoProcess ID 93449 is processing philosopher: Pierre LerouxProcess ID 93450 is processing philosopher: Louis LavelleProcess ID 93446 is processing philosopher: Marie-Francois-Pierre Maine de BiranProcess ID 93445 is processing philosopher: Shao YongProcess ID 93444 is processing philosopher: Rudolf BultmannProcess ID 93452 is processing philosopher: Max SchelerProcess ID 93448 is processing philosopher: Otto Friedrich von Gierke
#
#
#
#
#
#
#
#
#
# Process ID 93448 is processing philosopher: Otto NeurathProcess ID 93449 is processing philosopher: Pierre NicoleProcess ID 93447 is processing philosopher: Nathanael CulverwelProcess ID 93445 is processing philosopher: Shri AurobindoProcess ID 93444 is processing philosopher: Rudolf CarnapProcess ID 93451 is processing philosopher: Reinhold NiebuhrProcess ID 93452 is processing philosopher: Max StirnerProcess ID 93443 is processing philosopher: Kumazawa BanzanProcess ID 93446 is processing philosopher: Marin MersenneProcess ID 93450 is processing philosopher: Louis-Alexandre Couturat
#
#
#
#
#
#
#
#
#
# Process ID 93448 is processing philosopher: Paul ShoreyProcess ID 93445 is processing philosopher: Sidney HookProcess ID 93452 is processing philosopher: Michel FoucaultProcess ID 93447 is processing philosopher: Nicholas of CusaProcess ID 93449 is processing philosopher: Pierre Teilhard de ChardinProcess ID 93443 is processing philosopher: Leopold KroneckerProcess ID 93451 is processing philosopher: Rene DescartesProcess ID 93450 is processing philosopher: Lu JiuyuanProcess ID 93446 is processing philosopher: Marjorie GreneProcess ID 93444 is processing philosopher: Rudolf Otto
#
#
#
#
#
#
#
#
#
# Process ID 93451 is processing philosopher: Richard HookerProcess ID 93452 is processing philosopher: Moritz LazarusProcess ID 93445 is processing philosopher: Simon FoucherProcess ID 93448 is processing philosopher: Paul TillichProcess ID 93449 is processing philosopher: Pierre-Felix GuattariProcess ID 93447 is processing philosopher: Nikolay Yakovlevich DanilevskyProcess ID 93444 is processing philosopher: Salomon MaimonProcess ID 93443 is processing philosopher: Levi ben GershomProcess ID 93446 is processing philosopher: Marko MarulicProcess ID 93450 is processing philosopher: Lucien Levy-Bruhl
#
#
#
#
#
#
#
#
#
# Process ID 93451 is processing philosopher: Richard PriceProcess ID 93445 is processing philosopher: Simone WeilProcess ID 93448 is processing philosopher: Paul of VeniceProcess ID 93450 is processing philosopher: Ludwig KlagesProcess ID 93452 is processing philosopher: Mortimer J. AdlerProcess ID 93449 is processing philosopher: Pietro PomponazziProcess ID 93444 is processing philosopher: Samuel AlexanderProcess ID 93447 is processing philosopher: Nishida KitaroProcess ID 93443 is processing philosopher: Li AoProcess ID 93446 is processing philosopher: Marsilio Ficino
#
#
#
#
#
#
#
#
#
# Process ID 93450 is processing philosopher: Theodor Wiesengrund AdornoProcess ID 93449 is processing philosopher: Vladimir Sergeyevich SolovyovProcess ID 93448 is processing philosopher: Solomon FormstecherProcess ID 93447 is processing philosopher: Wilhelm DiltheyProcess ID 93445 is processing philosopher: William of AuxerreProcess ID 93444 is processing philosopher: al-Farabi
#
#
#
#
#
# Process ID 93448 is processing philosopher: Soren KierkegaardProcess ID 93449 is processing philosopher: Walter BenjaminProcess ID 93450 is processing philosopher: Theodosius DobzhanskyProcess ID 93445 is processing philosopher: William of ChampeauxProcess ID 93447 is processing philosopher: Willard Van Orman QuineProcess ID 93444 is processing philosopher: al-Ghazali
#
#
#
#
#
# Process ID 93445 is processing philosopher: William of OckhamProcess ID 93447 is processing philosopher: William GodwinProcess ID 93448 is processing philosopher: Stanislaw LesniewskiProcess ID 93449 is processing philosopher: Wang BiProcess ID 93450 is processing philosopher: Thomas Henry Huxley
#
#
#
#
# Process ID 93450 is processing philosopher: Thomas HobbesProcess ID 93448 is processing philosopher: Stephen Edelston ToulminProcess ID 93449 is processing philosopher: Wang ChongProcess ID 93447 is processing philosopher: William JamesProcess ID 93445 is processing philosopher: Xiong Shili
# Process ID 93445 is processing philosopher: Yan YuanProcess ID 93450 is processing philosopher: Thomas ReidProcess ID 93448 is processing philosopher: Susanne K. LangerProcess ID 93447 is processing philosopher: William Kingdon CliffordProcess ID 93449 is processing philosopher: Wang Yangming
#
#
#
#
# Process ID 93449 is processing philosopher: Watsuji TetsuroProcess ID 93448 is processing philosopher: TaixuProcess ID 93445 is processing philosopher: Zhang ZaiProcess ID 93447 is processing philosopher: William PaleyProcess ID 93450 is processing philosopher: Tommaso Campanella
#
#
#
#
# Process ID 93445 is processing philosopher: Zhou DunyiProcess ID 93449 is processing philosopher: Werner HeisenbergProcess ID 93447 is processing philosopher: William Ralph IngeProcess ID 93450 is processing philosopher: Uriel AcostaProcess ID 93448 is processing philosopher: Tao Sheng
#
#
#
#
# Process ID 93447 is processing philosopher: William WhewellProcess ID 93449 is processing philosopher: Wilfrid SellarsProcess ID 93450 is processing philosopher: VallabhaProcess ID 93445 is processing philosopher: Zhu XiProcess ID 93448 is processing philosopher: Theodor Gomperz
#
#
#
#
# CPU times: user 106 ms, sys: 97.8 ms, total: 204 ms
# Wall time: 494 ms
# [{'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53}]

# %%
# %%time
import multiprocess
import os

def transform(x):
    print(f"Process ID {os.getpid()} is processing philosopher: {x.name}")
    time.sleep(.01)
    return {"name": x.name, "age": x.died - x.born}

pool = multiprocess.Pool(processes=5)

result = pool.map(transform, philosophers)

result
# Out:
# Process ID 93453 is processing philosopher: Aaron David GordonProcess ID 93454 is processing philosopher: Arthur O. LovejoyProcess ID 93455 is processing philosopher: Blaise PascalProcess ID 93456 is processing philosopher: Eduard von HartmannProcess ID 93457 is processing philosopher: Francisco Suarez
#
#
#
#
# Process ID 93454 is processing philosopher: Arthur SchopenhauerProcess ID 93453 is processing philosopher: Abraham Joshua HeschelProcess ID 93457 is processing philosopher: Franciscus HemsterhuisProcess ID 93456 is processing philosopher: Edward CairdProcess ID 93455 is processing philosopher: Blessed John Duns Scotus
#
#
#
#
# Process ID 93457 is processing philosopher: Franz BrentanoProcess ID 93454 is processing philosopher: Arthur Stanley EddingtonProcess ID 93453 is processing philosopher: Albert of SaxonyProcess ID 93455 is processing philosopher: Carl Gustav Hempel
#
#
#
# Process ID 93456 is processing philosopher: Edward Westermarck
# Process ID 93454 is processing philosopher: AshvaghoshaProcess ID 93453 is processing philosopher: Alessandro AchilliniProcess ID 93455 is processing philosopher: Charles Sanders PeirceProcess ID 93457 is processing philosopher: Franz Rosenzweig
#
#
#
# Process ID 93456 is processing philosopher: Emmanuel Levinas
# Process ID 93454 is processing philosopher: Auguste ComteProcess ID 93453 is processing philosopher: Alexander Gottlieb BaumgartenProcess ID 93457 is processing philosopher: Frederick Robert TennantProcess ID 93455 is processing philosopher: Cheng Hao
#
#
#
# Process ID 93456 is processing philosopher: Erich Frank
# Process ID 93453 is processing philosopher: Alexius MeinongProcess ID 93454 is processing philosopher: AverroesProcess ID 93455 is processing philosopher: Cheng YiProcess ID 93457 is processing philosopher: Friedrich Nietzsche
#
#
#
# Process ID 93456 is processing philosopher: Erich Fromm
# Process ID 93453 is processing philosopher: Alfred Firmin LoisyProcess ID 93454 is processing philosopher: AvicennaProcess ID 93455 is processing philosopher: Claude-Adrien HelvetiusProcess ID 93457 is processing philosopher: Friedrich Schleiermacher
#
#
#
# Process ID 93456 is processing philosopher: Ernest NagelProcess ID 93454 is processing philosopher: Bartolome de MedinaProcess ID 93457 is processing philosopher: Friedrich Theodor von VischerProcess ID 93453 is processing philosopher: Alfred Korzybski
# Process ID 93455 is processing philosopher: David Friedrich Strauss
#
#
#
# Process ID 93456 is processing philosopher: Ernest RenanProcess ID 93454 is processing philosopher: Benedetto CroceProcess ID 93453 is processing philosopher: Alfred North WhiteheadProcess ID 93457 is processing philosopher: Friedrich Wilhelm Joseph von Schelling
# Process ID 93455 is processing philosopher: David Hartley
#
#
#
# Process ID 93456 is processing philosopher: Ernst MachProcess ID 93454 is processing philosopher: Benedict de SpinozaProcess ID 93453 is processing philosopher: Allan BloomProcess ID 93457 is processing philosopher: Fritz MauthnerProcess ID 93455 is processing philosopher: David Hume
#
#
#
#
# Process ID 93454 is processing philosopher: Bernard BosanquetProcess ID 93453 is processing philosopher: Anicius Manlius Severinus BoethiusProcess ID 93456 is processing philosopher: Ernst TroeltschProcess ID 93455 is processing philosopher: David RossProcess ID 93457 is processing philosopher: Fyodor Ippolitovich Shcherbatskoy
#
#
#
#
# Process ID 93454 is processing philosopher: Bernard de MandevilleProcess ID 93457 is processing philosopher: Gabriel BielProcess ID 93453 is processing philosopher: Antonio LabriolaProcess ID 93455 is processing philosopher: Denis DiderotProcess ID 93456 is processing philosopher: Erwin Schrodinger
#
#
#
#
# Process ID 93457 is processing philosopher: Gaston FrommelProcess ID 93454 is processing philosopher: Bertrand RussellProcess ID 93455 is processing philosopher: Derek ParfitProcess ID 93453 is processing philosopher: Antonio Rosmini-SerbatiProcess ID 93456 is processing philosopher: Etienne Bonnot de Condillac
#
#
#
#
# Process ID 93455 is processing philosopher: Edith SteinProcess ID 93456 is processing philosopher: Etienne GilsonProcess ID 93453 is processing philosopher: Antony FlewProcess ID 93457 is processing philosopher: Ge HongProcess ID 93454 is processing philosopher: Bessarion
#
#
#
#
# Process ID 93455 is processing philosopher: Edmund HusserlProcess ID 93453 is processing philosopher: Armando CarliniProcess ID 93456 is processing philosopher: Ferdinand Christian BaurProcess ID 93457 is processing philosopher: Gennadios II ScholariosProcess ID 93454 is processing philosopher: Bhartrihari
#
#
#
#
# Process ID 93456 is processing philosopher: Francis HutchesonProcess ID 93455 is processing philosopher: Georg Bernhard BilfingerProcess ID 93454 is processing philosopher: HemachandraProcess ID 93453 is processing philosopher: Gilles DeleuzeProcess ID 93457 is processing philosopher: Isaac of Stella
#
#
#
#
# Process ID 93455 is processing philosopher: Georg BrandesProcess ID 93454 is processing philosopher: Henri BergsonProcess ID 93457 is processing philosopher: Isaak August DornerProcess ID 93453 is processing philosopher: Gottfried Wilhelm LeibnizProcess ID 93456 is processing philosopher: Jean-Paul Sartre
#
#
#
#
# Process ID 93453 is processing philosopher: Gotthold Ephraim LessingProcess ID 93455 is processing philosopher: Georg SimmelProcess ID 93454 is processing philosopher: Henri BerrProcess ID 93456 is processing philosopher: Jeremy BenthamProcess ID 93457 is processing philosopher: Ito Jinsai
#
#
#
#
# Process ID 93453 is processing philosopher: Gottlob FregeProcess ID 93456 is processing philosopher: Joachim WachProcess ID 93455 is processing philosopher: Georg Wilhelm Friedrich HegelProcess ID 93457 is processing philosopher: Jacob MoleschottProcess ID 93454 is processing philosopher: Henri Poincare
#
#
#
#
# Process ID 93457 is processing philosopher: Jacques DerridaProcess ID 93453 is processing philosopher: Gregory of RiminiProcess ID 93455 is processing philosopher: George BerkeleyProcess ID 93454 is processing philosopher: Henry Longueville ManselProcess ID 93456 is processing philosopher: Johann Gottlieb Fichte
#
#
#
#
# Process ID 93454 is processing philosopher: Henry SidgwickProcess ID 93457 is processing philosopher: Jacques MaritainProcess ID 93455 is processing philosopher: George Gemistus PlethonProcess ID 93456 is processing philosopher: Johann Heinrich LambertProcess ID 93453 is processing philosopher: Gu Yanwu
#
#
#
#
# Process ID 93454 is processing philosopher: Herbert SpencerProcess ID 93456 is processing philosopher: John BaconthorpeProcess ID 93457 is processing philosopher: Jaime Luciano BalmesProcess ID 93453 is processing philosopher: Gustav Theodor FechnerProcess ID 93455 is processing philosopher: George Grant
#
#
#
#
# Process ID 93457 is processing philosopher: Jakob BohmeProcess ID 93454 is processing philosopher: Hermann CohenProcess ID 93453 is processing philosopher: Hajji Hadi SabzevariProcess ID 93455 is processing philosopher: George Henry LewesProcess ID 93456 is processing philosopher: John Dewey
#
#
#
#
# Process ID 93457 is processing philosopher: James Frederick FerrierProcess ID 93455 is processing philosopher: George Herbert MeadProcess ID 93456 is processing philosopher: John FiskeProcess ID 93453 is processing philosopher: Hannah ArendtProcess ID 93454 is processing philosopher: Hermann Samuel Reimarus
#
#
#
#
# Process ID 93457 is processing philosopher: James J. GibsonProcess ID 93456 is processing philosopher: John Langshaw AustinProcess ID 93455 is processing philosopher: George SantayanaProcess ID 93454 is processing philosopher: Hermann von HelmholtzProcess ID 93453 is processing philosopher: Hans Reichenbach
#
#
#
#
# Process ID 93453 is processing philosopher: Hans-Georg GadamerProcess ID 93456 is processing philosopher: John LockeProcess ID 93457 is processing philosopher: James Mark BaldwinProcess ID 93454 is processing philosopher: Hilary PutnamProcess ID 93455 is processing philosopher: George Trumbull Ladd
# Process ID 93456 is processing philosopher: John Neville KeynesProcess ID 93453 is processing philosopher: Harry S. BroudyProcess ID 93455 is processing philosopher: George TyrrellProcess ID 93454 is processing philosopher: Ibn FalaqueraProcess ID 93457 is processing philosopher: James Martineau
#
#
#
#
# Process ID 93456 is processing philosopher: John Scott HaldaneProcess ID 93453 is processing philosopher: Hatano SeiichiProcess ID 93454 is processing philosopher: Ibn GabirolProcess ID 93455 is processing philosopher: Geraud de CordemoyProcess ID 93457 is processing philosopher: Jean Baudrillard
#
#
#
#
# Process ID 93453 is processing philosopher: Hayashi RazanProcess ID 93455 is processing philosopher: Giambattista VicoProcess ID 93456 is processing philosopher: John Scotus ErigenaProcess ID 93454 is processing philosopher: Immanuel KantProcess ID 93457 is processing philosopher: Jean Buridan
#
#
#
#
# Process ID 93453 is processing philosopher: He YanProcess ID 93454 is processing philosopher: Inoue TetsujiroProcess ID 93457 is processing philosopher: Jean-Jacques RousseauProcess ID 93455 is processing philosopher: Giles of RomeProcess ID 93456 is processing philosopher: John Stuart Mill
#
#
#
#
# Process ID 93456 is processing philosopher: John VennProcess ID 93453 is processing philosopher: John WycliffeProcess ID 93457 is processing philosopher: Marin MersenneProcess ID 93454 is processing philosopher: Leopold KroneckerProcess ID 93455 is processing philosopher: Muro Kyuso
#
#
#
#
# Process ID 93453 is processing philosopher: John of ParisProcess ID 93454 is processing philosopher: Levi ben GershomProcess ID 93457 is processing philosopher: Marjorie GreneProcess ID 93455 is processing philosopher: Nathanael CulverwelProcess ID 93456 is processing philosopher: Pierre Laromiguiere
#
#
#
#
# Process ID 93453 is processing philosopher: John of SalisburyProcess ID 93455 is processing philosopher: Nicholas of CusaProcess ID 93456 is processing philosopher: Pierre LerouxProcess ID 93454 is processing philosopher: Li AoProcess ID 93457 is processing philosopher: Marko Marulic
#
#
#
#
# Process ID 93453 is processing philosopher: Jonathan EdwardsProcess ID 93455 is processing philosopher: Nikolay Yakovlevich DanilevskyProcess ID 93456 is processing philosopher: Pierre NicoleProcess ID 93454 is processing philosopher: Liang ShumingProcess ID 93457 is processing philosopher: Marsilio Ficino
#
#
#
#
# Process ID 93455 is processing philosopher: Nishida KitaroProcess ID 93456 is processing philosopher: Pierre Teilhard de ChardinProcess ID 93453 is processing philosopher: Jose Ortega y GassetProcess ID 93457 is processing philosopher: Maurice BlondelProcess ID 93454 is processing philosopher: Lorenzo Valla
#
#
#
#
# Process ID 93453 is processing philosopher: Jose VasconcelosProcess ID 93456 is processing philosopher: Pierre-Felix GuattariProcess ID 93455 is processing philosopher: Norman Robert CampbellProcess ID 93457 is processing philosopher: Maurice Merleau-PontyProcess ID 93454 is processing philosopher: Louis Althusser
#
#
#
#
# Process ID 93456 is processing philosopher: Pietro PomponazziProcess ID 93457 is processing philosopher: Max BlackProcess ID 93455 is processing philosopher: Oswald KulpeProcess ID 93453 is processing philosopher: Joseph ButlerProcess ID 93454 is processing philosopher: Louis Lavelle
#
#
#
#
# Process ID 93457 is processing philosopher: Max SchelerProcess ID 93453 is processing philosopher: Joseph PriestleyProcess ID 93456 is processing philosopher: Raghunatha ShiromaniProcess ID 93455 is processing philosopher: Oswald SpenglerProcess ID 93454 is processing philosopher: Louis-Alexandre Couturat
#
#
#
#
# Process ID 93456 is processing philosopher: Ramana MaharshiProcess ID 93457 is processing philosopher: Max StirnerProcess ID 93453 is processing philosopher: Josiah RoyceProcess ID 93454 is processing philosopher: Lu JiuyuanProcess ID 93455 is processing philosopher: Otto Friedrich von Gierke
#
#
#
#
# Process ID 93457 is processing philosopher: Michel FoucaultProcess ID 93456 is processing philosopher: RamanujaProcess ID 93453 is processing philosopher: Julian HuxleyProcess ID 93454 is processing philosopher: Lucien Levy-BruhlProcess ID 93455 is processing philosopher: Otto Neurath
#
#
#
#
# Process ID 93453 is processing philosopher: Justus LipsiusProcess ID 93457 is processing philosopher: Moritz LazarusProcess ID 93454 is processing philosopher: Ludwig KlagesProcess ID 93456 is processing philosopher: Ramon LlullProcess ID 93455 is processing philosopher: Paul Shorey
#
#
#
#
# Process ID 93457 is processing philosopher: Mortimer J. AdlerProcess ID 93456 is processing philosopher: Reinhold NiebuhrProcess ID 93453 is processing philosopher: Karl JaspersProcess ID 93454 is processing philosopher: Ludwig WittgensteinProcess ID 93455 is processing philosopher: Paul Tillich
#
#
#
#
# Process ID 93457 is processing philosopher: Moses MaimonidesProcess ID 93453 is processing philosopher: Karl MarxProcess ID 93456 is processing philosopher: Rene DescartesProcess ID 93454 is processing philosopher: MadhvaProcess ID 93455 is processing philosopher: Paul of Venice
#
#
#
#
# Process ID 93454 is processing philosopher: Maria Gaetana AgnesiProcess ID 93456 is processing philosopher: Richard HookerProcess ID 93457 is processing philosopher: Moses MendelssohnProcess ID 93455 is processing philosopher: Pierre BayleProcess ID 93453 is processing philosopher: Karl Popper
#
#
#
#
# Process ID 93456 is processing philosopher: Richard PriceProcess ID 93454 is processing philosopher: Marie-Francois-Pierre Maine de BiranProcess ID 93455 is processing philosopher: Pierre GassendiProcess ID 93457 is processing philosopher: Mulla SadraProcess ID 93453 is processing philosopher: Kumazawa Banzan
#
#
#
#
# Process ID 93456 is processing philosopher: Robert BoyleProcess ID 93454 is processing philosopher: Robert GrossetesteProcess ID 93455 is processing philosopher: Solomon FormstecherProcess ID 93457 is processing philosopher: William Ralph IngeProcess ID 93453 is processing philosopher: Vallabha
#
#
#
#
# Process ID 93454 is processing philosopher: Roger BaconProcess ID 93455 is processing philosopher: Soren KierkegaardProcess ID 93457 is processing philosopher: William WhewellProcess ID 93453 is processing philosopher: Vladimir Sergeyevich Solovyov
#
#
#
# Process ID 93455 is processing philosopher: Stanislaw LesniewskiProcess ID 93454 is processing philosopher: Rudolf BultmannProcess ID 93453 is processing philosopher: Walter BenjaminProcess ID 93457 is processing philosopher: William of Auxerre
#
#
#
# Process ID 93453 is processing philosopher: Wang BiProcess ID 93457 is processing philosopher: William of ChampeauxProcess ID 93454 is processing philosopher: Rudolf CarnapProcess ID 93455 is processing philosopher: Stephen Edelston Toulmin
#
#
#
# Process ID 93457 is processing philosopher: William of OckhamProcess ID 93453 is processing philosopher: Wang ChongProcess ID 93454 is processing philosopher: Rudolf OttoProcess ID 93455 is processing philosopher: Susanne K. Langer
#
#
#
# Process ID 93453 is processing philosopher: Wang YangmingProcess ID 93457 is processing philosopher: Xiong ShiliProcess ID 93455 is processing philosopher: TaixuProcess ID 93454 is processing philosopher: Salomon Maimon
#
#
#
# Process ID 93455 is processing philosopher: Tao ShengProcess ID 93453 is processing philosopher: Watsuji TetsuroProcess ID 93454 is processing philosopher: Samuel AlexanderProcess ID 93457 is processing philosopher: Yan Yuan
#
#
#
# Process ID 93453 is processing philosopher: Werner HeisenbergProcess ID 93455 is processing philosopher: Theodor GomperzProcess ID 93454 is processing philosopher: Samuel Bailey
# Process ID 93457 is processing philosopher: Zhang Zai
#
#
# Process ID 93455 is processing philosopher: Theodor Wiesengrund AdornoProcess ID 93453 is processing philosopher: Wilfrid SellarsProcess ID 93454 is processing philosopher: Samuel HirschProcess ID 93457 is processing philosopher: Zhou Dunyi
#
#
#
# Process ID 93455 is processing philosopher: Theodosius DobzhanskyProcess ID 93453 is processing philosopher: Wilhelm DiltheyProcess ID 93457 is processing philosopher: Zhu XiProcess ID 93454 is processing philosopher: Shankara
# Process ID 93455 is processing philosopher: Thomas Henry HuxleyProcess ID 93453 is processing philosopher: Willard Van Orman QuineProcess ID 93457 is processing philosopher: al-FarabiProcess ID 93454 is processing philosopher: Shao Yong
#
#
#
# Process ID 93457 is processing philosopher: al-GhazaliProcess ID 93453 is processing philosopher: William GodwinProcess ID 93454 is processing philosopher: Shri AurobindoProcess ID 93455 is processing philosopher: Thomas Hobbes
#
#
#
# Process ID 93455 is processing philosopher: Thomas ReidProcess ID 93453 is processing philosopher: William JamesProcess ID 93454 is processing philosopher: Sidney Hook
#
#
# Process ID 93455 is processing philosopher: Tommaso CampanellaProcess ID 93454 is processing philosopher: Simon FoucherProcess ID 93453 is processing philosopher: William Kingdon Clifford
#
#
# Process ID 93454 is processing philosopher: Simone WeilProcess ID 93455 is processing philosopher: Uriel AcostaProcess ID 93453 is processing philosopher: William Paley
#
#
# CPU times: user 114 ms, sys: 98.8 ms, total: 213 ms
# Wall time: 827 ms
# [{'name': 'Aaron David Gordon', 'age': 66},
#  {'name': 'Abraham Joshua Heschel', 'age': 65},
#  {'name': 'Albert of Saxony', 'age': 74},
#  {'name': 'Alessandro Achillini', 'age': 49},
#  {'name': 'Alexander Gottlieb Baumgarten', 'age': 48},
#  {'name': 'Alexius Meinong', 'age': 67},
#  {'name': 'Alfred Firmin Loisy', 'age': 83},
#  {'name': 'Alfred Korzybski', 'age': 71},
#  {'name': 'Alfred North Whitehead', 'age': 86},
#  {'name': 'Allan Bloom', 'age': 62},
#  {'name': 'Anicius Manlius Severinus Boethius', 'age': 49},
#  {'name': 'Antonio Labriola', 'age': 61},
#  {'name': 'Antonio Rosmini-Serbati', 'age': 58},
#  {'name': 'Antony Flew', 'age': 87},
#  {'name': 'Armando Carlini', 'age': 81},
#  {'name': 'Arthur O. Lovejoy', 'age': 89},
#  {'name': 'Arthur Schopenhauer', 'age': 72},
#  {'name': 'Arthur Stanley Eddington', 'age': 62},
#  {'name': 'Ashvaghosha', 'age': 70},
#  {'name': 'Auguste Comte', 'age': 59},
#  {'name': 'Averroes', 'age': 72},
#  {'name': 'Avicenna', 'age': 57},
#  {'name': 'Bartolome de Medina', 'age': 52},
#  {'name': 'Benedetto Croce', 'age': 86},
#  {'name': 'Benedict de Spinoza', 'age': 45},
#  {'name': 'Bernard Bosanquet', 'age': 75},
#  {'name': 'Bernard de Mandeville', 'age': 63},
#  {'name': 'Bertrand Russell', 'age': 98},
#  {'name': 'Bessarion', 'age': 69},
#  {'name': 'Bhartrihari', 'age': 81},
#  {'name': 'Blaise Pascal', 'age': 39},
#  {'name': 'Blessed John Duns Scotus', 'age': 42},
#  {'name': 'Carl Gustav Hempel', 'age': 92},
#  {'name': 'Charles Sanders Peirce', 'age': 75},
#  {'name': 'Cheng Hao', 'age': 53},
#  {'name': 'Cheng Yi', 'age': 74},
#  {'name': 'Claude-Adrien Helvetius', 'age': 56},
#  {'name': 'David Friedrich Strauss', 'age': 66},
#  {'name': 'David Hartley', 'age': 52},
#  {'name': 'David Hume', 'age': 65},
#  {'name': 'David Ross', 'age': 94},
#  {'name': 'Denis Diderot', 'age': 71},
#  {'name': 'Derek Parfit', 'age': 75},
#  {'name': 'Edith Stein', 'age': 51},
#  {'name': 'Edmund Husserl', 'age': 79},
#  {'name': 'Eduard von Hartmann', 'age': 64},
#  {'name': 'Edward Caird', 'age': 73},
#  {'name': 'Edward Westermarck', 'age': 77},
#  {'name': 'Emmanuel Levinas', 'age': 89},
#  {'name': 'Erich Frank', 'age': 66},
#  {'name': 'Erich Fromm', 'age': 80},
#  {'name': 'Ernest Nagel', 'age': 84},
#  {'name': 'Ernest Renan', 'age': 69},
#  {'name': 'Ernst Mach', 'age': 78},
#  {'name': 'Ernst Troeltsch', 'age': 58},
#  {'name': 'Erwin Schrodinger', 'age': 74},
#  {'name': 'Etienne Bonnot de Condillac', 'age': 65},
#  {'name': 'Etienne Gilson', 'age': 94},
#  {'name': 'Ferdinand Christian Baur', 'age': 68},
#  {'name': 'Francis Hutcheson', 'age': 52},
#  {'name': 'Francisco Suarez', 'age': 69},
#  {'name': 'Franciscus Hemsterhuis', 'age': 69},
#  {'name': 'Franz Brentano', 'age': 79},
#  {'name': 'Franz Rosenzweig', 'age': 43},
#  {'name': 'Frederick Robert Tennant', 'age': 91},
#  {'name': 'Friedrich Nietzsche', 'age': 56},
#  {'name': 'Friedrich Schleiermacher', 'age': 66},
#  {'name': 'Friedrich Theodor von Vischer', 'age': 80},
#  {'name': 'Friedrich Wilhelm Joseph von Schelling', 'age': 79},
#  {'name': 'Fritz Mauthner', 'age': 74},
#  {'name': 'Fyodor Ippolitovich Shcherbatskoy', 'age': 76},
#  {'name': 'Gabriel Biel', 'age': 75},
#  {'name': 'Gaston Frommel', 'age': 44},
#  {'name': 'Ge Hong', 'age': 60},
#  {'name': 'Gennadios II Scholarios', 'age': 68},
#  {'name': 'Georg Bernhard Bilfinger', 'age': 57},
#  {'name': 'Georg Brandes', 'age': 85},
#  {'name': 'Georg Simmel', 'age': 60},
#  {'name': 'Georg Wilhelm Friedrich Hegel', 'age': 61},
#  {'name': 'George Berkeley', 'age': 68},
#  {'name': 'George Gemistus Plethon', 'age': 97},
#  {'name': 'George Grant', 'age': 70},
#  {'name': 'George Henry Lewes', 'age': 61},
#  {'name': 'George Herbert Mead', 'age': 68},
#  {'name': 'George Santayana', 'age': 89},
#  {'name': 'George Trumbull Ladd', 'age': 79},
#  {'name': 'George Tyrrell', 'age': 48},
#  {'name': 'Geraud de Cordemoy', 'age': 64},
#  {'name': 'Giambattista Vico', 'age': 76},
#  {'name': 'Giles of Rome', 'age': 73},
#  {'name': 'Gilles Deleuze', 'age': 70},
#  {'name': 'Gottfried Wilhelm Leibniz', 'age': 70},
#  {'name': 'Gotthold Ephraim Lessing', 'age': 52},
#  {'name': 'Gottlob Frege', 'age': 77},
#  {'name': 'Gregory of Rimini', 'age': 58},
#  {'name': 'Gu Yanwu', 'age': 69},
#  {'name': 'Gustav Theodor Fechner', 'age': 86},
#  {'name': 'Hajji Hadi Sabzevari', 'age': 80},
#  {'name': 'Hannah Arendt', 'age': 69},
#  {'name': 'Hans Reichenbach', 'age': 62},
#  {'name': 'Hans-Georg Gadamer', 'age': 102},
#  {'name': 'Harry S. Broudy', 'age': 93},
#  {'name': 'Hatano Seiichi', 'age': 73},
#  {'name': 'Hayashi Razan', 'age': 74},
#  {'name': 'He Yan', 'age': 56},
#  {'name': 'Hemachandra', 'age': 84},
#  {'name': 'Henri Bergson', 'age': 82},
#  {'name': 'Henri Berr', 'age': 91},
#  {'name': 'Henri Poincare', 'age': 58},
#  {'name': 'Henry Longueville Mansel', 'age': 51},
#  {'name': 'Henry Sidgwick', 'age': 62},
#  {'name': 'Herbert Spencer', 'age': 83},
#  {'name': 'Hermann Cohen', 'age': 76},
#  {'name': 'Hermann Samuel Reimarus', 'age': 74},
#  {'name': 'Hermann von Helmholtz', 'age': 73},
#  {'name': 'Hilary Putnam', 'age': 90},
#  {'name': 'Ibn Falaquera', 'age': 70},
#  {'name': 'Ibn Gabirol', 'age': 48},
#  {'name': 'Immanuel Kant', 'age': 80},
#  {'name': 'Inoue Tetsujiro', 'age': 89},
#  {'name': 'Isaac of Stella', 'age': 69},
#  {'name': 'Isaak August Dorner', 'age': 75},
#  {'name': 'Ito Jinsai', 'age': 78},
#  {'name': 'Jacob Moleschott', 'age': 71},
#  {'name': 'Jacques Derrida', 'age': 74},
#  {'name': 'Jacques Maritain', 'age': 91},
#  {'name': 'Jaime Luciano Balmes', 'age': 38},
#  {'name': 'Jakob Bohme', 'age': 49},
#  {'name': 'James Frederick Ferrier', 'age': 56},
#  {'name': 'James J. Gibson', 'age': 75},
#  {'name': 'James Mark Baldwin', 'age': 73},
#  {'name': 'James Martineau', 'age': 95},
#  {'name': 'Jean Baudrillard', 'age': 78},
#  {'name': 'Jean Buridan', 'age': 58},
#  {'name': 'Jean-Jacques Rousseau', 'age': 66},
#  {'name': 'Jean-Paul Sartre', 'age': 75},
#  {'name': 'Jeremy Bentham', 'age': 84},
#  {'name': 'Joachim Wach', 'age': 57},
#  {'name': 'Johann Gottlieb Fichte', 'age': 52},
#  {'name': 'Johann Heinrich Lambert', 'age': 49},
#  {'name': 'John Baconthorpe', 'age': 56},
#  {'name': 'John Dewey', 'age': 93},
#  {'name': 'John Fiske', 'age': 59},
#  {'name': 'John Langshaw Austin', 'age': 49},
#  {'name': 'John Locke', 'age': 72},
#  {'name': 'John Neville Keynes', 'age': 97},
#  {'name': 'John Scott Haldane', 'age': 76},
#  {'name': 'John Scotus Erigena', 'age': 67},
#  {'name': 'John Stuart Mill', 'age': 67},
#  {'name': 'John Venn', 'age': 89},
#  {'name': 'John Wycliffe', 'age': 54},
#  {'name': 'John of Paris', 'age': 51},
#  {'name': 'John of Salisbury', 'age': 60},
#  {'name': 'Jonathan Edwards', 'age': 55},
#  {'name': 'Jose Ortega y Gasset', 'age': 72},
#  {'name': 'Jose Vasconcelos', 'age': 77},
#  {'name': 'Joseph Butler', 'age': 60},
#  {'name': 'Joseph Priestley', 'age': 71},
#  {'name': 'Josiah Royce', 'age': 61},
#  {'name': 'Julian Huxley', 'age': 88},
#  {'name': 'Justus Lipsius', 'age': 59},
#  {'name': 'Karl Jaspers', 'age': 86},
#  {'name': 'Karl Marx', 'age': 65},
#  {'name': 'Karl Popper', 'age': 92},
#  {'name': 'Kumazawa Banzan', 'age': 72},
#  {'name': 'Leopold Kronecker', 'age': 68},
#  {'name': 'Levi ben Gershom', 'age': 56},
#  {'name': 'Li Ao', 'age': 69},
#  {'name': 'Liang Shuming', 'age': 95},
#  {'name': 'Lorenzo Valla', 'age': 50},
#  {'name': 'Louis Althusser', 'age': 72},
#  {'name': 'Louis Lavelle', 'age': 68},
#  {'name': 'Louis-Alexandre Couturat', 'age': 46},
#  {'name': 'Lu Jiuyuan', 'age': 54},
#  {'name': 'Lucien Levy-Bruhl', 'age': 82},
#  {'name': 'Ludwig Klages', 'age': 84},
#  {'name': 'Ludwig Wittgenstein', 'age': 62},
#  {'name': 'Madhva', 'age': 79},
#  {'name': 'Maria Gaetana Agnesi', 'age': 81},
#  {'name': 'Marie-Francois-Pierre Maine de Biran', 'age': 58},
#  {'name': 'Marin Mersenne', 'age': 60},
#  {'name': 'Marjorie Grene', 'age': 99},
#  {'name': 'Marko Marulic', 'age': 74},
#  {'name': 'Marsilio Ficino', 'age': 66},
#  {'name': 'Maurice Blondel', 'age': 88},
#  {'name': 'Maurice Merleau-Ponty', 'age': 53},
#  {'name': 'Max Black', 'age': 79},
#  {'name': 'Max Scheler', 'age': 54},
#  {'name': 'Max Stirner', 'age': 50},
#  {'name': 'Michel Foucault', 'age': 58},
#  {'name': 'Moritz Lazarus', 'age': 79},
#  {'name': 'Mortimer J. Adler', 'age': 99},
#  {'name': 'Moses Maimonides', 'age': 69},
#  {'name': 'Moses Mendelssohn', 'age': 57},
#  {'name': 'Mulla Sadra', 'age': 69},
#  {'name': 'Muro Kyuso', 'age': 76},
#  {'name': 'Nathanael Culverwel', 'age': 33},
#  {'name': 'Nicholas of Cusa', 'age': 63},
#  {'name': 'Nikolay Yakovlevich Danilevsky', 'age': 63},
#  {'name': 'Nishida Kitaro', 'age': 75},
#  {'name': 'Norman Robert Campbell', 'age': 69},
#  {'name': 'Oswald Kulpe', 'age': 53},
#  {'name': 'Oswald Spengler', 'age': 56},
#  {'name': 'Otto Friedrich von Gierke', 'age': 80},
#  {'name': 'Otto Neurath', 'age': 63},
#  {'name': 'Paul Shorey', 'age': 77},
#  {'name': 'Paul Tillich', 'age': 79},
#  {'name': 'Paul of Venice', 'age': 57},
#  {'name': 'Pierre Bayle', 'age': 59},
#  {'name': 'Pierre Gassendi', 'age': 63},
#  {'name': 'Pierre Laromiguiere', 'age': 81},
#  {'name': 'Pierre Leroux', 'age': 74},
#  {'name': 'Pierre Nicole', 'age': 70},
#  {'name': 'Pierre Teilhard de Chardin', 'age': 74},
#  {'name': 'Pierre-Felix Guattari', 'age': 62},
#  {'name': 'Pietro Pomponazzi', 'age': 63},
#  {'name': 'Raghunatha Shiromani', 'age': 75},
#  {'name': 'Ramana Maharshi', 'age': 71},
#  {'name': 'Ramanuja', 'age': 120},
#  {'name': 'Ramon Llull', 'age': 83},
#  {'name': 'Reinhold Niebuhr', 'age': 79},
#  {'name': 'Rene Descartes', 'age': 54},
#  {'name': 'Richard Hooker', 'age': 46},
#  {'name': 'Richard Price', 'age': 68},
#  {'name': 'Robert Boyle', 'age': 64},
#  {'name': 'Robert Grosseteste', 'age': 78},
#  {'name': 'Roger Bacon', 'age': 72},
#  {'name': 'Rudolf Bultmann', 'age': 92},
#  {'name': 'Rudolf Carnap', 'age': 79},
#  {'name': 'Rudolf Otto', 'age': 68},
#  {'name': 'Salomon Maimon', 'age': 46},
#  {'name': 'Samuel Alexander', 'age': 79},
#  {'name': 'Samuel Bailey', 'age': 79},
#  {'name': 'Samuel Hirsch', 'age': 74},
#  {'name': 'Shankara', 'age': 50},
#  {'name': 'Shao Yong', 'age': 66},
#  {'name': 'Shri Aurobindo', 'age': 78},
#  {'name': 'Sidney Hook', 'age': 87},
#  {'name': 'Simon Foucher', 'age': 52},
#  {'name': 'Simone Weil', 'age': 34},
#  {'name': 'Solomon Formstecher', 'age': 81},
#  {'name': 'Soren Kierkegaard', 'age': 42},
#  {'name': 'Stanislaw Lesniewski', 'age': 53},
#  {'name': 'Stephen Edelston Toulmin', 'age': 87},
#  {'name': 'Susanne K. Langer', 'age': 90},
#  {'name': 'Taixu', 'age': 57},
#  {'name': 'Tao Sheng', 'age': 74},
#  {'name': 'Theodor Gomperz', 'age': 80},
#  {'name': 'Theodor Wiesengrund Adorno', 'age': 66},
#  {'name': 'Theodosius Dobzhansky', 'age': 75},
#  {'name': 'Thomas Henry Huxley', 'age': 70},
#  {'name': 'Thomas Hobbes', 'age': 91},
#  {'name': 'Thomas Reid', 'age': 86},
#  {'name': 'Tommaso Campanella', 'age': 71},
#  {'name': 'Uriel Acosta', 'age': 55},
#  {'name': 'Vallabha', 'age': 52},
#  {'name': 'Vladimir Sergeyevich Solovyov', 'age': 47},
#  {'name': 'Walter Benjamin', 'age': 48},
#  {'name': 'Wang Bi', 'age': 23},
#  {'name': 'Wang Chong', 'age': 73},
#  {'name': 'Wang Yangming', 'age': 57},
#  {'name': 'Watsuji Tetsuro', 'age': 71},
#  {'name': 'Werner Heisenberg', 'age': 75},
#  {'name': 'Wilfrid Sellars', 'age': 77},
#  {'name': 'Wilhelm Dilthey', 'age': 78},
#  {'name': 'Willard Van Orman Quine', 'age': 92},
#  {'name': 'William Godwin', 'age': 80},
#  {'name': 'William James', 'age': 68},
#  {'name': 'William Kingdon Clifford', 'age': 34},
#  {'name': 'William Paley', 'age': 62},
#  {'name': 'William Ralph Inge', 'age': 94},
#  {'name': 'William Whewell', 'age': 72},
#  {'name': 'William of Auxerre', 'age': 81},
#  {'name': 'William of Champeaux', 'age': 51},
#  {'name': 'William of Ockham', 'age': 64},
#  {'name': 'Xiong Shili', 'age': 83},
#  {'name': 'Yan Yuan', 'age': 69},
#  {'name': 'Zhang Zai', 'age': 57},
#  {'name': 'Zhou Dunyi', 'age': 56},
#  {'name': 'Zhu Xi', 'age': 70},
#  {'name': 'al-Farabi', 'age': 72},
#  {'name': 'al-Ghazali', 'age': 53}]

# %% [markdown]
# ### Multiprocess vs Multiprocessing
#
# Just a note here that I am using the package `multiprocess` above, but in practice, you will almost always want to use the package that is shipped with Python `multiprocessing`. The reason I am not using `mutliprocessing` above, but instead the package `multiprocess`, which has to be separately pip installed is that `mutliprocessing` relies heavily on the the `__main__` attribute which is not precent when running in a shell or on Jupyter Notebook.

# %%
# %%time
# Example of multiprocessing
# !python multiprocessing_example.py
# Out:
# Process ID 93463 is processing philosopher: Aaron David Gordon
# Process ID 93463 is processing philosopher: Abraham Joshua Heschel
# Process ID 93463 is processing philosopher: Albert of Saxony
# Process ID 93462 is processing philosopher: Arthur O. Lovejoy
# Process ID 93464 is processing philosopher: Blaise Pascal
# Process ID 93460 is processing philosopher: Eduard von Hartmann
# Process ID 93463 is processing philosopher: Alessandro Achillini
# Process ID 93462 is processing philosopher: Arthur Schopenhauer
# Process ID 93461 is processing philosopher: Francisco Suarez
# Process ID 93464 is processing philosopher: Blessed John Duns Scotus
# Process ID 93460 is processing philosopher: Edward Caird
# Process ID 93463 is processing philosopher: Alexander Gottlieb Baumgarten
# Process ID 93462 is processing philosopher: Arthur Stanley Eddington
# Process ID 93461 is processing philosopher: Franciscus Hemsterhuis
# Process ID 93464 is processing philosopher: Carl Gustav Hempel
# Process ID 93460 is processing philosopher: Edward Westermarck
# Process ID 93463 is processing philosopher: Alexius Meinong
# Process ID 93462 is processing philosopher: Ashvaghosha
# Process ID 93461 is processing philosopher: Franz Brentano
# Process ID 93460 is processing philosopher: Emmanuel Levinas
# Process ID 93464 is processing philosopher: Charles Sanders Peirce
# Process ID 93462 is processing philosopher: Auguste Comte
# Process ID 93463 is processing philosopher: Alfred Firmin Loisy
# Process ID 93460 is processing philosopher: Erich Frank
# Process ID 93461 is processing philosopher: Franz Rosenzweig
# Process ID 93464 is processing philosopher: Cheng Hao
# Process ID 93463 is processing philosopher: Alfred Korzybski
# Process ID 93462 is processing philosopher: Averroes
# Process ID 93461 is processing philosopher: Frederick Robert Tennant
# Process ID 93460 is processing philosopher: Erich Fromm
# Process ID 93464 is processing philosopher: Cheng Yi
# Process ID 93463 is processing philosopher: Alfred North Whitehead
# Process ID 93462 is processing philosopher: Avicenna
# Process ID 93461 is processing philosopher: Friedrich Nietzsche
# Process ID 93460 is processing philosopher: Ernest Nagel
# Process ID 93464 is processing philosopher: Claude-Adrien Helvetius
# Process ID 93463 is processing philosopher: Allan Bloom
# Process ID 93462 is processing philosopher: Bartolome de Medina
# Process ID 93460 is processing philosopher: Ernest Renan
# Process ID 93461 is processing philosopher: Friedrich Schleiermacher
# Process ID 93464 is processing philosopher: David Friedrich Strauss
# Process ID 93463 is processing philosopher: Anicius Manlius Severinus Boethius
# Process ID 93462 is processing philosopher: Benedetto Croce
# Process ID 93460 is processing philosopher: Ernst Mach
# Process ID 93461 is processing philosopher: Friedrich Theodor von Vischer
# Process ID 93464 is processing philosopher: David Hartley
# Process ID 93463 is processing philosopher: Antonio Labriola
# Process ID 93462 is processing philosopher: Benedict de Spinoza
# Process ID 93460 is processing philosopher: Ernst Troeltsch
# Process ID 93461 is processing philosopher: Friedrich Wilhelm Joseph von Schelling
# Process ID 93464 is processing philosopher: David Hume
# Process ID 93463 is processing philosopher: Antonio Rosmini-Serbati
# Process ID 93462 is processing philosopher: Bernard Bosanquet
# Process ID 93460 is processing philosopher: Erwin Schrodinger
# Process ID 93461 is processing philosopher: Fritz Mauthner
# Process ID 93463 is processing philosopher: Antony Flew
# Process ID 93464 is processing philosopher: David Ross
# Process ID 93462 is processing philosopher: Bernard de Mandeville
# Process ID 93460 is processing philosopher: Etienne Bonnot de Condillac
# Process ID 93461 is processing philosopher: Fyodor Ippolitovich Shcherbatskoy
# Process ID 93464 is processing philosopher: Denis Diderot
# Process ID 93463 is processing philosopher: Armando Carlini
# Process ID 93462 is processing philosopher: Bertrand Russell
# Process ID 93464 is processing philosopher: Derek Parfit
# Process ID 93460 is processing philosopher: Etienne Gilson
# Process ID 93461 is processing philosopher: Gabriel Biel
# Process ID 93463 is processing philosopher: Georg Bernhard Bilfinger
# Process ID 93462 is processing philosopher: Bessarion
# Process ID 93464 is processing philosopher: Edith Stein
# Process ID 93460 is processing philosopher: Ferdinand Christian Baur
# Process ID 93461 is processing philosopher: Gaston Frommel
# Process ID 93463 is processing philosopher: Georg Brandes
# Process ID 93462 is processing philosopher: Bhartrihari
# Process ID 93460 is processing philosopher: Francis Hutcheson
# Process ID 93464 is processing philosopher: Edmund Husserl
# Process ID 93461 is processing philosopher: Ge Hong
# Process ID 93463 is processing philosopher: Georg Simmel
# Process ID 93462 is processing philosopher: Gilles Deleuze
# Process ID 93461 is processing philosopher: Gennadios II Scholarios
# Process ID 93460 is processing philosopher: Hemachandra
# Process ID 93464 is processing philosopher: Isaac of Stella
# Process ID 93463 is processing philosopher: Georg Wilhelm Friedrich Hegel
# Process ID 93462 is processing philosopher: Gottfried Wilhelm Leibniz
# Process ID 93460 is processing philosopher: Henri Bergson
# Process ID 93464 is processing philosopher: Isaak August Dorner
# Process ID 93461 is processing philosopher: Jean-Paul Sartre
# Process ID 93463 is processing philosopher: George Berkeley
# Process ID 93462 is processing philosopher: Gotthold Ephraim Lessing
# Process ID 93460 is processing philosopher: Henri Berr
# Process ID 93464 is processing philosopher: Ito Jinsai
# Process ID 93461 is processing philosopher: Jeremy Bentham
# Process ID 93463 is processing philosopher: George Gemistus Plethon
# Process ID 93462 is processing philosopher: Gottlob Frege
# Process ID 93464 is processing philosopher: Jacob Moleschott
# Process ID 93461 is processing philosopher: Joachim Wach
# Process ID 93460 is processing philosopher: Henri Poincare
# Process ID 93463 is processing philosopher: George Grant
# Process ID 93462 is processing philosopher: Gregory of Rimini
# Process ID 93461 is processing philosopher: Johann Gottlieb Fichte
# Process ID 93464 is processing philosopher: Jacques Derrida
# Process ID 93460 is processing philosopher: Henry Longueville Mansel
# Process ID 93463 is processing philosopher: George Henry Lewes
# Process ID 93462 is processing philosopher: Gu Yanwu
# Process ID 93461 is processing philosopher: Johann Heinrich Lambert
# Process ID 93464 is processing philosopher: Jacques Maritain
# Process ID 93460 is processing philosopher: Henry Sidgwick
# Process ID 93463 is processing philosopher: George Herbert Mead
# Process ID 93462 is processing philosopher: Gustav Theodor Fechner
# Process ID 93464 is processing philosopher: Jaime Luciano Balmes
# Process ID 93461 is processing philosopher: John Baconthorpe
# Process ID 93460 is processing philosopher: Herbert Spencer
# Process ID 93463 is processing philosopher: George Santayana
# Process ID 93462 is processing philosopher: Hajji Hadi Sabzevari
# Process ID 93464 is processing philosopher: Jakob Bohme
# Process ID 93461 is processing philosopher: John Dewey
# Process ID 93460 is processing philosopher: Hermann Cohen
# Process ID 93463 is processing philosopher: George Trumbull Ladd
# Process ID 93462 is processing philosopher: Hannah Arendt
# Process ID 93464 is processing philosopher: James Frederick Ferrier
# Process ID 93461 is processing philosopher: John Fiske
# Process ID 93460 is processing philosopher: Hermann Samuel Reimarus
# Process ID 93463 is processing philosopher: George Tyrrell
# Process ID 93462 is processing philosopher: Hans Reichenbach
# Process ID 93464 is processing philosopher: James J. Gibson
# Process ID 93461 is processing philosopher: John Langshaw Austin
# Process ID 93460 is processing philosopher: Hermann von Helmholtz
# Process ID 93463 is processing philosopher: Geraud de Cordemoy
# Process ID 93462 is processing philosopher: Hans-Georg Gadamer
# Process ID 93464 is processing philosopher: James Mark Baldwin
# Process ID 93461 is processing philosopher: John Locke
# Process ID 93460 is processing philosopher: Hilary Putnam
# Process ID 93463 is processing philosopher: Giambattista Vico
# Process ID 93462 is processing philosopher: Harry S. Broudy
# Process ID 93461 is processing philosopher: John Neville Keynes
# Process ID 93464 is processing philosopher: James Martineau
# Process ID 93460 is processing philosopher: Ibn Falaquera
# Process ID 93463 is processing philosopher: Giles of Rome
# Process ID 93462 is processing philosopher: Hatano Seiichi
# Process ID 93461 is processing philosopher: John Scott Haldane
# Process ID 93464 is processing philosopher: Jean Baudrillard
# Process ID 93460 is processing philosopher: Ibn Gabirol
# Process ID 93463 is processing philosopher: John Wycliffe
# Process ID 93462 is processing philosopher: Hayashi Razan
# Process ID 93461 is processing philosopher: John Scotus Erigena
# Process ID 93464 is processing philosopher: Jean Buridan
# Process ID 93460 is processing philosopher: Immanuel Kant
# Process ID 93463 is processing philosopher: John of Paris
# Process ID 93461 is processing philosopher: John Stuart Mill
# Process ID 93462 is processing philosopher: He Yan
# Process ID 93464 is processing philosopher: Jean-Jacques Rousseau
# Process ID 93460 is processing philosopher: Inoue Tetsujiro
# Process ID 93463 is processing philosopher: John of Salisbury
# Process ID 93461 is processing philosopher: John Venn
# Process ID 93462 is processing philosopher: Leopold Kronecker
# Process ID 93464 is processing philosopher: Marin Mersenne
# Process ID 93463 is processing philosopher: Jonathan Edwards
# Process ID 93460 is processing philosopher: Muro Kyuso
# Process ID 93462 is processing philosopher: Levi ben Gershom
# Process ID 93461 is processing philosopher: Pierre Laromiguiere
# Process ID 93464 is processing philosopher: Marjorie Grene
# Process ID 93463 is processing philosopher: Jose Ortega y Gasset
# Process ID 93460 is processing philosopher: Nathanael Culverwel
# Process ID 93462 is processing philosopher: Li Ao
# Process ID 93461 is processing philosopher: Pierre Leroux
# Process ID 93463 is processing philosopher: Jose Vasconcelos
# Process ID 93464 is processing philosopher: Marko Marulic
# Process ID 93460 is processing philosopher: Nicholas of Cusa
# Process ID 93462 is processing philosopher: Liang Shuming
# Process ID 93461 is processing philosopher: Pierre Nicole
# Process ID 93463 is processing philosopher: Joseph Butler
# Process ID 93464 is processing philosopher: Marsilio Ficino
# Process ID 93460 is processing philosopher: Nikolay Yakovlevich Danilevsky
# Process ID 93461 is processing philosopher: Pierre Teilhard de Chardin
# Process ID 93462 is processing philosopher: Lorenzo Valla
# Process ID 93463 is processing philosopher: Joseph Priestley
# Process ID 93464 is processing philosopher: Maurice Blondel
# Process ID 93460 is processing philosopher: Nishida Kitaro
# Process ID 93461 is processing philosopher: Pierre-Felix Guattari
# Process ID 93462 is processing philosopher: Louis Althusser
# Process ID 93464 is processing philosopher: Maurice Merleau-Ponty
# Process ID 93463 is processing philosopher: Josiah Royce
# Process ID 93460 is processing philosopher: Norman Robert Campbell
# Process ID 93462 is processing philosopher: Louis Lavelle
# Process ID 93461 is processing philosopher: Pietro Pomponazzi
# Process ID 93460 is processing philosopher: Oswald Kulpe
# Process ID 93464 is processing philosopher: Max Black
# Process ID 93463 is processing philosopher: Julian Huxley
# Process ID 93462 is processing philosopher: Louis-Alexandre Couturat
# Process ID 93461 is processing philosopher: Raghunatha Shiromani
# Process ID 93460 is processing philosopher: Oswald Spengler
# Process ID 93464 is processing philosopher: Max Scheler
# Process ID 93463 is processing philosopher: Justus Lipsius
# Process ID 93462 is processing philosopher: Lu Jiuyuan
# Process ID 93461 is processing philosopher: Ramana Maharshi
# Process ID 93464 is processing philosopher: Max Stirner
# Process ID 93460 is processing philosopher: Otto Friedrich von Gierke
# Process ID 93463 is processing philosopher: Karl Jaspers
# Process ID 93462 is processing philosopher: Lucien Levy-Bruhl
# Process ID 93461 is processing philosopher: Ramanuja
# Process ID 93460 is processing philosopher: Otto Neurath
# Process ID 93464 is processing philosopher: Michel Foucault
# Process ID 93463 is processing philosopher: Karl Marx
# Process ID 93461 is processing philosopher: Ramon Llull
# Process ID 93462 is processing philosopher: Ludwig Klages
# Process ID 93460 is processing philosopher: Paul Shorey
# Process ID 93464 is processing philosopher: Moritz Lazarus
# Process ID 93463 is processing philosopher: Karl Popper
# Process ID 93461 is processing philosopher: Reinhold Niebuhr
# Process ID 93462 is processing philosopher: Ludwig Wittgenstein
# Process ID 93460 is processing philosopher: Paul Tillich
# Process ID 93464 is processing philosopher: Mortimer J. Adler
# Process ID 93463 is processing philosopher: Kumazawa Banzan
# Process ID 93461 is processing philosopher: Rene Descartes
# Process ID 93462 is processing philosopher: Madhva
# Process ID 93464 is processing philosopher: Moses Maimonides
# Process ID 93460 is processing philosopher: Paul of Venice
# Process ID 93463 is processing philosopher: Robert Grosseteste
# Process ID 93462 is processing philosopher: Maria Gaetana Agnesi
# Process ID 93461 is processing philosopher: Richard Hooker
# Process ID 93460 is processing philosopher: Pierre Bayle
# Process ID 93464 is processing philosopher: Moses Mendelssohn
# Process ID 93463 is processing philosopher: Roger Bacon
# Process ID 93462 is processing philosopher: Marie-Francois-Pierre Maine de Biran
# Process ID 93461 is processing philosopher: Richard Price
# Process ID 93460 is processing philosopher: Pierre Gassendi
# Process ID 93464 is processing philosopher: Mulla Sadra
# Process ID 93463 is processing philosopher: Rudolf Bultmann
# Process ID 93461 is processing philosopher: Robert Boyle
# Process ID 93462 is processing philosopher: Solomon Formstecher
# Process ID 93460 is processing philosopher: Vallabha
# Process ID 93463 is processing philosopher: Rudolf Carnap
# Process ID 93464 is processing philosopher: William Ralph Inge
# Process ID 93462 is processing philosopher: Soren Kierkegaard
# Process ID 93460 is processing philosopher: Vladimir Sergeyevich Solovyov
# Process ID 93463 is processing philosopher: Rudolf Otto
# Process ID 93464 is processing philosopher: William Whewell
# Process ID 93462 is processing philosopher: Stanislaw Lesniewski
# Process ID 93460 is processing philosopher: Walter Benjamin
# Process ID 93464 is processing philosopher: William of Auxerre
# Process ID 93463 is processing philosopher: Salomon Maimon
# Process ID 93462 is processing philosopher: Stephen Edelston Toulmin
# Process ID 93464 is processing philosopher: William of Champeaux
# Process ID 93460 is processing philosopher: Wang Bi
# Process ID 93463 is processing philosopher: Samuel Alexander
# Process ID 93462 is processing philosopher: Susanne K. Langer
# Process ID 93464 is processing philosopher: William of Ockham
# Process ID 93463 is processing philosopher: Samuel Bailey
# Process ID 93460 is processing philosopher: Wang Chong
# Process ID 93462 is processing philosopher: Taixu
# Process ID 93464 is processing philosopher: Xiong Shili
# Process ID 93460 is processing philosopher: Wang Yangming
# Process ID 93463 is processing philosopher: Samuel Hirsch
# Process ID 93462 is processing philosopher: Tao Sheng
# Process ID 93464 is processing philosopher: Yan Yuan
# Process ID 93463 is processing philosopher: Shankara
# Process ID 93460 is processing philosopher: Watsuji Tetsuro
# Process ID 93462 is processing philosopher: Theodor Gomperz
# Process ID 93464 is processing philosopher: Zhang Zai
# Process ID 93460 is processing philosopher: Werner Heisenberg
# Process ID 93463 is processing philosopher: Shao Yong
# Process ID 93462 is processing philosopher: Theodor Wiesengrund Adorno
# Process ID 93464 is processing philosopher: Zhou Dunyi
# Process ID 93460 is processing philosopher: Wilfrid Sellars
# Process ID 93463 is processing philosopher: Shri Aurobindo
# Process ID 93460 is processing philosopher: Wilhelm Dilthey
# Process ID 93462 is processing philosopher: Theodosius Dobzhansky
# Process ID 93464 is processing philosopher: Zhu Xi
# Process ID 93463 is processing philosopher: Sidney Hook
# Process ID 93462 is processing philosopher: Thomas Henry Huxley
# Process ID 93464 is processing philosopher: al-Farabi
# Process ID 93460 is processing philosopher: Willard Van Orman Quine
# Process ID 93463 is processing philosopher: Simon Foucher
# Process ID 93462 is processing philosopher: Thomas Hobbes
# Process ID 93464 is processing philosopher: al-Ghazali
# Process ID 93460 is processing philosopher: William Godwin
# Process ID 93463 is processing philosopher: Simone Weil
# Process ID 93460 is processing philosopher: William James
# Process ID 93462 is processing philosopher: Thomas Reid
# Process ID 93460 is processing philosopher: William Kingdon Clifford
# Process ID 93462 is processing philosopher: Tommaso Campanella
# Process ID 93460 is processing philosopher: William Paley
# Process ID 93462 is processing philosopher: Uriel Acosta
# [{'age': 66, 'name': 'Aaron David Gordon'},
#  {'age': 65, 'name': 'Abraham Joshua Heschel'},
#  {'age': 74, 'name': 'Albert of Saxony'},
#  {'age': 49, 'name': 'Alessandro Achillini'},
#  {'age': 48, 'name': 'Alexander Gottlieb Baumgarten'},
#  {'age': 67, 'name': 'Alexius Meinong'},
#  {'age': 83, 'name': 'Alfred Firmin Loisy'},
#  {'age': 71, 'name': 'Alfred Korzybski'},
#  {'age': 86, 'name': 'Alfred North Whitehead'},
#  {'age': 62, 'name': 'Allan Bloom'},
#  {'age': 49, 'name': 'Anicius Manlius Severinus Boethius'},
#  {'age': 61, 'name': 'Antonio Labriola'},
#  {'age': 58, 'name': 'Antonio Rosmini-Serbati'},
#  {'age': 87, 'name': 'Antony Flew'},
#  {'age': 81, 'name': 'Armando Carlini'},
#  {'age': 89, 'name': 'Arthur O. Lovejoy'},
#  {'age': 72, 'name': 'Arthur Schopenhauer'},
#  {'age': 62, 'name': 'Arthur Stanley Eddington'},
#  {'age': 70, 'name': 'Ashvaghosha'},
#  {'age': 59, 'name': 'Auguste Comte'},
#  {'age': 72, 'name': 'Averroes'},
#  {'age': 57, 'name': 'Avicenna'},
#  {'age': 52, 'name': 'Bartolome de Medina'},
#  {'age': 86, 'name': 'Benedetto Croce'},
#  {'age': 45, 'name': 'Benedict de Spinoza'},
#  {'age': 75, 'name': 'Bernard Bosanquet'},
#  {'age': 63, 'name': 'Bernard de Mandeville'},
#  {'age': 98, 'name': 'Bertrand Russell'},
#  {'age': 69, 'name': 'Bessarion'},
#  {'age': 81, 'name': 'Bhartrihari'},
#  {'age': 39, 'name': 'Blaise Pascal'},
#  {'age': 42, 'name': 'Blessed John Duns Scotus'},
#  {'age': 92, 'name': 'Carl Gustav Hempel'},
#  {'age': 75, 'name': 'Charles Sanders Peirce'},
#  {'age': 53, 'name': 'Cheng Hao'},
#  {'age': 74, 'name': 'Cheng Yi'},
#  {'age': 56, 'name': 'Claude-Adrien Helvetius'},
#  {'age': 66, 'name': 'David Friedrich Strauss'},
#  {'age': 52, 'name': 'David Hartley'},
#  {'age': 65, 'name': 'David Hume'},
#  {'age': 94, 'name': 'David Ross'},
#  {'age': 71, 'name': 'Denis Diderot'},
#  {'age': 75, 'name': 'Derek Parfit'},
#  {'age': 51, 'name': 'Edith Stein'},
#  {'age': 79, 'name': 'Edmund Husserl'},
#  {'age': 64, 'name': 'Eduard von Hartmann'},
#  {'age': 73, 'name': 'Edward Caird'},
#  {'age': 77, 'name': 'Edward Westermarck'},
#  {'age': 89, 'name': 'Emmanuel Levinas'},
#  {'age': 66, 'name': 'Erich Frank'},
#  {'age': 80, 'name': 'Erich Fromm'},
#  {'age': 84, 'name': 'Ernest Nagel'},
#  {'age': 69, 'name': 'Ernest Renan'},
#  {'age': 78, 'name': 'Ernst Mach'},
#  {'age': 58, 'name': 'Ernst Troeltsch'},
#  {'age': 74, 'name': 'Erwin Schrodinger'},
#  {'age': 65, 'name': 'Etienne Bonnot de Condillac'},
#  {'age': 94, 'name': 'Etienne Gilson'},
#  {'age': 68, 'name': 'Ferdinand Christian Baur'},
#  {'age': 52, 'name': 'Francis Hutcheson'},
#  {'age': 69, 'name': 'Francisco Suarez'},
#  {'age': 69, 'name': 'Franciscus Hemsterhuis'},
#  {'age': 79, 'name': 'Franz Brentano'},
#  {'age': 43, 'name': 'Franz Rosenzweig'},
#  {'age': 91, 'name': 'Frederick Robert Tennant'},
#  {'age': 56, 'name': 'Friedrich Nietzsche'},
#  {'age': 66, 'name': 'Friedrich Schleiermacher'},
#  {'age': 80, 'name': 'Friedrich Theodor von Vischer'},
#  {'age': 79, 'name': 'Friedrich Wilhelm Joseph von Schelling'},
#  {'age': 74, 'name': 'Fritz Mauthner'},
#  {'age': 76, 'name': 'Fyodor Ippolitovich Shcherbatskoy'},
#  {'age': 75, 'name': 'Gabriel Biel'},
#  {'age': 44, 'name': 'Gaston Frommel'},
#  {'age': 60, 'name': 'Ge Hong'},
#  {'age': 68, 'name': 'Gennadios II Scholarios'},
#  {'age': 57, 'name': 'Georg Bernhard Bilfinger'},
#  {'age': 85, 'name': 'Georg Brandes'},
#  {'age': 60, 'name': 'Georg Simmel'},
#  {'age': 61, 'name': 'Georg Wilhelm Friedrich Hegel'},
#  {'age': 68, 'name': 'George Berkeley'},
#  {'age': 97, 'name': 'George Gemistus Plethon'},
#  {'age': 70, 'name': 'George Grant'},
#  {'age': 61, 'name': 'George Henry Lewes'},
#  {'age': 68, 'name': 'George Herbert Mead'},
#  {'age': 89, 'name': 'George Santayana'},
#  {'age': 79, 'name': 'George Trumbull Ladd'},
#  {'age': 48, 'name': 'George Tyrrell'},
#  {'age': 64, 'name': 'Geraud de Cordemoy'},
#  {'age': 76, 'name': 'Giambattista Vico'},
#  {'age': 73, 'name': 'Giles of Rome'},
#  {'age': 70, 'name': 'Gilles Deleuze'},
#  {'age': 70, 'name': 'Gottfried Wilhelm Leibniz'},
#  {'age': 52, 'name': 'Gotthold Ephraim Lessing'},
#  {'age': 77, 'name': 'Gottlob Frege'},
#  {'age': 58, 'name': 'Gregory of Rimini'},
#  {'age': 69, 'name': 'Gu Yanwu'},
#  {'age': 86, 'name': 'Gustav Theodor Fechner'},
#  {'age': 80, 'name': 'Hajji Hadi Sabzevari'},
#  {'age': 69, 'name': 'Hannah Arendt'},
#  {'age': 62, 'name': 'Hans Reichenbach'},
#  {'age': 102, 'name': 'Hans-Georg Gadamer'},
#  {'age': 93, 'name': 'Harry S. Broudy'},
#  {'age': 73, 'name': 'Hatano Seiichi'},
#  {'age': 74, 'name': 'Hayashi Razan'},
#  {'age': 56, 'name': 'He Yan'},
#  {'age': 84, 'name': 'Hemachandra'},
#  {'age': 82, 'name': 'Henri Bergson'},
#  {'age': 91, 'name': 'Henri Berr'},
#  {'age': 58, 'name': 'Henri Poincare'},
#  {'age': 51, 'name': 'Henry Longueville Mansel'},
#  {'age': 62, 'name': 'Henry Sidgwick'},
#  {'age': 83, 'name': 'Herbert Spencer'},
#  {'age': 76, 'name': 'Hermann Cohen'},
#  {'age': 74, 'name': 'Hermann Samuel Reimarus'},
#  {'age': 73, 'name': 'Hermann von Helmholtz'},
#  {'age': 90, 'name': 'Hilary Putnam'},
#  {'age': 70, 'name': 'Ibn Falaquera'},
#  {'age': 48, 'name': 'Ibn Gabirol'},
#  {'age': 80, 'name': 'Immanuel Kant'},
#  {'age': 89, 'name': 'Inoue Tetsujiro'},
#  {'age': 69, 'name': 'Isaac of Stella'},
#  {'age': 75, 'name': 'Isaak August Dorner'},
#  {'age': 78, 'name': 'Ito Jinsai'},
#  {'age': 71, 'name': 'Jacob Moleschott'},
#  {'age': 74, 'name': 'Jacques Derrida'},
#  {'age': 91, 'name': 'Jacques Maritain'},
#  {'age': 38, 'name': 'Jaime Luciano Balmes'},
#  {'age': 49, 'name': 'Jakob Bohme'},
#  {'age': 56, 'name': 'James Frederick Ferrier'},
#  {'age': 75, 'name': 'James J. Gibson'},
#  {'age': 73, 'name': 'James Mark Baldwin'},
#  {'age': 95, 'name': 'James Martineau'},
#  {'age': 78, 'name': 'Jean Baudrillard'},
#  {'age': 58, 'name': 'Jean Buridan'},
#  {'age': 66, 'name': 'Jean-Jacques Rousseau'},
#  {'age': 75, 'name': 'Jean-Paul Sartre'},
#  {'age': 84, 'name': 'Jeremy Bentham'},
#  {'age': 57, 'name': 'Joachim Wach'},
#  {'age': 52, 'name': 'Johann Gottlieb Fichte'},
#  {'age': 49, 'name': 'Johann Heinrich Lambert'},
#  {'age': 56, 'name': 'John Baconthorpe'},
#  {'age': 93, 'name': 'John Dewey'},
#  {'age': 59, 'name': 'John Fiske'},
#  {'age': 49, 'name': 'John Langshaw Austin'},
#  {'age': 72, 'name': 'John Locke'},
#  {'age': 97, 'name': 'John Neville Keynes'},
#  {'age': 76, 'name': 'John Scott Haldane'},
#  {'age': 67, 'name': 'John Scotus Erigena'},
#  {'age': 67, 'name': 'John Stuart Mill'},
#  {'age': 89, 'name': 'John Venn'},
#  {'age': 54, 'name': 'John Wycliffe'},
#  {'age': 51, 'name': 'John of Paris'},
#  {'age': 60, 'name': 'John of Salisbury'},
#  {'age': 55, 'name': 'Jonathan Edwards'},
#  {'age': 72, 'name': 'Jose Ortega y Gasset'},
#  {'age': 77, 'name': 'Jose Vasconcelos'},
#  {'age': 60, 'name': 'Joseph Butler'},
#  {'age': 71, 'name': 'Joseph Priestley'},
#  {'age': 61, 'name': 'Josiah Royce'},
#  {'age': 88, 'name': 'Julian Huxley'},
#  {'age': 59, 'name': 'Justus Lipsius'},
#  {'age': 86, 'name': 'Karl Jaspers'},
#  {'age': 65, 'name': 'Karl Marx'},
#  {'age': 92, 'name': 'Karl Popper'},
#  {'age': 72, 'name': 'Kumazawa Banzan'},
#  {'age': 68, 'name': 'Leopold Kronecker'},
#  {'age': 56, 'name': 'Levi ben Gershom'},
#  {'age': 69, 'name': 'Li Ao'},
#  {'age': 95, 'name': 'Liang Shuming'},
#  {'age': 50, 'name': 'Lorenzo Valla'},
#  {'age': 72, 'name': 'Louis Althusser'},
#  {'age': 68, 'name': 'Louis Lavelle'},
#  {'age': 46, 'name': 'Louis-Alexandre Couturat'},
#  {'age': 54, 'name': 'Lu Jiuyuan'},
#  {'age': 82, 'name': 'Lucien Levy-Bruhl'},
#  {'age': 84, 'name': 'Ludwig Klages'},
#  {'age': 62, 'name': 'Ludwig Wittgenstein'},
#  {'age': 79, 'name': 'Madhva'},
#  {'age': 81, 'name': 'Maria Gaetana Agnesi'},
#  {'age': 58, 'name': 'Marie-Francois-Pierre Maine de Biran'},
#  {'age': 60, 'name': 'Marin Mersenne'},
#  {'age': 99, 'name': 'Marjorie Grene'},
#  {'age': 74, 'name': 'Marko Marulic'},
#  {'age': 66, 'name': 'Marsilio Ficino'},
#  {'age': 88, 'name': 'Maurice Blondel'},
#  {'age': 53, 'name': 'Maurice Merleau-Ponty'},
#  {'age': 79, 'name': 'Max Black'},
#  {'age': 54, 'name': 'Max Scheler'},
#  {'age': 50, 'name': 'Max Stirner'},
#  {'age': 58, 'name': 'Michel Foucault'},
#  {'age': 79, 'name': 'Moritz Lazarus'},
#  {'age': 99, 'name': 'Mortimer J. Adler'},
#  {'age': 69, 'name': 'Moses Maimonides'},
#  {'age': 57, 'name': 'Moses Mendelssohn'},
#  {'age': 69, 'name': 'Mulla Sadra'},
#  {'age': 76, 'name': 'Muro Kyuso'},
#  {'age': 33, 'name': 'Nathanael Culverwel'},
#  {'age': 63, 'name': 'Nicholas of Cusa'},
#  {'age': 63, 'name': 'Nikolay Yakovlevich Danilevsky'},
#  {'age': 75, 'name': 'Nishida Kitaro'},
#  {'age': 69, 'name': 'Norman Robert Campbell'},
#  {'age': 53, 'name': 'Oswald Kulpe'},
#  {'age': 56, 'name': 'Oswald Spengler'},
#  {'age': 80, 'name': 'Otto Friedrich von Gierke'},
#  {'age': 63, 'name': 'Otto Neurath'},
#  {'age': 77, 'name': 'Paul Shorey'},
#  {'age': 79, 'name': 'Paul Tillich'},
#  {'age': 57, 'name': 'Paul of Venice'},
#  {'age': 59, 'name': 'Pierre Bayle'},
#  {'age': 63, 'name': 'Pierre Gassendi'},
#  {'age': 81, 'name': 'Pierre Laromiguiere'},
#  {'age': 74, 'name': 'Pierre Leroux'},
#  {'age': 70, 'name': 'Pierre Nicole'},
#  {'age': 74, 'name': 'Pierre Teilhard de Chardin'},
#  {'age': 62, 'name': 'Pierre-Felix Guattari'},
#  {'age': 63, 'name': 'Pietro Pomponazzi'},
#  {'age': 75, 'name': 'Raghunatha Shiromani'},
#  {'age': 71, 'name': 'Ramana Maharshi'},
#  {'age': 120, 'name': 'Ramanuja'},
#  {'age': 83, 'name': 'Ramon Llull'},
#  {'age': 79, 'name': 'Reinhold Niebuhr'},
#  {'age': 54, 'name': 'Rene Descartes'},
#  {'age': 46, 'name': 'Richard Hooker'},
#  {'age': 68, 'name': 'Richard Price'},
#  {'age': 64, 'name': 'Robert Boyle'},
#  {'age': 78, 'name': 'Robert Grosseteste'},
#  {'age': 72, 'name': 'Roger Bacon'},
#  {'age': 92, 'name': 'Rudolf Bultmann'},
#  {'age': 79, 'name': 'Rudolf Carnap'},
#  {'age': 68, 'name': 'Rudolf Otto'},
#  {'age': 46, 'name': 'Salomon Maimon'},
#  {'age': 79, 'name': 'Samuel Alexander'},
#  {'age': 79, 'name': 'Samuel Bailey'},
#  {'age': 74, 'name': 'Samuel Hirsch'},
#  {'age': 50, 'name': 'Shankara'},
#  {'age': 66, 'name': 'Shao Yong'},
#  {'age': 78, 'name': 'Shri Aurobindo'},
#  {'age': 87, 'name': 'Sidney Hook'},
#  {'age': 52, 'name': 'Simon Foucher'},
#  {'age': 34, 'name': 'Simone Weil'},
#  {'age': 81, 'name': 'Solomon Formstecher'},
#  {'age': 42, 'name': 'Soren Kierkegaard'},
#  {'age': 53, 'name': 'Stanislaw Lesniewski'},
#  {'age': 87, 'name': 'Stephen Edelston Toulmin'},
#  {'age': 90, 'name': 'Susanne K. Langer'},
#  {'age': 57, 'name': 'Taixu'},
#  {'age': 74, 'name': 'Tao Sheng'},
#  {'age': 80, 'name': 'Theodor Gomperz'},
#  {'age': 66, 'name': 'Theodor Wiesengrund Adorno'},
#  {'age': 75, 'name': 'Theodosius Dobzhansky'},
#  {'age': 70, 'name': 'Thomas Henry Huxley'},
#  {'age': 91, 'name': 'Thomas Hobbes'},
#  {'age': 86, 'name': 'Thomas Reid'},
#  {'age': 71, 'name': 'Tommaso Campanella'},
#  {'age': 55, 'name': 'Uriel Acosta'},
#  {'age': 52, 'name': 'Vallabha'},
#  {'age': 47, 'name': 'Vladimir Sergeyevich Solovyov'},
#  {'age': 48, 'name': 'Walter Benjamin'},
#  {'age': 23, 'name': 'Wang Bi'},
#  {'age': 73, 'name': 'Wang Chong'},
#  {'age': 57, 'name': 'Wang Yangming'},
#  {'age': 71, 'name': 'Watsuji Tetsuro'},
#  {'age': 75, 'name': 'Werner Heisenberg'},
#  {'age': 77, 'name': 'Wilfrid Sellars'},
#  {'age': 78, 'name': 'Wilhelm Dilthey'},
#  {'age': 92, 'name': 'Willard Van Orman Quine'},
#  {'age': 80, 'name': 'William Godwin'},
#  {'age': 68, 'name': 'William James'},
#  {'age': 34, 'name': 'William Kingdon Clifford'},
#  {'age': 62, 'name': 'William Paley'},
#  {'age': 94, 'name': 'William Ralph Inge'},
#  {'age': 72, 'name': 'William Whewell'},
#  {'age': 81, 'name': 'William of Auxerre'},
#  {'age': 51, 'name': 'William of Champeaux'},
#  {'age': 64, 'name': 'William of Ockham'},
#  {'age': 83, 'name': 'Xiong Shili'},
#  {'age': 69, 'name': 'Yan Yuan'},
#  {'age': 57, 'name': 'Zhang Zai'},
#  {'age': 56, 'name': 'Zhou Dunyi'},
#  {'age': 70, 'name': 'Zhu Xi'},
#  {'age': 72, 'name': 'al-Farabi'},
#  {'age': 53, 'name': 'al-Ghazali'}]
# CPU times: user 39.5 ms, sys: 21.2 ms, total: 60.6 ms
# Wall time: 1.78 s

# %% [markdown]
# ## Concurrent.futures
#
#
# More modern way of handling multiprocessing in Python

# %%
# %%time
# !python concurrent_example.py
# Out:
# Process ID 93472 is processing philosopher: Aaron David Gordon
# Process ID 93468 is processing philosopher: Abraham Joshua Heschel
# Process ID 93472 is processing philosopher: Albert of Saxony
# Process ID 93467 is processing philosopher: Alessandro Achillini
# Process ID 93468 is processing philosopher: Alexander Gottlieb Baumgarten
# Process ID 93469 is processing philosopher: Alexius Meinong
# Process ID 93472 is processing philosopher: Alfred Firmin Loisy
# Process ID 93475 is processing philosopher: Alfred Korzybski
# Process ID 93467 is processing philosopher: Alfred North Whitehead
# Process ID 93468 is processing philosopher: Allan Bloom
# Process ID 93470 is processing philosopher: Anicius Manlius Severinus Boethius
# Process ID 93469 is processing philosopher: Antonio Labriola
# Process ID 93473 is processing philosopher: Antonio Rosmini-Serbati
# Process ID 93472 is processing philosopher: Antony Flew
# Process ID 93475 is processing philosopher: Armando Carlini
# Process ID 93467 is processing philosopher: Arthur O. Lovejoy
# Process ID 93468 is processing philosopher: Arthur Schopenhauer
# Process ID 93471 is processing philosopher: Arthur Stanley Eddington
# Process ID 93469 is processing philosopher: Ashvaghosha
# Process ID 93470 is processing philosopher: Auguste Comte
# Process ID 93473 is processing philosopher: Averroes
# Process ID 93476 is processing philosopher: Avicenna
# Process ID 93472 is processing philosopher: Bartolome de Medina
# Process ID 93475 is processing philosopher: Benedetto Croce
# Process ID 93467 is processing philosopher: Benedict de Spinoza
# Process ID 93469 is processing philosopher: Bernard Bosanquet
# Process ID 93468 is processing philosopher: Bernard de Mandeville
# Process ID 93470 is processing philosopher: Bertrand Russell
# Process ID 93471 is processing philosopher: Bessarion
# Process ID 93476 is processing philosopher: Bhartrihari
# Process ID 93473 is processing philosopher: Blaise Pascal
# Process ID 93472 is processing philosopher: Blessed John Duns Scotus
# Process ID 93475 is processing philosopher: Carl Gustav Hempel
# Process ID 93471 is processing philosopher: Charles Sanders Peirce
# Process ID 93467 is processing philosopher: Cheng Hao
# Process ID 93469 is processing philosopher: Cheng Yi
# Process ID 93476 is processing philosopher: Claude-Adrien Helvetius
# Process ID 93468 is processing philosopher: David Friedrich Strauss
# Process ID 93470 is processing philosopher: David Hartley
# Process ID 93473 is processing philosopher: David Hume
# Process ID 93472 is processing philosopher: David Ross
# Process ID 93475 is processing philosopher: Denis Diderot
# Process ID 93469 is processing philosopher: Derek Parfit
# Process ID 93471 is processing philosopher: Edith Stein
# Process ID 93467 is processing philosopher: Edmund Husserl
# Process ID 93470 is processing philosopher: Eduard von Hartmann
# Process ID 93476 is processing philosopher: Edward Caird
# Process ID 93468 is processing philosopher: Edward Westermarck
# Process ID 93472 is processing philosopher: Emmanuel Levinas
# Process ID 93475 is processing philosopher: Erich Frank
# Process ID 93473 is processing philosopher: Erich Fromm
# Process ID 93469 is processing philosopher: Ernest Nagel
# Process ID 93476 is processing philosopher: Ernest Renan
# Process ID 93471 is processing philosopher: Ernst Mach
# Process ID 93470 is processing philosopher: Ernst Troeltsch
# Process ID 93467 is processing philosopher: Erwin Schrodinger
# Process ID 93474 is processing philosopher: Etienne Bonnot de Condillac
# Process ID 93468 is processing philosopher: Etienne Gilson
# Process ID 93473 is processing philosopher: Ferdinand Christian Baur
# Process ID 93472 is processing philosopher: Francis Hutcheson
# Process ID 93475 is processing philosopher: Francisco Suarez
# Process ID 93469 is processing philosopher: Franciscus Hemsterhuis
# Process ID 93476 is processing philosopher: Franz Brentano
# Process ID 93470 is processing philosopher: Franz Rosenzweig
# Process ID 93471 is processing philosopher: Frederick Robert Tennant
# Process ID 93467 is processing philosopher: Friedrich Nietzsche
# Process ID 93468 is processing philosopher: Friedrich Schleiermacher
# Process ID 93474 is processing philosopher: Friedrich Theodor von Vischer
# Process ID 93472 is processing philosopher: Friedrich Wilhelm Joseph von Schelling
# Process ID 93473 is processing philosopher: Fritz Mauthner
# Process ID 93475 is processing philosopher: Fyodor Ippolitovich Shcherbatskoy
# Process ID 93471 is processing philosopher: Gabriel Biel
# Process ID 93469 is processing philosopher: Gaston Frommel
# Process ID 93476 is processing philosopher: Ge Hong
# Process ID 93470 is processing philosopher: Gennadios II Scholarios
# Process ID 93467 is processing philosopher: Georg Bernhard Bilfinger
# Process ID 93468 is processing philosopher: Georg Brandes
# Process ID 93474 is processing philosopher: Georg Simmel
# Process ID 93472 is processing philosopher: Georg Wilhelm Friedrich Hegel
# Process ID 93475 is processing philosopher: George Berkeley
# Process ID 93473 is processing philosopher: George Gemistus Plethon
# Process ID 93476 is processing philosopher: George Grant
# Process ID 93471 is processing philosopher: George Henry Lewes
# Process ID 93469 is processing philosopher: George Herbert Mead
# Process ID 93468 is processing philosopher: George Santayana
# Process ID 93467 is processing philosopher: George Trumbull Ladd
# Process ID 93474 is processing philosopher: George Tyrrell
# Process ID 93470 is processing philosopher: Geraud de Cordemoy
# Process ID 93472 is processing philosopher: Giambattista Vico
# Process ID 93475 is processing philosopher: Giles of Rome
# Process ID 93473 is processing philosopher: Gilles Deleuze
# Process ID 93474 is processing philosopher: Gottfried Wilhelm Leibniz
# Process ID 93470 is processing philosopher: Gotthold Ephraim Lessing
# Process ID 93476 is processing philosopher: Gottlob Frege
# Process ID 93467 is processing philosopher: Gregory of Rimini
# Process ID 93471 is processing philosopher: Gu Yanwu
# Process ID 93469 is processing philosopher: Gustav Theodor Fechner
# Process ID 93468 is processing philosopher: Hajji Hadi Sabzevari
# Process ID 93472 is processing philosopher: Hannah Arendt
# Process ID 93475 is processing philosopher: Hans Reichenbach
# Process ID 93473 is processing philosopher: Hans-Georg Gadamer
# Process ID 93468 is processing philosopher: Harry S. Broudy
# Process ID 93470 is processing philosopher: Hatano Seiichi
# Process ID 93471 is processing philosopher: Hayashi Razan
# Process ID 93474 is processing philosopher: He Yan
# Process ID 93467 is processing philosopher: Hemachandra
# Process ID 93476 is processing philosopher: Henri Bergson
# Process ID 93469 is processing philosopher: Henri Berr
# Process ID 93472 is processing philosopher: Henri Poincare
# Process ID 93475 is processing philosopher: Henry Longueville Mansel
# Process ID 93473 is processing philosopher: Henry Sidgwick
# Process ID 93468 is processing philosopher: Herbert Spencer
# Process ID 93476 is processing philosopher: Hermann Cohen
# Process ID 93470 is processing philosopher: Hermann Samuel Reimarus
# Process ID 93471 is processing philosopher: Hermann von Helmholtz
# Process ID 93469 is processing philosopher: Hilary Putnam
# Process ID 93474 is processing philosopher: Ibn Falaquera
# Process ID 93467 is processing philosopher: Ibn Gabirol
# Process ID 93472 is processing philosopher: Immanuel Kant
# Process ID 93473 is processing philosopher: Inoue Tetsujiro
# Process ID 93475 is processing philosopher: Isaac of Stella
# Process ID 93468 is processing philosopher: Isaak August Dorner
# Process ID 93471 is processing philosopher: Jacob Moleschott
# Process ID 93476 is processing philosopher: Ito Jinsai
# Process ID 93470 is processing philosopher: Jacques Derrida
# Process ID 93469 is processing philosopher: Jacques Maritain
# Process ID 93467 is processing philosopher: Jaime Luciano Balmes
# Process ID 93474 is processing philosopher: Jakob Bohme
# Process ID 93472 is processing philosopher: James Frederick Ferrier
# Process ID 93473 is processing philosopher: James J. Gibson
# Process ID 93475 is processing philosopher: James Mark Baldwin
# Process ID 93470 is processing philosopher: James Martineau
# Process ID 93476 is processing philosopher: Jean Baudrillard
# Process ID 93469 is processing philosopher: Jean Buridan
# Process ID 93468 is processing philosopher: Jean-Jacques Rousseau
# Process ID 93467 is processing philosopher: Jean-Paul Sartre
# Process ID 93471 is processing philosopher: Jeremy Bentham
# Process ID 93474 is processing philosopher: Joachim Wach
# Process ID 93475 is processing philosopher: Johann Gottlieb Fichte
# Process ID 93472 is processing philosopher: Johann Heinrich Lambert
# Process ID 93473 is processing philosopher: John Baconthorpe
# Process ID 93476 is processing philosopher: John Dewey
# Process ID 93467 is processing philosopher: John Fiske
# Process ID 93474 is processing philosopher: John Langshaw Austin
# Process ID 93468 is processing philosopher: John Locke
# Process ID 93469 is processing philosopher: John Neville Keynes
# Process ID 93470 is processing philosopher: John Scott Haldane
# Process ID 93471 is processing philosopher: John Scotus Erigena
# Process ID 93475 is processing philosopher: John Stuart Mill
# Process ID 93472 is processing philosopher: John Venn
# Process ID 93473 is processing philosopher: John Wycliffe
# Process ID 93476 is processing philosopher: John of Paris
# Process ID 93471 is processing philosopher: John of Salisbury
# Process ID 93469 is processing philosopher: Jonathan Edwards
# Process ID 93474 is processing philosopher: Jose Ortega y Gasset
# Process ID 93467 is processing philosopher: Jose Vasconcelos
# Process ID 93470 is processing philosopher: Joseph Butler
# Process ID 93468 is processing philosopher: Joseph Priestley
# Process ID 93475 is processing philosopher: Josiah Royce
# Process ID 93472 is processing philosopher: Julian Huxley
# Process ID 93473 is processing philosopher: Justus Lipsius
# Process ID 93471 is processing philosopher: Karl Jaspers
# Process ID 93469 is processing philosopher: Karl Marx
# Process ID 93476 is processing philosopher: Karl Popper
# Process ID 93468 is processing philosopher: Kumazawa Banzan
# Process ID 93474 is processing philosopher: Leopold Kronecker
# Process ID 93467 is processing philosopher: Levi ben Gershom
# Process ID 93470 is processing philosopher: Li Ao
# Process ID 93475 is processing philosopher: Liang Shuming
# Process ID 93472 is processing philosopher: Lorenzo Valla
# Process ID 93473 is processing philosopher: Louis Althusser
# Process ID 93471 is processing philosopher: Louis Lavelle
# Process ID 93470 is processing philosopher: Louis-Alexandre Couturat
# Process ID 93474 is processing philosopher: Lu Jiuyuan
# Process ID 93468 is processing philosopher: Lucien Levy-Bruhl
# Process ID 93469 is processing philosopher: Ludwig Klages
# Process ID 93476 is processing philosopher: Ludwig Wittgenstein
# Process ID 93467 is processing philosopher: Madhva
# Process ID 93475 is processing philosopher: Maria Gaetana Agnesi
# Process ID 93472 is processing philosopher: Marie-Francois-Pierre Maine de Biran
# Process ID 93473 is processing philosopher: Marin Mersenne
# Process ID 93474 is processing philosopher: Marjorie Grene
# Process ID 93470 is processing philosopher: Marko Marulic
# Process ID 93468 is processing philosopher: Marsilio Ficino
# Process ID 93476 is processing philosopher: Maurice Blondel
# Process ID 93467 is processing philosopher: Maurice Merleau-Ponty
# Process ID 93471 is processing philosopher: Max Black
# Process ID 93469 is processing philosopher: Max Scheler
# Process ID 93475 is processing philosopher: Max Stirner
# Process ID 93472 is processing philosopher: Michel Foucault
# Process ID 93473 is processing philosopher: Moritz Lazarus
# Process ID 93474 is processing philosopher: Mortimer J. Adler
# Process ID 93470 is processing philosopher: Moses Maimonides
# Process ID 93476 is processing philosopher: Moses Mendelssohn
# Process ID 93468 is processing philosopher: Mulla Sadra
# Process ID 93467 is processing philosopher: Muro Kyuso
# Process ID 93471 is processing philosopher: Nathanael Culverwel
# Process ID 93469 is processing philosopher: Nicholas of Cusa
# Process ID 93472 is processing philosopher: Nikolay Yakovlevich Danilevsky
# Process ID 93475 is processing philosopher: Nishida Kitaro
# Process ID 93474 is processing philosopher: Norman Robert Campbell
# Process ID 93473 is processing philosopher: Oswald Kulpe
# Process ID 93470 is processing philosopher: Oswald Spengler
# Process ID 93476 is processing philosopher: Otto Friedrich von Gierke
# Process ID 93469 is processing philosopher: Otto Neurath
# Process ID 93468 is processing philosopher: Paul Shorey
# Process ID 93467 is processing philosopher: Paul Tillich
# Process ID 93471 is processing philosopher: Paul of Venice
# Process ID 93472 is processing philosopher: Pierre Bayle
# Process ID 93475 is processing philosopher: Pierre Gassendi
# Process ID 93470 is processing philosopher: Pierre Laromiguiere
# Process ID 93474 is processing philosopher: Pierre Leroux
# Process ID 93473 is processing philosopher: Pierre Nicole
# Process ID 93476 is processing philosopher: Pierre Teilhard de Chardin
# Process ID 93469 is processing philosopher: Pierre-Felix Guattari
# Process ID 93471 is processing philosopher: Pietro Pomponazzi
# Process ID 93468 is processing philosopher: Raghunatha Shiromani
# Process ID 93467 is processing philosopher: Ramana Maharshi
# Process ID 93472 is processing philosopher: Ramanuja
# Process ID 93475 is processing philosopher: Ramon Llull
# Process ID 93474 is processing philosopher: Reinhold Niebuhr
# Process ID 93470 is processing philosopher: Rene Descartes
# Process ID 93473 is processing philosopher: Richard Hooker
# Process ID 93476 is processing philosopher: Richard Price
# Process ID 93467 is processing philosopher: Robert Boyle
# Process ID 93471 is processing philosopher: Robert Grosseteste
# Process ID 93469 is processing philosopher: Roger Bacon
# Process ID 93468 is processing philosopher: Rudolf Bultmann
# Process ID 93472 is processing philosopher: Rudolf Carnap
# Process ID 93475 is processing philosopher: Rudolf Otto
# Process ID 93474 is processing philosopher: Salomon Maimon
# Process ID 93470 is processing philosopher: Samuel Alexander
# Process ID 93473 is processing philosopher: Samuel Bailey
# Process ID 93476 is processing philosopher: Samuel Hirsch
# Process ID 93467 is processing philosopher: Shankara
# Process ID 93469 is processing philosopher: Shao Yong
# Process ID 93471 is processing philosopher: Shri Aurobindo
# Process ID 93468 is processing philosopher: Sidney Hook
# Process ID 93472 is processing philosopher: Simon Foucher
# Process ID 93475 is processing philosopher: Simone Weil
# Process ID 93474 is processing philosopher: Solomon Formstecher
# Process ID 93470 is processing philosopher: Soren Kierkegaard
# Process ID 93473 is processing philosopher: Stanislaw Lesniewski
# Process ID 93476 is processing philosopher: Stephen Edelston Toulmin
# Process ID 93467 is processing philosopher: Susanne K. Langer
# Process ID 93469 is processing philosopher: Taixu
# Process ID 93468 is processing philosopher: Tao Sheng
# Process ID 93471 is processing philosopher: Theodor Gomperz
# Process ID 93474 is processing philosopher: Theodor Wiesengrund Adorno
# Process ID 93472 is processing philosopher: Theodosius Dobzhansky
# Process ID 93475 is processing philosopher: Thomas Henry Huxley
# Process ID 93473 is processing philosopher: Thomas Hobbes
# Process ID 93470 is processing philosopher: Thomas Reid
# Process ID 93476 is processing philosopher: Tommaso Campanella
# Process ID 93467 is processing philosopher: Uriel Acosta
# Process ID 93469 is processing philosopher: Vallabha
# Process ID 93468 is processing philosopher: Vladimir Sergeyevich Solovyov
# Process ID 93471 is processing philosopher: Walter Benjamin
# Process ID 93474 is processing philosopher: Wang Bi
# Process ID 93472 is processing philosopher: Wang Chong
# Process ID 93475 is processing philosopher: Wang Yangming
# Process ID 93473 is processing philosopher: Watsuji Tetsuro
# Process ID 93470 is processing philosopher: Werner Heisenberg
# Process ID 93476 is processing philosopher: Wilfrid Sellars
# Process ID 93467 is processing philosopher: Wilhelm Dilthey
# Process ID 93469 is processing philosopher: Willard Van Orman Quine
# Process ID 93468 is processing philosopher: William Godwin
# Process ID 93471 is processing philosopher: William James
# Process ID 93474 is processing philosopher: William Kingdon Clifford
# Process ID 93475 is processing philosopher: William Paley
# Process ID 93472 is processing philosopher: William Ralph Inge
# Process ID 93473 is processing philosopher: William Whewell
# Process ID 93470 is processing philosopher: William of Auxerre
# Process ID 93469 is processing philosopher: William of Champeaux
# Process ID 93476 is processing philosopher: William of Ockham
# Process ID 93467 is processing philosopher: Xiong Shili
# Process ID 93468 is processing philosopher: Yan Yuan
# Process ID 93471 is processing philosopher: Zhang Zai
# Process ID 93474 is processing philosopher: Zhou Dunyi
# Process ID 93475 is processing philosopher: Zhu Xi
# Process ID 93472 is processing philosopher: al-Farabi
# Process ID 93473 is processing philosopher: al-Ghazali
# ({'age': 66, 'name': 'Aaron David Gordon'},
#  {'age': 65, 'name': 'Abraham Joshua Heschel'},
#  {'age': 74, 'name': 'Albert of Saxony'},
#  {'age': 49, 'name': 'Alessandro Achillini'},
#  {'age': 48, 'name': 'Alexander Gottlieb Baumgarten'},
#  {'age': 67, 'name': 'Alexius Meinong'},
#  {'age': 83, 'name': 'Alfred Firmin Loisy'},
#  {'age': 71, 'name': 'Alfred Korzybski'},
#  {'age': 86, 'name': 'Alfred North Whitehead'},
#  {'age': 62, 'name': 'Allan Bloom'},
#  {'age': 49, 'name': 'Anicius Manlius Severinus Boethius'},
#  {'age': 61, 'name': 'Antonio Labriola'},
#  {'age': 58, 'name': 'Antonio Rosmini-Serbati'},
#  {'age': 87, 'name': 'Antony Flew'},
#  {'age': 81, 'name': 'Armando Carlini'},
#  {'age': 89, 'name': 'Arthur O. Lovejoy'},
#  {'age': 72, 'name': 'Arthur Schopenhauer'},
#  {'age': 62, 'name': 'Arthur Stanley Eddington'},
#  {'age': 70, 'name': 'Ashvaghosha'},
#  {'age': 59, 'name': 'Auguste Comte'},
#  {'age': 72, 'name': 'Averroes'},
#  {'age': 57, 'name': 'Avicenna'},
#  {'age': 52, 'name': 'Bartolome de Medina'},
#  {'age': 86, 'name': 'Benedetto Croce'},
#  {'age': 45, 'name': 'Benedict de Spinoza'},
#  {'age': 75, 'name': 'Bernard Bosanquet'},
#  {'age': 63, 'name': 'Bernard de Mandeville'},
#  {'age': 98, 'name': 'Bertrand Russell'},
#  {'age': 69, 'name': 'Bessarion'},
#  {'age': 81, 'name': 'Bhartrihari'},
#  {'age': 39, 'name': 'Blaise Pascal'},
#  {'age': 42, 'name': 'Blessed John Duns Scotus'},
#  {'age': 92, 'name': 'Carl Gustav Hempel'},
#  {'age': 75, 'name': 'Charles Sanders Peirce'},
#  {'age': 53, 'name': 'Cheng Hao'},
#  {'age': 74, 'name': 'Cheng Yi'},
#  {'age': 56, 'name': 'Claude-Adrien Helvetius'},
#  {'age': 66, 'name': 'David Friedrich Strauss'},
#  {'age': 52, 'name': 'David Hartley'},
#  {'age': 65, 'name': 'David Hume'},
#  {'age': 94, 'name': 'David Ross'},
#  {'age': 71, 'name': 'Denis Diderot'},
#  {'age': 75, 'name': 'Derek Parfit'},
#  {'age': 51, 'name': 'Edith Stein'},
#  {'age': 79, 'name': 'Edmund Husserl'},
#  {'age': 64, 'name': 'Eduard von Hartmann'},
#  {'age': 73, 'name': 'Edward Caird'},
#  {'age': 77, 'name': 'Edward Westermarck'},
#  {'age': 89, 'name': 'Emmanuel Levinas'},
#  {'age': 66, 'name': 'Erich Frank'},
#  {'age': 80, 'name': 'Erich Fromm'},
#  {'age': 84, 'name': 'Ernest Nagel'},
#  {'age': 69, 'name': 'Ernest Renan'},
#  {'age': 78, 'name': 'Ernst Mach'},
#  {'age': 58, 'name': 'Ernst Troeltsch'},
#  {'age': 74, 'name': 'Erwin Schrodinger'},
#  {'age': 65, 'name': 'Etienne Bonnot de Condillac'},
#  {'age': 94, 'name': 'Etienne Gilson'},
#  {'age': 68, 'name': 'Ferdinand Christian Baur'},
#  {'age': 52, 'name': 'Francis Hutcheson'},
#  {'age': 69, 'name': 'Francisco Suarez'},
#  {'age': 69, 'name': 'Franciscus Hemsterhuis'},
#  {'age': 79, 'name': 'Franz Brentano'},
#  {'age': 43, 'name': 'Franz Rosenzweig'},
#  {'age': 91, 'name': 'Frederick Robert Tennant'},
#  {'age': 56, 'name': 'Friedrich Nietzsche'},
#  {'age': 66, 'name': 'Friedrich Schleiermacher'},
#  {'age': 80, 'name': 'Friedrich Theodor von Vischer'},
#  {'age': 79, 'name': 'Friedrich Wilhelm Joseph von Schelling'},
#  {'age': 74, 'name': 'Fritz Mauthner'},
#  {'age': 76, 'name': 'Fyodor Ippolitovich Shcherbatskoy'},
#  {'age': 75, 'name': 'Gabriel Biel'},
#  {'age': 44, 'name': 'Gaston Frommel'},
#  {'age': 60, 'name': 'Ge Hong'},
#  {'age': 68, 'name': 'Gennadios II Scholarios'},
#  {'age': 57, 'name': 'Georg Bernhard Bilfinger'},
#  {'age': 85, 'name': 'Georg Brandes'},
#  {'age': 60, 'name': 'Georg Simmel'},
#  {'age': 61, 'name': 'Georg Wilhelm Friedrich Hegel'},
#  {'age': 68, 'name': 'George Berkeley'},
#  {'age': 97, 'name': 'George Gemistus Plethon'},
#  {'age': 70, 'name': 'George Grant'},
#  {'age': 61, 'name': 'George Henry Lewes'},
#  {'age': 68, 'name': 'George Herbert Mead'},
#  {'age': 89, 'name': 'George Santayana'},
#  {'age': 79, 'name': 'George Trumbull Ladd'},
#  {'age': 48, 'name': 'George Tyrrell'},
#  {'age': 64, 'name': 'Geraud de Cordemoy'},
#  {'age': 76, 'name': 'Giambattista Vico'},
#  {'age': 73, 'name': 'Giles of Rome'},
#  {'age': 70, 'name': 'Gilles Deleuze'},
#  {'age': 70, 'name': 'Gottfried Wilhelm Leibniz'},
#  {'age': 52, 'name': 'Gotthold Ephraim Lessing'},
#  {'age': 77, 'name': 'Gottlob Frege'},
#  {'age': 58, 'name': 'Gregory of Rimini'},
#  {'age': 69, 'name': 'Gu Yanwu'},
#  {'age': 86, 'name': 'Gustav Theodor Fechner'},
#  {'age': 80, 'name': 'Hajji Hadi Sabzevari'},
#  {'age': 69, 'name': 'Hannah Arendt'},
#  {'age': 62, 'name': 'Hans Reichenbach'},
#  {'age': 102, 'name': 'Hans-Georg Gadamer'},
#  {'age': 93, 'name': 'Harry S. Broudy'},
#  {'age': 73, 'name': 'Hatano Seiichi'},
#  {'age': 74, 'name': 'Hayashi Razan'},
#  {'age': 56, 'name': 'He Yan'},
#  {'age': 84, 'name': 'Hemachandra'},
#  {'age': 82, 'name': 'Henri Bergson'},
#  {'age': 91, 'name': 'Henri Berr'},
#  {'age': 58, 'name': 'Henri Poincare'},
#  {'age': 51, 'name': 'Henry Longueville Mansel'},
#  {'age': 62, 'name': 'Henry Sidgwick'},
#  {'age': 83, 'name': 'Herbert Spencer'},
#  {'age': 76, 'name': 'Hermann Cohen'},
#  {'age': 74, 'name': 'Hermann Samuel Reimarus'},
#  {'age': 73, 'name': 'Hermann von Helmholtz'},
#  {'age': 90, 'name': 'Hilary Putnam'},
#  {'age': 70, 'name': 'Ibn Falaquera'},
#  {'age': 48, 'name': 'Ibn Gabirol'},
#  {'age': 80, 'name': 'Immanuel Kant'},
#  {'age': 89, 'name': 'Inoue Tetsujiro'},
#  {'age': 69, 'name': 'Isaac of Stella'},
#  {'age': 75, 'name': 'Isaak August Dorner'},
#  {'age': 78, 'name': 'Ito Jinsai'},
#  {'age': 71, 'name': 'Jacob Moleschott'},
#  {'age': 74, 'name': 'Jacques Derrida'},
#  {'age': 91, 'name': 'Jacques Maritain'},
#  {'age': 38, 'name': 'Jaime Luciano Balmes'},
#  {'age': 49, 'name': 'Jakob Bohme'},
#  {'age': 56, 'name': 'James Frederick Ferrier'},
#  {'age': 75, 'name': 'James J. Gibson'},
#  {'age': 73, 'name': 'James Mark Baldwin'},
#  {'age': 95, 'name': 'James Martineau'},
#  {'age': 78, 'name': 'Jean Baudrillard'},
#  {'age': 58, 'name': 'Jean Buridan'},
#  {'age': 66, 'name': 'Jean-Jacques Rousseau'},
#  {'age': 75, 'name': 'Jean-Paul Sartre'},
#  {'age': 84, 'name': 'Jeremy Bentham'},
#  {'age': 57, 'name': 'Joachim Wach'},
#  {'age': 52, 'name': 'Johann Gottlieb Fichte'},
#  {'age': 49, 'name': 'Johann Heinrich Lambert'},
#  {'age': 56, 'name': 'John Baconthorpe'},
#  {'age': 93, 'name': 'John Dewey'},
#  {'age': 59, 'name': 'John Fiske'},
#  {'age': 49, 'name': 'John Langshaw Austin'},
#  {'age': 72, 'name': 'John Locke'},
#  {'age': 97, 'name': 'John Neville Keynes'},
#  {'age': 76, 'name': 'John Scott Haldane'},
#  {'age': 67, 'name': 'John Scotus Erigena'},
#  {'age': 67, 'name': 'John Stuart Mill'},
#  {'age': 89, 'name': 'John Venn'},
#  {'age': 54, 'name': 'John Wycliffe'},
#  {'age': 51, 'name': 'John of Paris'},
#  {'age': 60, 'name': 'John of Salisbury'},
#  {'age': 55, 'name': 'Jonathan Edwards'},
#  {'age': 72, 'name': 'Jose Ortega y Gasset'},
#  {'age': 77, 'name': 'Jose Vasconcelos'},
#  {'age': 60, 'name': 'Joseph Butler'},
#  {'age': 71, 'name': 'Joseph Priestley'},
#  {'age': 61, 'name': 'Josiah Royce'},
#  {'age': 88, 'name': 'Julian Huxley'},
#  {'age': 59, 'name': 'Justus Lipsius'},
#  {'age': 86, 'name': 'Karl Jaspers'},
#  {'age': 65, 'name': 'Karl Marx'},
#  {'age': 92, 'name': 'Karl Popper'},
#  {'age': 72, 'name': 'Kumazawa Banzan'},
#  {'age': 68, 'name': 'Leopold Kronecker'},
#  {'age': 56, 'name': 'Levi ben Gershom'},
#  {'age': 69, 'name': 'Li Ao'},
#  {'age': 95, 'name': 'Liang Shuming'},
#  {'age': 50, 'name': 'Lorenzo Valla'},
#  {'age': 72, 'name': 'Louis Althusser'},
#  {'age': 68, 'name': 'Louis Lavelle'},
#  {'age': 46, 'name': 'Louis-Alexandre Couturat'},
#  {'age': 54, 'name': 'Lu Jiuyuan'},
#  {'age': 82, 'name': 'Lucien Levy-Bruhl'},
#  {'age': 84, 'name': 'Ludwig Klages'},
#  {'age': 62, 'name': 'Ludwig Wittgenstein'},
#  {'age': 79, 'name': 'Madhva'},
#  {'age': 81, 'name': 'Maria Gaetana Agnesi'},
#  {'age': 58, 'name': 'Marie-Francois-Pierre Maine de Biran'},
#  {'age': 60, 'name': 'Marin Mersenne'},
#  {'age': 99, 'name': 'Marjorie Grene'},
#  {'age': 74, 'name': 'Marko Marulic'},
#  {'age': 66, 'name': 'Marsilio Ficino'},
#  {'age': 88, 'name': 'Maurice Blondel'},
#  {'age': 53, 'name': 'Maurice Merleau-Ponty'},
#  {'age': 79, 'name': 'Max Black'},
#  {'age': 54, 'name': 'Max Scheler'},
#  {'age': 50, 'name': 'Max Stirner'},
#  {'age': 58, 'name': 'Michel Foucault'},
#  {'age': 79, 'name': 'Moritz Lazarus'},
#  {'age': 99, 'name': 'Mortimer J. Adler'},
#  {'age': 69, 'name': 'Moses Maimonides'},
#  {'age': 57, 'name': 'Moses Mendelssohn'},
#  {'age': 69, 'name': 'Mulla Sadra'},
#  {'age': 76, 'name': 'Muro Kyuso'},
#  {'age': 33, 'name': 'Nathanael Culverwel'},
#  {'age': 63, 'name': 'Nicholas of Cusa'},
#  {'age': 63, 'name': 'Nikolay Yakovlevich Danilevsky'},
#  {'age': 75, 'name': 'Nishida Kitaro'},
#  {'age': 69, 'name': 'Norman Robert Campbell'},
#  {'age': 53, 'name': 'Oswald Kulpe'},
#  {'age': 56, 'name': 'Oswald Spengler'},
#  {'age': 80, 'name': 'Otto Friedrich von Gierke'},
#  {'age': 63, 'name': 'Otto Neurath'},
#  {'age': 77, 'name': 'Paul Shorey'},
#  {'age': 79, 'name': 'Paul Tillich'},
#  {'age': 57, 'name': 'Paul of Venice'},
#  {'age': 59, 'name': 'Pierre Bayle'},
#  {'age': 63, 'name': 'Pierre Gassendi'},
#  {'age': 81, 'name': 'Pierre Laromiguiere'},
#  {'age': 74, 'name': 'Pierre Leroux'},
#  {'age': 70, 'name': 'Pierre Nicole'},
#  {'age': 74, 'name': 'Pierre Teilhard de Chardin'},
#  {'age': 62, 'name': 'Pierre-Felix Guattari'},
#  {'age': 63, 'name': 'Pietro Pomponazzi'},
#  {'age': 75, 'name': 'Raghunatha Shiromani'},
#  {'age': 71, 'name': 'Ramana Maharshi'},
#  {'age': 120, 'name': 'Ramanuja'},
#  {'age': 83, 'name': 'Ramon Llull'},
#  {'age': 79, 'name': 'Reinhold Niebuhr'},
#  {'age': 54, 'name': 'Rene Descartes'},
#  {'age': 46, 'name': 'Richard Hooker'},
#  {'age': 68, 'name': 'Richard Price'},
#  {'age': 64, 'name': 'Robert Boyle'},
#  {'age': 78, 'name': 'Robert Grosseteste'},
#  {'age': 72, 'name': 'Roger Bacon'},
#  {'age': 92, 'name': 'Rudolf Bultmann'},
#  {'age': 79, 'name': 'Rudolf Carnap'},
#  {'age': 68, 'name': 'Rudolf Otto'},
#  {'age': 46, 'name': 'Salomon Maimon'},
#  {'age': 79, 'name': 'Samuel Alexander'},
#  {'age': 79, 'name': 'Samuel Bailey'},
#  {'age': 74, 'name': 'Samuel Hirsch'},
#  {'age': 50, 'name': 'Shankara'},
#  {'age': 66, 'name': 'Shao Yong'},
#  {'age': 78, 'name': 'Shri Aurobindo'},
#  {'age': 87, 'name': 'Sidney Hook'},
#  {'age': 52, 'name': 'Simon Foucher'},
#  {'age': 34, 'name': 'Simone Weil'},
#  {'age': 81, 'name': 'Solomon Formstecher'},
#  {'age': 42, 'name': 'Soren Kierkegaard'},
#  {'age': 53, 'name': 'Stanislaw Lesniewski'},
#  {'age': 87, 'name': 'Stephen Edelston Toulmin'},
#  {'age': 90, 'name': 'Susanne K. Langer'},
#  {'age': 57, 'name': 'Taixu'},
#  {'age': 74, 'name': 'Tao Sheng'},
#  {'age': 80, 'name': 'Theodor Gomperz'},
#  {'age': 66, 'name': 'Theodor Wiesengrund Adorno'},
#  {'age': 75, 'name': 'Theodosius Dobzhansky'},
#  {'age': 70, 'name': 'Thomas Henry Huxley'},
#  {'age': 91, 'name': 'Thomas Hobbes'},
#  {'age': 86, 'name': 'Thomas Reid'},
#  {'age': 71, 'name': 'Tommaso Campanella'},
#  {'age': 55, 'name': 'Uriel Acosta'},
#  {'age': 52, 'name': 'Vallabha'},
#  {'age': 47, 'name': 'Vladimir Sergeyevich Solovyov'},
#  {'age': 48, 'name': 'Walter Benjamin'},
#  {'age': 23, 'name': 'Wang Bi'},
#  {'age': 73, 'name': 'Wang Chong'},
#  {'age': 57, 'name': 'Wang Yangming'},
#  {'age': 71, 'name': 'Watsuji Tetsuro'},
#  {'age': 75, 'name': 'Werner Heisenberg'},
#  {'age': 77, 'name': 'Wilfrid Sellars'},
#  {'age': 78, 'name': 'Wilhelm Dilthey'},
#  {'age': 92, 'name': 'Willard Van Orman Quine'},
#  {'age': 80, 'name': 'William Godwin'},
#  {'age': 68, 'name': 'William James'},
#  {'age': 34, 'name': 'William Kingdon Clifford'},
#  {'age': 62, 'name': 'William Paley'},
#  {'age': 94, 'name': 'William Ralph Inge'},
#  {'age': 72, 'name': 'William Whewell'},
#  {'age': 81, 'name': 'William of Auxerre'},
#  {'age': 51, 'name': 'William of Champeaux'},
#  {'age': 64, 'name': 'William of Ockham'},
#  {'age': 83, 'name': 'Xiong Shili'},
#  {'age': 69, 'name': 'Yan Yuan'},
#  {'age': 57, 'name': 'Zhang Zai'},
#  {'age': 56, 'name': 'Zhou Dunyi'},
#  {'age': 70, 'name': 'Zhu Xi'},
#  {'age': 72, 'name': 'al-Farabi'},
#  {'age': 53, 'name': 'al-Ghazali'})
# CPU times: user 25.9 ms, sys: 16.1 ms, total: 42 ms
# Wall time: 1.97 s

# %% [markdown]
# Why concurrent.futures over multiprocessing?
#
# One answer, it allows for multithreading...

# %%
# %%time
# !python concurrent_example.py
# Out:
# Process ID 93481 is processing philosopher: Aaron David Gordon
# Process ID 93481 is processing philosopher: Abraham Joshua Heschel
# Process ID 93481 is processing philosopher: Albert of Saxony
# Process ID 93481 is processing philosopher: Alessandro Achillini
# Process ID 93481 is processing philosopher: Alexander Gottlieb Baumgarten
# Process ID 93481 is processing philosopher: Alexius Meinong
# Process ID 93481 is processing philosopher: Alfred Firmin Loisy
# Process ID 93479 is processing philosopher: Alfred Korzybski
# Process ID 93483 is processing philosopher: Alfred North Whitehead
# Process ID 93479 is processing philosopher: Allan Bloom
# Process ID 93481 is processing philosopher: Anicius Manlius Severinus Boethius
# Process ID 93484 is processing philosopher: Antonio Labriola
# Process ID 93483 is processing philosopher: Antonio Rosmini-Serbati
# Process ID 93485 is processing philosopher: Antony Flew
# Process ID 93479 is processing philosopher: Armando Carlini
# Process ID 93481 is processing philosopher: Arthur O. Lovejoy
# Process ID 93480 is processing philosopher: Arthur Schopenhauer
# Process ID 93484 is processing philosopher: Arthur Stanley Eddington
# Process ID 93483 is processing philosopher: Ashvaghosha
# Process ID 93485 is processing philosopher: Auguste Comte
# Process ID 93481 is processing philosopher: Averroes
# Process ID 93479 is processing philosopher: Avicenna
# Process ID 93486 is processing philosopher: Bartolome de Medina
# Process ID 93480 is processing philosopher: Benedetto Croce
# Process ID 93484 is processing philosopher: Benedict de Spinoza
# Process ID 93483 is processing philosopher: Bernard Bosanquet
# Process ID 93485 is processing philosopher: Bernard de Mandeville
# Process ID 93481 is processing philosopher: Bertrand Russell
# Process ID 93479 is processing philosopher: Bessarion
# Process ID 93486 is processing philosopher: Bhartrihari
# Process ID 93480 is processing philosopher: Blaise Pascal
# Process ID 93484 is processing philosopher: Blessed John Duns Scotus
# Process ID 93483 is processing philosopher: Carl Gustav Hempel
# Process ID 93485 is processing philosopher: Charles Sanders Peirce
# Process ID 93481 is processing philosopher: Cheng Hao
# Process ID 93488 is processing philosopher: Cheng Yi
# Process ID 93479 is processing philosopher: Claude-Adrien Helvetius
# Process ID 93487 is processing philosopher: David Friedrich Strauss
# Process ID 93486 is processing philosopher: David Hartley
# Process ID 93480 is processing philosopher: David Hume
# Process ID 93483 is processing philosopher: David Ross
# Process ID 93484 is processing philosopher: Denis Diderot
# Process ID 93485 is processing philosopher: Derek Parfit
# Process ID 93481 is processing philosopher: Edith Stein
# Process ID 93488 is processing philosopher: Edmund Husserl
# Process ID 93479 is processing philosopher: Eduard von Hartmann
# Process ID 93487 is processing philosopher: Edward Caird
# Process ID 93486 is processing philosopher: Edward Westermarck
# Process ID 93480 is processing philosopher: Emmanuel Levinas
# Process ID 93483 is processing philosopher: Erich Frank
# Process ID 93484 is processing philosopher: Erich Fromm
# Process ID 93485 is processing philosopher: Ernest Nagel
# Process ID 93481 is processing philosopher: Ernest Renan
# Process ID 93479 is processing philosopher: Ernst Mach
# Process ID 93488 is processing philosopher: Ernst Troeltsch
# Process ID 93486 is processing philosopher: Erwin Schrodinger
# Process ID 93487 is processing philosopher: Etienne Bonnot de Condillac
# Process ID 93480 is processing philosopher: Etienne Gilson
# Process ID 93483 is processing philosopher: Ferdinand Christian Baur
# Process ID 93484 is processing philosopher: Francis Hutcheson
# Process ID 93482 is processing philosopher: Francisco Suarez
# Process ID 93481 is processing philosopher: Franciscus Hemsterhuis
# Process ID 93487 is processing philosopher: Franz Brentano
# Process ID 93479 is processing philosopher: Franz Rosenzweig
# Process ID 93485 is processing philosopher: Frederick Robert Tennant
# Process ID 93488 is processing philosopher: Friedrich Nietzsche
# Process ID 93486 is processing philosopher: Friedrich Schleiermacher
# Process ID 93480 is processing philosopher: Friedrich Theodor von Vischer
# Process ID 93483 is processing philosopher: Friedrich Wilhelm Joseph von Schelling
# Process ID 93484 is processing philosopher: Fritz Mauthner
# Process ID 93482 is processing philosopher: Fyodor Ippolitovich Shcherbatskoy
# Process ID 93481 is processing philosopher: Gabriel Biel
# Process ID 93487 is processing philosopher: Gaston Frommel
# Process ID 93488 is processing philosopher: Ge Hong
# Process ID 93479 is processing philosopher: Gennadios II Scholarios
# Process ID 93485 is processing philosopher: Georg Bernhard Bilfinger
# Process ID 93486 is processing philosopher: Georg Brandes
# Process ID 93480 is processing philosopher: Georg Simmel
# Process ID 93483 is processing philosopher: Georg Wilhelm Friedrich Hegel
# Process ID 93484 is processing philosopher: George Berkeley
# Process ID 93482 is processing philosopher: George Gemistus Plethon
# Process ID 93479 is processing philosopher: George Grant
# Process ID 93485 is processing philosopher: George Henry Lewes
# Process ID 93487 is processing philosopher: George Herbert Mead
# Process ID 93481 is processing philosopher: George Santayana
# Process ID 93486 is processing philosopher: George Trumbull Ladd
# Process ID 93488 is processing philosopher: George Tyrrell
# Process ID 93480 is processing philosopher: Geraud de Cordemoy
# Process ID 93483 is processing philosopher: Giambattista Vico
# Process ID 93484 is processing philosopher: Giles of Rome
# Process ID 93487 is processing philosopher: Gilles Deleuze
# Process ID 93481 is processing philosopher: Gottfried Wilhelm Leibniz
# Process ID 93486 is processing philosopher: Gotthold Ephraim Lessing
# Process ID 93482 is processing philosopher: Gottlob Frege
# Process ID 93488 is processing philosopher: Gregory of Rimini
# Process ID 93485 is processing philosopher: Gu Yanwu
# Process ID 93479 is processing philosopher: Gustav Theodor Fechner
# Process ID 93483 is processing philosopher: Hajji Hadi Sabzevari
# Process ID 93480 is processing philosopher: Hannah Arendt
# Process ID 93484 is processing philosopher: Hans Reichenbach
# Process ID 93479 is processing philosopher: Hans-Georg Gadamer
# Process ID 93481 is processing philosopher: Harry S. Broudy
# Process ID 93487 is processing philosopher: Hatano Seiichi
# Process ID 93482 is processing philosopher: Hayashi Razan
# Process ID 93485 is processing philosopher: He Yan
# Process ID 93486 is processing philosopher: Hemachandra
# Process ID 93488 is processing philosopher: Henri Bergson
# Process ID 93483 is processing philosopher: Henri Berr
# Process ID 93480 is processing philosopher: Henri Poincare
# Process ID 93484 is processing philosopher: Henry Longueville Mansel
# Process ID 93485 is processing philosopher: Henry Sidgwick
# Process ID 93479 is processing philosopher: Herbert Spencer
# Process ID 93481 is processing philosopher: Hermann Cohen
# Process ID 93486 is processing philosopher: Hermann Samuel Reimarus
# Process ID 93488 is processing philosopher: Hermann von Helmholtz
# Process ID 93482 is processing philosopher: Hilary Putnam
# Process ID 93487 is processing philosopher: Ibn Falaquera
# Process ID 93480 is processing philosopher: Ibn Gabirol
# Process ID 93483 is processing philosopher: Immanuel Kant
# Process ID 93484 is processing philosopher: Inoue Tetsujiro
# Process ID 93479 is processing philosopher: Isaac of Stella
# Process ID 93485 is processing philosopher: Isaak August Dorner
# Process ID 93481 is processing philosopher: Ito Jinsai
# Process ID 93488 is processing philosopher: Jacob Moleschott
# Process ID 93487 is processing philosopher: Jacques Derrida
# Process ID 93486 is processing philosopher: Jacques Maritain
# Process ID 93482 is processing philosopher: Jaime Luciano Balmes
# Process ID 93480 is processing philosopher: Jakob Bohme
# Process ID 93483 is processing philosopher: James Frederick Ferrier
# Process ID 93484 is processing philosopher: James J. Gibson
# Process ID 93481 is processing philosopher: James Mark Baldwin
# Process ID 93488 is processing philosopher: Jean Baudrillard
# Process ID 93485 is processing philosopher: Jean Buridan
# Process ID 93487 is processing philosopher: James Martineau
# Process ID 93479 is processing philosopher: Jean-Jacques Rousseau
# Process ID 93486 is processing philosopher: Jean-Paul Sartre
# Process ID 93482 is processing philosopher: Jeremy Bentham
# Process ID 93480 is processing philosopher: Joachim Wach
# Process ID 93483 is processing philosopher: Johann Gottlieb Fichte
# Process ID 93484 is processing philosopher: Johann Heinrich Lambert
# Process ID 93481 is processing philosopher: John Baconthorpe
# Process ID 93479 is processing philosopher: John Dewey
# Process ID 93488 is processing philosopher: John Fiske
# Process ID 93485 is processing philosopher: John Langshaw Austin
# Process ID 93487 is processing philosopher: John Locke
# Process ID 93486 is processing philosopher: John Neville Keynes
# Process ID 93482 is processing philosopher: John Scott Haldane
# Process ID 93483 is processing philosopher: John Scotus Erigena
# Process ID 93480 is processing philosopher: John Stuart Mill
# Process ID 93484 is processing philosopher: John Venn
# Process ID 93481 is processing philosopher: John Wycliffe
# Process ID 93488 is processing philosopher: John of Paris
# Process ID 93479 is processing philosopher: John of Salisbury
# Process ID 93485 is processing philosopher: Jonathan Edwards
# Process ID 93482 is processing philosopher: Jose Ortega y Gasset
# Process ID 93487 is processing philosopher: Jose Vasconcelos
# Process ID 93486 is processing philosopher: Joseph Butler
# Process ID 93483 is processing philosopher: Joseph Priestley
# Process ID 93481 is processing philosopher: Josiah Royce
# Process ID 93480 is processing philosopher: Julian Huxley
# Process ID 93484 is processing philosopher: Justus Lipsius
# Process ID 93488 is processing philosopher: Karl Jaspers
# Process ID 93479 is processing philosopher: Karl Marx
# Process ID 93482 is processing philosopher: Karl Popper
# Process ID 93487 is processing philosopher: Kumazawa Banzan
# Process ID 93486 is processing philosopher: Leopold Kronecker
# Process ID 93485 is processing philosopher: Levi ben Gershom
# Process ID 93483 is processing philosopher: Li Ao
# Process ID 93481 is processing philosopher: Liang Shuming
# Process ID 93484 is processing philosopher: Lorenzo Valla
# Process ID 93480 is processing philosopher: Louis Althusser
# Process ID 93488 is processing philosopher: Louis Lavelle
# Process ID 93479 is processing philosopher: Louis-Alexandre Couturat
# Process ID 93482 is processing philosopher: Lu Jiuyuan
# Process ID 93487 is processing philosopher: Lucien Levy-Bruhl
# Process ID 93486 is processing philosopher: Ludwig Klages
# Process ID 93485 is processing philosopher: Ludwig Wittgenstein
# Process ID 93483 is processing philosopher: Madhva
# Process ID 93484 is processing philosopher: Maria Gaetana Agnesi
# Process ID 93480 is processing philosopher: Marie-Francois-Pierre Maine de Biran
# Process ID 93481 is processing philosopher: Marin Mersenne
# Process ID 93488 is processing philosopher: Marjorie Grene
# Process ID 93486 is processing philosopher: Marko Marulic
# Process ID 93479 is processing philosopher: Marsilio Ficino
# Process ID 93482 is processing philosopher: Maurice Blondel
# Process ID 93485 is processing philosopher: Maurice Merleau-Ponty
# Process ID 93487 is processing philosopher: Max Black
# Process ID 93481 is processing philosopher: Max Scheler
# Process ID 93483 is processing philosopher: Max Stirner
# Process ID 93484 is processing philosopher: Michel Foucault
# Process ID 93480 is processing philosopher: Moritz Lazarus
# Process ID 93487 is processing philosopher: Mortimer J. Adler
# Process ID 93488 is processing philosopher: Moses Maimonides
# Process ID 93482 is processing philosopher: Moses Mendelssohn
# Process ID 93479 is processing philosopher: Mulla Sadra
# Process ID 93486 is processing philosopher: Muro Kyuso
# Process ID 93485 is processing philosopher: Nathanael Culverwel
# Process ID 93484 is processing philosopher: Nicholas of Cusa
# Process ID 93480 is processing philosopher: Nikolay Yakovlevich Danilevsky
# Process ID 93481 is processing philosopher: Nishida Kitaro
# Process ID 93483 is processing philosopher: Norman Robert Campbell
# Process ID 93487 is processing philosopher: Oswald Kulpe
# Process ID 93479 is processing philosopher: Oswald Spengler
# Process ID 93488 is processing philosopher: Otto Friedrich von Gierke
# Process ID 93482 is processing philosopher: Otto Neurath
# Process ID 93486 is processing philosopher: Paul Shorey
# Process ID 93485 is processing philosopher: Paul Tillich
# Process ID 93480 is processing philosopher: Paul of Venice
# Process ID 93484 is processing philosopher: Pierre Bayle
# Process ID 93481 is processing philosopher: Pierre Gassendi
# Process ID 93483 is processing philosopher: Pierre Laromiguiere
# Process ID 93488 is processing philosopher: Pierre Leroux
# Process ID 93487 is processing philosopher: Pierre Nicole
# Process ID 93485 is processing philosopher: Pierre Teilhard de Chardin
# Process ID 93482 is processing philosopher: Pierre-Felix Guattari
# Process ID 93479 is processing philosopher: Pietro Pomponazzi
# Process ID 93486 is processing philosopher: Raghunatha Shiromani
# Process ID 93480 is processing philosopher: Ramana Maharshi
# Process ID 93481 is processing philosopher: Ramon Llull
# Process ID 93484 is processing philosopher: Ramanuja
# Process ID 93483 is processing philosopher: Reinhold Niebuhr
# Process ID 93482 is processing philosopher: Rene Descartes
# Process ID 93487 is processing philosopher: Richard Price
# Process ID 93488 is processing philosopher: Richard Hooker
# Process ID 93485 is processing philosopher: Robert Boyle
# Process ID 93479 is processing philosopher: Robert Grosseteste
# Process ID 93486 is processing philosopher: Roger Bacon
# Process ID 93483 is processing philosopher: Rudolf Bultmann
# Process ID 93480 is processing philosopher: Rudolf Carnap
# Process ID 93484 is processing philosopher: Rudolf Otto
# Process ID 93481 is processing philosopher: Salomon Maimon
# Process ID 93482 is processing philosopher: Samuel Alexander
# Process ID 93485 is processing philosopher: Samuel Bailey
# Process ID 93487 is processing philosopher: Samuel Hirsch
# Process ID 93486 is processing philosopher: Shankara
# Process ID 93488 is processing philosopher: Shao Yong
# Process ID 93479 is processing philosopher: Shri Aurobindo
# Process ID 93483 is processing philosopher: Sidney Hook
# Process ID 93481 is processing philosopher: Simon Foucher
# Process ID 93480 is processing philosopher: Simone Weil
# Process ID 93484 is processing philosopher: Solomon Formstecher
# Process ID 93482 is processing philosopher: Soren Kierkegaard
# Process ID 93485 is processing philosopher: Stanislaw Lesniewski
# Process ID 93487 is processing philosopher: Stephen Edelston Toulmin
# Process ID 93479 is processing philosopher: Susanne K. Langer
# Process ID 93488 is processing philosopher: Taixu
# Process ID 93486 is processing philosopher: Tao Sheng
# Process ID 93483 is processing philosopher: Theodor Gomperz
# Process ID 93481 is processing philosopher: Theodor Wiesengrund Adorno
# Process ID 93484 is processing philosopher: Theodosius Dobzhansky
# Process ID 93480 is processing philosopher: Thomas Henry Huxley
# Process ID 93482 is processing philosopher: Thomas Hobbes
# Process ID 93485 is processing philosopher: Thomas Reid
# Process ID 93479 is processing philosopher: Tommaso Campanella
# Process ID 93487 is processing philosopher: Uriel Acosta
# Process ID 93488 is processing philosopher: Vallabha
# Process ID 93486 is processing philosopher: Vladimir Sergeyevich Solovyov
# Process ID 93483 is processing philosopher: Walter Benjamin
# Process ID 93480 is processing philosopher: Wang Bi
# Process ID 93481 is processing philosopher: Wang Chong
# Process ID 93484 is processing philosopher: Wang Yangming
# Process ID 93482 is processing philosopher: Watsuji Tetsuro
# Process ID 93485 is processing philosopher: Werner Heisenberg
# Process ID 93479 is processing philosopher: Wilfrid Sellars
# Process ID 93486 is processing philosopher: Wilhelm Dilthey
# Process ID 93487 is processing philosopher: Willard Van Orman Quine
# Process ID 93488 is processing philosopher: William Godwin
# Process ID 93484 is processing philosopher: William James
# Process ID 93480 is processing philosopher: William Kingdon Clifford
# Process ID 93483 is processing philosopher: William Paley
# Process ID 93481 is processing philosopher: William Ralph Inge
# Process ID 93485 is processing philosopher: William Whewell
# Process ID 93479 is processing philosopher: William of Auxerre
# Process ID 93482 is processing philosopher: William of Champeaux
# Process ID 93486 is processing philosopher: William of Ockham
# Process ID 93488 is processing philosopher: Xiong Shili
# Process ID 93487 is processing philosopher: Yan Yuan
# Process ID 93480 is processing philosopher: Zhang Zai
# Process ID 93481 is processing philosopher: Zhou Dunyi
# Process ID 93484 is processing philosopher: Zhu Xi
# Process ID 93483 is processing philosopher: al-Farabi
# Process ID 93479 is processing philosopher: al-Ghazali
# ({'age': 66, 'name': 'Aaron David Gordon'},
#  {'age': 65, 'name': 'Abraham Joshua Heschel'},
#  {'age': 74, 'name': 'Albert of Saxony'},
#  {'age': 49, 'name': 'Alessandro Achillini'},
#  {'age': 48, 'name': 'Alexander Gottlieb Baumgarten'},
#  {'age': 67, 'name': 'Alexius Meinong'},
#  {'age': 83, 'name': 'Alfred Firmin Loisy'},
#  {'age': 71, 'name': 'Alfred Korzybski'},
#  {'age': 86, 'name': 'Alfred North Whitehead'},
#  {'age': 62, 'name': 'Allan Bloom'},
#  {'age': 49, 'name': 'Anicius Manlius Severinus Boethius'},
#  {'age': 61, 'name': 'Antonio Labriola'},
#  {'age': 58, 'name': 'Antonio Rosmini-Serbati'},
#  {'age': 87, 'name': 'Antony Flew'},
#  {'age': 81, 'name': 'Armando Carlini'},
#  {'age': 89, 'name': 'Arthur O. Lovejoy'},
#  {'age': 72, 'name': 'Arthur Schopenhauer'},
#  {'age': 62, 'name': 'Arthur Stanley Eddington'},
#  {'age': 70, 'name': 'Ashvaghosha'},
#  {'age': 59, 'name': 'Auguste Comte'},
#  {'age': 72, 'name': 'Averroes'},
#  {'age': 57, 'name': 'Avicenna'},
#  {'age': 52, 'name': 'Bartolome de Medina'},
#  {'age': 86, 'name': 'Benedetto Croce'},
#  {'age': 45, 'name': 'Benedict de Spinoza'},
#  {'age': 75, 'name': 'Bernard Bosanquet'},
#  {'age': 63, 'name': 'Bernard de Mandeville'},
#  {'age': 98, 'name': 'Bertrand Russell'},
#  {'age': 69, 'name': 'Bessarion'},
#  {'age': 81, 'name': 'Bhartrihari'},
#  {'age': 39, 'name': 'Blaise Pascal'},
#  {'age': 42, 'name': 'Blessed John Duns Scotus'},
#  {'age': 92, 'name': 'Carl Gustav Hempel'},
#  {'age': 75, 'name': 'Charles Sanders Peirce'},
#  {'age': 53, 'name': 'Cheng Hao'},
#  {'age': 74, 'name': 'Cheng Yi'},
#  {'age': 56, 'name': 'Claude-Adrien Helvetius'},
#  {'age': 66, 'name': 'David Friedrich Strauss'},
#  {'age': 52, 'name': 'David Hartley'},
#  {'age': 65, 'name': 'David Hume'},
#  {'age': 94, 'name': 'David Ross'},
#  {'age': 71, 'name': 'Denis Diderot'},
#  {'age': 75, 'name': 'Derek Parfit'},
#  {'age': 51, 'name': 'Edith Stein'},
#  {'age': 79, 'name': 'Edmund Husserl'},
#  {'age': 64, 'name': 'Eduard von Hartmann'},
#  {'age': 73, 'name': 'Edward Caird'},
#  {'age': 77, 'name': 'Edward Westermarck'},
#  {'age': 89, 'name': 'Emmanuel Levinas'},
#  {'age': 66, 'name': 'Erich Frank'},
#  {'age': 80, 'name': 'Erich Fromm'},
#  {'age': 84, 'name': 'Ernest Nagel'},
#  {'age': 69, 'name': 'Ernest Renan'},
#  {'age': 78, 'name': 'Ernst Mach'},
#  {'age': 58, 'name': 'Ernst Troeltsch'},
#  {'age': 74, 'name': 'Erwin Schrodinger'},
#  {'age': 65, 'name': 'Etienne Bonnot de Condillac'},
#  {'age': 94, 'name': 'Etienne Gilson'},
#  {'age': 68, 'name': 'Ferdinand Christian Baur'},
#  {'age': 52, 'name': 'Francis Hutcheson'},
#  {'age': 69, 'name': 'Francisco Suarez'},
#  {'age': 69, 'name': 'Franciscus Hemsterhuis'},
#  {'age': 79, 'name': 'Franz Brentano'},
#  {'age': 43, 'name': 'Franz Rosenzweig'},
#  {'age': 91, 'name': 'Frederick Robert Tennant'},
#  {'age': 56, 'name': 'Friedrich Nietzsche'},
#  {'age': 66, 'name': 'Friedrich Schleiermacher'},
#  {'age': 80, 'name': 'Friedrich Theodor von Vischer'},
#  {'age': 79, 'name': 'Friedrich Wilhelm Joseph von Schelling'},
#  {'age': 74, 'name': 'Fritz Mauthner'},
#  {'age': 76, 'name': 'Fyodor Ippolitovich Shcherbatskoy'},
#  {'age': 75, 'name': 'Gabriel Biel'},
#  {'age': 44, 'name': 'Gaston Frommel'},
#  {'age': 60, 'name': 'Ge Hong'},
#  {'age': 68, 'name': 'Gennadios II Scholarios'},
#  {'age': 57, 'name': 'Georg Bernhard Bilfinger'},
#  {'age': 85, 'name': 'Georg Brandes'},
#  {'age': 60, 'name': 'Georg Simmel'},
#  {'age': 61, 'name': 'Georg Wilhelm Friedrich Hegel'},
#  {'age': 68, 'name': 'George Berkeley'},
#  {'age': 97, 'name': 'George Gemistus Plethon'},
#  {'age': 70, 'name': 'George Grant'},
#  {'age': 61, 'name': 'George Henry Lewes'},
#  {'age': 68, 'name': 'George Herbert Mead'},
#  {'age': 89, 'name': 'George Santayana'},
#  {'age': 79, 'name': 'George Trumbull Ladd'},
#  {'age': 48, 'name': 'George Tyrrell'},
#  {'age': 64, 'name': 'Geraud de Cordemoy'},
#  {'age': 76, 'name': 'Giambattista Vico'},
#  {'age': 73, 'name': 'Giles of Rome'},
#  {'age': 70, 'name': 'Gilles Deleuze'},
#  {'age': 70, 'name': 'Gottfried Wilhelm Leibniz'},
#  {'age': 52, 'name': 'Gotthold Ephraim Lessing'},
#  {'age': 77, 'name': 'Gottlob Frege'},
#  {'age': 58, 'name': 'Gregory of Rimini'},
#  {'age': 69, 'name': 'Gu Yanwu'},
#  {'age': 86, 'name': 'Gustav Theodor Fechner'},
#  {'age': 80, 'name': 'Hajji Hadi Sabzevari'},
#  {'age': 69, 'name': 'Hannah Arendt'},
#  {'age': 62, 'name': 'Hans Reichenbach'},
#  {'age': 102, 'name': 'Hans-Georg Gadamer'},
#  {'age': 93, 'name': 'Harry S. Broudy'},
#  {'age': 73, 'name': 'Hatano Seiichi'},
#  {'age': 74, 'name': 'Hayashi Razan'},
#  {'age': 56, 'name': 'He Yan'},
#  {'age': 84, 'name': 'Hemachandra'},
#  {'age': 82, 'name': 'Henri Bergson'},
#  {'age': 91, 'name': 'Henri Berr'},
#  {'age': 58, 'name': 'Henri Poincare'},
#  {'age': 51, 'name': 'Henry Longueville Mansel'},
#  {'age': 62, 'name': 'Henry Sidgwick'},
#  {'age': 83, 'name': 'Herbert Spencer'},
#  {'age': 76, 'name': 'Hermann Cohen'},
#  {'age': 74, 'name': 'Hermann Samuel Reimarus'},
#  {'age': 73, 'name': 'Hermann von Helmholtz'},
#  {'age': 90, 'name': 'Hilary Putnam'},
#  {'age': 70, 'name': 'Ibn Falaquera'},
#  {'age': 48, 'name': 'Ibn Gabirol'},
#  {'age': 80, 'name': 'Immanuel Kant'},
#  {'age': 89, 'name': 'Inoue Tetsujiro'},
#  {'age': 69, 'name': 'Isaac of Stella'},
#  {'age': 75, 'name': 'Isaak August Dorner'},
#  {'age': 78, 'name': 'Ito Jinsai'},
#  {'age': 71, 'name': 'Jacob Moleschott'},
#  {'age': 74, 'name': 'Jacques Derrida'},
#  {'age': 91, 'name': 'Jacques Maritain'},
#  {'age': 38, 'name': 'Jaime Luciano Balmes'},
#  {'age': 49, 'name': 'Jakob Bohme'},
#  {'age': 56, 'name': 'James Frederick Ferrier'},
#  {'age': 75, 'name': 'James J. Gibson'},
#  {'age': 73, 'name': 'James Mark Baldwin'},
#  {'age': 95, 'name': 'James Martineau'},
#  {'age': 78, 'name': 'Jean Baudrillard'},
#  {'age': 58, 'name': 'Jean Buridan'},
#  {'age': 66, 'name': 'Jean-Jacques Rousseau'},
#  {'age': 75, 'name': 'Jean-Paul Sartre'},
#  {'age': 84, 'name': 'Jeremy Bentham'},
#  {'age': 57, 'name': 'Joachim Wach'},
#  {'age': 52, 'name': 'Johann Gottlieb Fichte'},
#  {'age': 49, 'name': 'Johann Heinrich Lambert'},
#  {'age': 56, 'name': 'John Baconthorpe'},
#  {'age': 93, 'name': 'John Dewey'},
#  {'age': 59, 'name': 'John Fiske'},
#  {'age': 49, 'name': 'John Langshaw Austin'},
#  {'age': 72, 'name': 'John Locke'},
#  {'age': 97, 'name': 'John Neville Keynes'},
#  {'age': 76, 'name': 'John Scott Haldane'},
#  {'age': 67, 'name': 'John Scotus Erigena'},
#  {'age': 67, 'name': 'John Stuart Mill'},
#  {'age': 89, 'name': 'John Venn'},
#  {'age': 54, 'name': 'John Wycliffe'},
#  {'age': 51, 'name': 'John of Paris'},
#  {'age': 60, 'name': 'John of Salisbury'},
#  {'age': 55, 'name': 'Jonathan Edwards'},
#  {'age': 72, 'name': 'Jose Ortega y Gasset'},
#  {'age': 77, 'name': 'Jose Vasconcelos'},
#  {'age': 60, 'name': 'Joseph Butler'},
#  {'age': 71, 'name': 'Joseph Priestley'},
#  {'age': 61, 'name': 'Josiah Royce'},
#  {'age': 88, 'name': 'Julian Huxley'},
#  {'age': 59, 'name': 'Justus Lipsius'},
#  {'age': 86, 'name': 'Karl Jaspers'},
#  {'age': 65, 'name': 'Karl Marx'},
#  {'age': 92, 'name': 'Karl Popper'},
#  {'age': 72, 'name': 'Kumazawa Banzan'},
#  {'age': 68, 'name': 'Leopold Kronecker'},
#  {'age': 56, 'name': 'Levi ben Gershom'},
#  {'age': 69, 'name': 'Li Ao'},
#  {'age': 95, 'name': 'Liang Shuming'},
#  {'age': 50, 'name': 'Lorenzo Valla'},
#  {'age': 72, 'name': 'Louis Althusser'},
#  {'age': 68, 'name': 'Louis Lavelle'},
#  {'age': 46, 'name': 'Louis-Alexandre Couturat'},
#  {'age': 54, 'name': 'Lu Jiuyuan'},
#  {'age': 82, 'name': 'Lucien Levy-Bruhl'},
#  {'age': 84, 'name': 'Ludwig Klages'},
#  {'age': 62, 'name': 'Ludwig Wittgenstein'},
#  {'age': 79, 'name': 'Madhva'},
#  {'age': 81, 'name': 'Maria Gaetana Agnesi'},
#  {'age': 58, 'name': 'Marie-Francois-Pierre Maine de Biran'},
#  {'age': 60, 'name': 'Marin Mersenne'},
#  {'age': 99, 'name': 'Marjorie Grene'},
#  {'age': 74, 'name': 'Marko Marulic'},
#  {'age': 66, 'name': 'Marsilio Ficino'},
#  {'age': 88, 'name': 'Maurice Blondel'},
#  {'age': 53, 'name': 'Maurice Merleau-Ponty'},
#  {'age': 79, 'name': 'Max Black'},
#  {'age': 54, 'name': 'Max Scheler'},
#  {'age': 50, 'name': 'Max Stirner'},
#  {'age': 58, 'name': 'Michel Foucault'},
#  {'age': 79, 'name': 'Moritz Lazarus'},
#  {'age': 99, 'name': 'Mortimer J. Adler'},
#  {'age': 69, 'name': 'Moses Maimonides'},
#  {'age': 57, 'name': 'Moses Mendelssohn'},
#  {'age': 69, 'name': 'Mulla Sadra'},
#  {'age': 76, 'name': 'Muro Kyuso'},
#  {'age': 33, 'name': 'Nathanael Culverwel'},
#  {'age': 63, 'name': 'Nicholas of Cusa'},
#  {'age': 63, 'name': 'Nikolay Yakovlevich Danilevsky'},
#  {'age': 75, 'name': 'Nishida Kitaro'},
#  {'age': 69, 'name': 'Norman Robert Campbell'},
#  {'age': 53, 'name': 'Oswald Kulpe'},
#  {'age': 56, 'name': 'Oswald Spengler'},
#  {'age': 80, 'name': 'Otto Friedrich von Gierke'},
#  {'age': 63, 'name': 'Otto Neurath'},
#  {'age': 77, 'name': 'Paul Shorey'},
#  {'age': 79, 'name': 'Paul Tillich'},
#  {'age': 57, 'name': 'Paul of Venice'},
#  {'age': 59, 'name': 'Pierre Bayle'},
#  {'age': 63, 'name': 'Pierre Gassendi'},
#  {'age': 81, 'name': 'Pierre Laromiguiere'},
#  {'age': 74, 'name': 'Pierre Leroux'},
#  {'age': 70, 'name': 'Pierre Nicole'},
#  {'age': 74, 'name': 'Pierre Teilhard de Chardin'},
#  {'age': 62, 'name': 'Pierre-Felix Guattari'},
#  {'age': 63, 'name': 'Pietro Pomponazzi'},
#  {'age': 75, 'name': 'Raghunatha Shiromani'},
#  {'age': 71, 'name': 'Ramana Maharshi'},
#  {'age': 120, 'name': 'Ramanuja'},
#  {'age': 83, 'name': 'Ramon Llull'},
#  {'age': 79, 'name': 'Reinhold Niebuhr'},
#  {'age': 54, 'name': 'Rene Descartes'},
#  {'age': 46, 'name': 'Richard Hooker'},
#  {'age': 68, 'name': 'Richard Price'},
#  {'age': 64, 'name': 'Robert Boyle'},
#  {'age': 78, 'name': 'Robert Grosseteste'},
#  {'age': 72, 'name': 'Roger Bacon'},
#  {'age': 92, 'name': 'Rudolf Bultmann'},
#  {'age': 79, 'name': 'Rudolf Carnap'},
#  {'age': 68, 'name': 'Rudolf Otto'},
#  {'age': 46, 'name': 'Salomon Maimon'},
#  {'age': 79, 'name': 'Samuel Alexander'},
#  {'age': 79, 'name': 'Samuel Bailey'},
#  {'age': 74, 'name': 'Samuel Hirsch'},
#  {'age': 50, 'name': 'Shankara'},
#  {'age': 66, 'name': 'Shao Yong'},
#  {'age': 78, 'name': 'Shri Aurobindo'},
#  {'age': 87, 'name': 'Sidney Hook'},
#  {'age': 52, 'name': 'Simon Foucher'},
#  {'age': 34, 'name': 'Simone Weil'},
#  {'age': 81, 'name': 'Solomon Formstecher'},
#  {'age': 42, 'name': 'Soren Kierkegaard'},
#  {'age': 53, 'name': 'Stanislaw Lesniewski'},
#  {'age': 87, 'name': 'Stephen Edelston Toulmin'},
#  {'age': 90, 'name': 'Susanne K. Langer'},
#  {'age': 57, 'name': 'Taixu'},
#  {'age': 74, 'name': 'Tao Sheng'},
#  {'age': 80, 'name': 'Theodor Gomperz'},
#  {'age': 66, 'name': 'Theodor Wiesengrund Adorno'},
#  {'age': 75, 'name': 'Theodosius Dobzhansky'},
#  {'age': 70, 'name': 'Thomas Henry Huxley'},
#  {'age': 91, 'name': 'Thomas Hobbes'},
#  {'age': 86, 'name': 'Thomas Reid'},
#  {'age': 71, 'name': 'Tommaso Campanella'},
#  {'age': 55, 'name': 'Uriel Acosta'},
#  {'age': 52, 'name': 'Vallabha'},
#  {'age': 47, 'name': 'Vladimir Sergeyevich Solovyov'},
#  {'age': 48, 'name': 'Walter Benjamin'},
#  {'age': 23, 'name': 'Wang Bi'},
#  {'age': 73, 'name': 'Wang Chong'},
#  {'age': 57, 'name': 'Wang Yangming'},
#  {'age': 71, 'name': 'Watsuji Tetsuro'},
#  {'age': 75, 'name': 'Werner Heisenberg'},
#  {'age': 77, 'name': 'Wilfrid Sellars'},
#  {'age': 78, 'name': 'Wilhelm Dilthey'},
#  {'age': 92, 'name': 'Willard Van Orman Quine'},
#  {'age': 80, 'name': 'William Godwin'},
#  {'age': 68, 'name': 'William James'},
#  {'age': 34, 'name': 'William Kingdon Clifford'},
#  {'age': 62, 'name': 'William Paley'},
#  {'age': 94, 'name': 'William Ralph Inge'},
#  {'age': 72, 'name': 'William Whewell'},
#  {'age': 81, 'name': 'William of Auxerre'},
#  {'age': 51, 'name': 'William of Champeaux'},
#  {'age': 64, 'name': 'William of Ockham'},
#  {'age': 83, 'name': 'Xiong Shili'},
#  {'age': 69, 'name': 'Yan Yuan'},
#  {'age': 57, 'name': 'Zhang Zai'},
#  {'age': 56, 'name': 'Zhou Dunyi'},
#  {'age': 70, 'name': 'Zhu Xi'},
#  {'age': 72, 'name': 'al-Farabi'},
#  {'age': 53, 'name': 'al-Ghazali'})
# CPU times: user 27.8 ms, sys: 16.5 ms, total: 44.3 ms
# Wall time: 1.82 s

# %% [markdown]
# ### Multiprocessing vs Concurrent.Futures and the GIL
#
# Python has something called the [Global Interpreter Lock (GIL)](https://realpython.com/python-gil/). The GIL prevents Python code from being executed in more than one thread at a time. So you may be asking yourself, how were we able to run `concurrent_example.py` above with `ThreadPoolExecutor` and get a faster time than with `ProcessPoolExecutor`. That is because our `time.sleep` is an I/O command that is blocking the thread, thereby allowing other threads to process.
#
# So, to regards to the question, "when should I use multiprocessing and when should I use concurrent.futures?" the answer is that you can use either, but you are probably better off using `concurrent.futures` every time. This is because `concurrent.futures` gives you access to both the `ThreadPoolExecutor` and the `ProcessPoolExecutor`, which each have their own time and place for use. Additionally, `ProcessPoolExecutor` is just a wrapper around `multiprocessing` (see [docs](https://docs.python.org/3/library/concurrent.futures.html#processpoolexecutor)), and there is no equivalent to `ThreadPoolExecutor` in `multiprocessing`.

# %% [markdown]
# ### The End of the GIL?
#
# This title is a bit click baity. No one is proposing we do away with the GIL entirely. However, there is a PEP currently under consideration ([PEP-684](https://peps.python.org/pep-0684/)) that proposes isolating the GIL to the interpreter level, not the process level. This would allow multiple interpreters to run in a process independently and help unlock true multi-core parallelism in Python.

# %% [markdown]
# ## Resources
#
# * [Overview of Functional Programming Generally](https://www.guru99.com/functional-programming-tutorial.html)
# * [Functional Programming in Python](https://realpython.com/python-functional-programming/)
# * [Philosopher Data Source](https://www.kaggle.com/datasets/matheusdalbuquerque/philosophers-dataset?resource=download)
# * [Python GIL](https://realpython.com/python-gil/)
